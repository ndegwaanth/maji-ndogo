# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Subquery in the SELECT clause

# %% [markdown]
# In this notebook, we will look at subqueries, which are powerful tools to enable more in-depth analysis in SQL. They are essentially intermediate results sets that we access with another query, so **a query inside another query**. We can use subqueries in various places in a query, and those subquery results also have various forms. Here, we look at the **use of a subquery in the `SELECT` clause.**

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to use **subqueries** instead of static values to make calculations dynamic.
# - How to turn a normal subquery into a **correlated subquery** to perform calculations based on specific criteria.

# %% [markdown]
# ## Overview
#
# Imagine we want to calculate the percentage of land area a specific country in a sub-region occupies, as a percentage of the total land area in that sub-region. That is a challenging question because we need to divide each country's land area with the sum of all countries in that sub-region.
# To do it, we can use a subquery. For example, let's just look at one sub-region for now, `Middle Africa`, and use the `Geographic_location` table to **find out the percentage of land each country has as a percentage of the total for 'Middle Africa'.**

# %% [markdown]
# ## Connecting to our MySQL database
#
# We will use our `Geographic_location` table in our `united_nations` database that we created in MySQL Workbench. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://anthony:Sucess%4022@localhost:3306/united_nations

# %%
# %%sql
# show tables;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 14 rows affected.
# [('access_to_basic_services',),
#  ('access_to_water',),
#  ('analysis_costs',),
#  ('basic_services',),
#  ('country_list',),
#  ('economic_indicators',),
#  ('employees',),
#  ('geographic_location',),
#  ('location',),
#  ('no_duplicates_access_to_basic_services',),
#  ('regions',),
#  ('sample_locations',),
#  ('water_basic_services',),
#  ('water_samples',)]

# %%
# %%sql
# select * from geographic_location limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700')),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', Decimal('0'))]

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. Calculate the total land area of the 'Middle Africa' sub-region
#
# Write a query that will find the `Land_area` sum for the `Middle Africa` sub-region. Call this column `total_land_area`.

# %%
# %%sql
# select
#     Country_name,
#     (
#         select
#             sum(land_area) from geographic_location
#         where
#             Country_name = gl.Country_name
#             and Sub_region = 'Middle Africa'
#     ) as Total_Land_Area
# from geographic_location gl
# where Sub_region = 'Middle Africa'
# group by Country_name;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 9 rows affected.
# [('Angola', Decimal('1246700')),
#  ('Cameroon', Decimal('472710')),
#  ('Central African Republic', Decimal('622980')),
#  ('Chad', Decimal('1259200')),
#  ('Congo', Decimal('0')),
#  ('Democratic Republic of the Congo', Decimal('0')),
#  ('Equatorial Guinea', Decimal('28050')),
#  ('Gabon', Decimal('257670')),
#  ('Sao Tome and Principe', Decimal('960'))]

# %%
# %%sql
# SELECT
#     SUM(land_area) AS total_land_area
# FROM geographic_location
# WHERE Sub_region = 'Middle Africa';
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('3888270'),)]

# %%
# %%sql
# SELECT
#     gl.Country_name,
#     (
#         SELECT SUM(land_area)
#         FROM geographic_location
#         WHERE Sub_region = 'Middle Africa'
#     ) AS total_land_area
# FROM geographic_location gl
# WHERE gl.Sub_region = 'Middle Africa';
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 9 rows affected.
# [('Angola', Decimal('3888270')),
#  ('Cameroon', Decimal('3888270')),
#  ('Central African Republic', Decimal('3888270')),
#  ('Chad', Decimal('3888270')),
#  ('Congo', Decimal('3888270')),
#  ('Democratic Republic of the Congo', Decimal('3888270')),
#  ('Equatorial Guinea', Decimal('3888270')),
#  ('Gabon', Decimal('3888270')),
#  ('Sao Tome and Principe', Decimal('3888270'))]

# %% [markdown]
# ### 2. Calculate land area percentages for the Middle African countries using a static value
#
# Recall that, to find the percentage of land area each country in the `Middle Africa` sub-region occupies, we need to **divide each country’s land area with the `total_land_area`**, which we have calculated above. Copy and paste this land area value into a new query and calculate the percentages. Call this calculated column `pct_regional_land`.

# %%
# %%sql
# select
#     Country_name,
#     (
#         select
#             sum(land_area) from geographic_location
#         where
#             Country_name = gl.Country_name
#             and Sub_region = 'Middle Africa'
#     ) / (
#         select
#             sum(land_area) from geographic_location
#         where
#             Sub_region = 'Middle Africa'
#     ) * 100 as Total_Land_Area
# from geographic_location gl
# where Sub_region = 'Middle Africa'
# group by Country_name;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 9 rows affected.
# [('Angola', Decimal('32.0631')),
#  ('Cameroon', Decimal('12.1573')),
#  ('Central African Republic', Decimal('16.0220')),
#  ('Chad', Decimal('32.3846')),
#  ('Congo', Decimal('0.0000')),
#  ('Democratic Republic of the Congo', Decimal('0.0000')),
#  ('Equatorial Guinea', Decimal('0.7214')),
#  ('Gabon', Decimal('6.6269')),
#  ('Sao Tome and Principe', Decimal('0.0247'))]

# %% [markdown]
# ### 3. Calculate land area percentages for the Middle African countries using a subquery
#
# Instead of using the static value above, let's improve our query by using a subquery to achieve the same result.
#
# Hint: The subquery in this case will be the query we created to find the total land area in Exercise 1.

# %%
# %%sql
# select
#     Country_name,
#     (
#         select
#             sum(land_area) from geographic_location
#         where
#             Country_name = gl.Country_name
#             and Sub_region = 'Middle Africa'
#     ) / (
#         select
#             sum(land_area) from geographic_location
#         where
#             Sub_region = 'Middle Africa'
#     ) * 100 as Total_Land_Area
# from geographic_location gl
# where Sub_region = 'Middle Africa'
# group by Country_name;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 9 rows affected.
# [('Angola', Decimal('32.0631')),
#  ('Cameroon', Decimal('12.1573')),
#  ('Central African Republic', Decimal('16.0220')),
#  ('Chad', Decimal('32.3846')),
#  ('Congo', Decimal('0.0000')),
#  ('Democratic Republic of the Congo', Decimal('0.0000')),
#  ('Equatorial Guinea', Decimal('0.7214')),
#  ('Gabon', Decimal('6.6269')),
#  ('Sao Tome and Principe', Decimal('0.0247'))]

# %% [markdown]
# ### Correlated subqueries
#
# With a normal nested subquery (uncorrelated), **it runs first and executes once**, returning value(s) to be used by the outer query. This is what we have above where our subquery calculates the land area sum for the `Middle Africa` sub-region, and this is the value that is returned to the outer query to calculate land area percentages.
#
# If we want to calculate the land area percentages for all the regions, we would need to manually edit the search string in the `WHERE` clause, which is not very practical.
#
# Instead, we can use a **correlated subquery**. This is a type of subquery that is **executed once for every row processed by the outer query**. It is often used when you need to perform a calculation based on values in the current row of the outer query. In our case, we want the subquery to calculate the land area sum based on the sub-region value of the current row being processed by the outer query.
#
# Below is a general syntax template where a correlated subquery has been used:

# %% [markdown]
# ```
# SELECT
#     outer_column1,
#     outer_column2
# FROM
#     outer_table AS outer_alias
# WHERE
#     expression operator (
#                         SELECT
#                             aggregate_function(inner_column)
#                         FROM
#                             inner_table AS inner_alias
#                         WHERE
#                             inner_column = outer_alias.outer_column2
#                         )
# ;
# ```

# %% [markdown]
# ### 4. Calculate country land area percentages for all the regions using a correlated subquery
#
# Transform the subquery in Exercise 2 into a correlated subquery that will calculate land area percentages for all the regions.
#
# Hint: Use the general syntax above to help you figure out how to achieve this.

# %%
# %%sql
# select
#     Country_name,
#     (
#         select
#             sum(land_area) from geographic_location
#         where
#             Country_name = gl.Country_name
#             and Sub_region = gl.Sub_region
#     ) / (
#         select
#             sum(land_area) from geographic_location
#         where
#             Sub_region = gl.Sub_region
#     ) * 100 as Total_Land_Area
# from geographic_location gl
# where Sub_region = gl.Sub_region
# group by Country_name;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 182 rows affected.
# [('Afghanistan', Decimal('13.6732')),
#  ('Algeria', Decimal('36.0273')),
#  ('American Samoa', Decimal('2.7709')),
#  ('Angola', Decimal('32.0631')),
#  ('Anguilla', Decimal('0.0000')),
#  ('Antigua and Barbuda', Decimal('0.2114')),
#  ('Argentina', Decimal('17.7691')),
#  ('Armenia', Decimal('0.8161')),
#  ('Aruba', Decimal('0.0865')),
#  ('Australia', Decimal('96.6895')),
#  ('Azerbaijan', Decimal('2.3694')),
#  ('Bahamas', Decimal('0.0000')),
#  ('Bahrain', Decimal('0.0224')),
#  ('Bangladesh', Decimal('2.7289')),
#  ('Barbados', Decimal('0.2066')),
#  ('Belize', Decimal('0.9302')),
#  ('Benin', Decimal('1.9660')),
#  ('Bermuda', Decimal('0.0006')),
#  ('Bhutan', Decimal('0.7995')),
#  ('Bolivia (Plurinational State of)', Decimal('0.0000')),
#  ('Botswana', Decimal('21.3806')),
#  ('Brazil', Decimal('54.2687')),
#  ('British Virgin Islands', Decimal('0.0721')),
#  ('Brunei Darussalam', Decimal('0.1363')),
#  ('Burkina Faso', Decimal('4.7702')),
#  ('Burundi', Decimal('0.4317')),
#  ('Cabo Verde', Decimal('0.0703')),
#  ('Cambodia', Decimal('4.5668')),
#  ('Cameroon', Decimal('12.1573')),
#  ('Canada', Decimal('95.6218')),
#  ('Cayman Islands', Decimal('0.1153')),
#  ('Central African Republic', Decimal('16.0220')),
#  ('Chad', Decimal('32.3846')),
#  ('Chile', Decimal('4.8277')),
#  ('China', Decimal('83.0626')),
#  ('Colombia', Decimal('7.2039')),
#  ('Comoros', Decimal('0.0313')),
#  ('Congo', Decimal('0.0000')),
#  ('Cook Islands', Decimal('0.0000')),
#  ('Costa Rica', Decimal('2.0823')),
#  ("Côte d'Ivoire", Decimal('0.0000')),
#  ('Cuba', Decimal('49.9222')),
#  ('Curaçao', Decimal('0.0000')),
#  ('Cyprus', Decimal('0.2649')),
#  ("Democratic People's Republic of Korea", Decimal('0.0000')),
#  ('Democratic Republic of the Congo', Decimal('0.0000')),
#  ('Djibouti', Decimal('0.3896')),
#  ('Dominica', Decimal('0.3604')),
#  ('Dominican Republic', Decimal('23.2144')),
#  ('Ecuador', Decimal('1.6126')),
#  ('Egypt', Decimal('0.0000')),
#  ('El Salvador', Decimal('0.8450')),
#  ('Equatorial Guinea', Decimal('0.7214')),
#  ('Eritrea', Decimal('2.0353')),
#  ('Eswatini', Decimal('0.6489')),
#  ('Ethiopia', Decimal('18.9701')),
#  ('Falkland Islands (Malvinas)', Decimal('0.0000')),
#  ('Fiji', Decimal('3.4498')),
#  ('French Guiana', Decimal('0.0000')),
#  ('French Polynesia', Decimal('48.0881')),
#  ('Gabon', Decimal('6.6269')),
#  ('Gambia', Decimal('0.0000')),
#  ('Georgia', Decimal('1.9919')),
#  ('Ghana', Decimal('3.9672')),
#  ('Greenland', Decimal('4.3776')),
#  ('Grenada', Decimal('0.1634')),
#  ('Guadeloupe', Decimal('0.0000')),
#  ('Guam', Decimal('21.8623')),
#  ('Guatemala', Decimal('4.3702')),
#  ('Guinea', Decimal('4.2842')),
#  ('Guinea-Bissau', Decimal('0.4903')),
#  ('Guyana', Decimal('1.2781')),
#  ('Haiti', Decimal('13.2434')),
#  ('Honduras', Decimal('4.5631')),
#  ('India', Decimal('62.3293')),
#  ('Indonesia', Decimal('48.5739')),
#  ('Iran (Islamic Republic of)', Decimal('0.0000')),
#  ('Iraq', Decimal('12.4443')),
#  ('Israel', Decimal('0.6203')),
#  ('Jamaica', Decimal('5.2041')),
#  ('Japan', Decimal('3.2124')),
#  ('Jordan', Decimal('2.5450')),
#  ('Kazakhstan', Decimal('72.0109')),
#  ('Kenya', Decimal('9.5667')),
#  ('Kiribati', Decimal('32.7935')),
#  ('Kuwait', Decimal('0.5108')),
#  ('Kyrgyzstan', Decimal('0.0000')),
#  ("Lao People's Democratic Republic", Decimal('0.0000')),
#  ('Lebanon', Decimal('0.2932')),
#  ('Lesotho', Decimal('1.1454')),
#  ('Liberia', Decimal('1.6794')),
#  ('Libya', Decimal('26.6156')),
#  ('Madagascar', Decimal('9.7795')),
#  ('Malawi', Decimal('1.5848')),
#  ('Malaysia', Decimal('8.5000')),
#  ('Maldives', Decimal('0.0063')),
#  ('Mali', Decimal('21.2742')),
#  ('Marshall Islands', Decimal('7.2874')),
#  ('Martinique', Decimal('0.0000')),
#  ('Mauritania', Decimal('17.9704')),
#  ('Mauritius', Decimal('0.0341')),
#  ('Mayotte', Decimal('0.0000')),
#  ('Mexico', Decimal('79.2776')),
#  ('Micronesia (Federated States of)', Decimal('0.0000')),
#  ('Mongolia', Decimal('13.7249')),
#  ('Montserrat', Decimal('0.0000')),
#  ('Morocco', Decimal('6.7509')),
#  ('Mozambique', Decimal('13.2184')),
#  ('Myanmar', Decimal('16.8883')),
#  ('Namibia', Decimal('31.0597')),
#  ('Nauru', Decimal('0.8097')),
#  ('Nepal', Decimal('3.0052')),
#  ('New Caledonia', Decimal('3.4517')),
#  ('New Zealand', Decimal('3.3105')),
#  ('Nicaragua', Decimal('4.9077')),
#  ('Niger', Decimal('22.0851')),
#  ('Nigeria', Decimal('15.8794')),
#  ('Niue', Decimal('0.0000')),
#  ('Northern Mariana Islands', Decimal('18.6235')),
#  ('Oman', Decimal('8.8718')),
#  ('Pakistan', Decimal('16.1605')),
#  ('Palau', Decimal('18.6235')),
#  ('Panama', Decimal('3.0240')),
#  ('Papua New Guinea', Decimal('85.5114')),
#  ('Paraguay', Decimal('2.5796')),
#  ('Peru', Decimal('8.3109')),
#  ('Philippines', Decimal('7.7141')),
#  ('Puerto Rico', Decimal('4.2623')),
#  ('Qatar', Decimal('0.3294')),
#  ('Republic of Korea', Decimal('0.0000')),
#  ('Réunion', Decimal('0.0000')),
#  ('Rwanda', Decimal('0.4147')),
#  ('Saint Barthélemy', Decimal('0.0000')),
#  ('Saint Helena', Decimal('0.0000')),
#  ('Saint Kitts and Nevis', Decimal('0.0000')),
#  ('Saint Lucia', Decimal('0.0000')),
#  ('Saint Martin (French Part)', Decimal('0.0000')),
#  ('Saint Pierre and Miquelon', Decimal('0.0000')),
#  ('Saint Vincent and the Grenadines', Decimal('0.0000')),
#  ('Samoa', Decimal('38.7503')),
#  ('Sao Tome and Principe', Decimal('0.0247')),
#  ('Saudi Arabia', Decimal('61.6209')),
#  ('Senegal', Decimal('3.3568')),
#  ('Seychelles', Decimal('0.0077')),
#  ('Sierra Leone', Decimal('1.2585')),
#  ('Singapore', Decimal('0.0184')),
#  ('Sint Maarten (Dutch part)', Decimal('0.0163')),
#  ('Solomon Islands', Decimal('5.2852')),
#  ('Somalia', Decimal('10.5450')),
#  ('South Africa', Decimal('45.7654')),
#  ('South Sudan', Decimal('10.6222')),
#  ('Sri Lanka', Decimal('1.2972')),
#  ('State of Palestine', Decimal('0.0000')),
#  ('Sudan', Decimal('28.2562')),
#  ('Suriname', Decimal('1.0129')),
#  ('Syrian Arab Republic', Decimal('5.2638')),
#  ('Tajikistan', Decimal('3.7020')),
#  ('Thailand', Decimal('13.2174')),
#  ('Timor-Leste', Decimal('0.3847')),
#  ('Togo', Decimal('0.9483')),
#  ('Tokelau', Decimal('0.0000')),
#  ('Tonga', Decimal('9.9751')),
#  ('Trinidad and Tobago', Decimal('2.4651')),
#  ('Tunisia', Decimal('2.3500')),
#  ('Türkiye', Decimal('0.0000')),
#  ('Turkmenistan', Decimal('12.5348')),
#  ('Turks and Caicos Islands', Decimal('0.4565')),
#  ('Tuvalu', Decimal('0.4156')),
#  ('Uganda', Decimal('3.3706')),
#  ('United Arab Emirates', Decimal('2.0358')),
#  ('United Republic of Tanzania', Decimal('0.0000')),
#  ('United States of America', Decimal('0.0000')),
#  ('United States Virgin Islands', Decimal('0.0000')),
#  ('Uruguay', Decimal('1.1364')),
#  ('Uzbekistan', Decimal('11.7523')),
#  ('Vanuatu', Decimal('2.3018')),
#  ('Venezuela (Bolivarian Republic of)', Decimal('0.0000')),
#  ('Viet Nam', Decimal('0.0000')),
#  ('Wallis and Futuna Islands', Decimal('0.0000')),
#  ('Yemen', Decimal('0.0000')),
#  ('Zambia', Decimal('12.4957')),
#  ('Zimbabwe', Decimal('6.5026'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Calculate the total land area of the 'Middle Africa' sub-region

# %%
# %%sql
#
# SELECT
#     SUM(Land_area) as total_land_area
# FROM
#     Geographic_location
# WHERE
#     Sub_region = 'Middle Africa';
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('3888270'),)]

# %% [markdown]
# This query will return a single value which is the sum of all of the `Land_area` for the `Middle Africa` sub-region.

# %% [markdown]
# ### 2. Calculate land area percentages for the Middle African countries using a static value
#
# To calculate the percentages, we select the country names and the land area for each country, which we then divide by the total area for Middle Africa multiplied by 100 (to get the percentage), and then round the result off.
#
# **Note:** In the above query, we calculated a `total_land_area` of **"3888270.00"** which we'll use in the query below to calculate percentages for each country.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     ROUND(Land_area/3888270.00*100) AS  pct_regional_land
# FROM
#     Geographic_location
# WHERE
#     Sub_region = 'Middle Africa';
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 9 rows affected.
# [('Angola', Decimal('32')),
#  ('Cameroon', Decimal('12')),
#  ('Central African Republic', Decimal('16')),
#  ('Chad', Decimal('32')),
#  ('Congo', Decimal('0')),
#  ('Democratic Republic of the Congo', Decimal('0')),
#  ('Equatorial Guinea', Decimal('1')),
#  ('Gabon', Decimal('7')),
#  ('Sao Tome and Principe', Decimal('0'))]

# %% [markdown]
# ### 3. Calculate land area percentages for the Middle African countries using a subquery
#
# We replace the static value above with the query that generated that result (the query in Exercise 1).

# %%
# %%sql
#
# SELECT
#     Country_name,
#     ROUND(land_area / (
#                         SELECT
#                             SUM(Land_area)
#                         FROM
#                             Geographic_location
#                         WHERE
#                             Sub_region = 'Middle Africa') * 100, 2) as Pct_regional_land
# FROM
#     Geographic_location
# WHERE
#     Sub_region = 'Middle Africa';

# %% [markdown]
# When we execute this, the inner query runs first and calculates the sum value, then “passes” that to the outer query to get the percentages. A subquery that passes a single value to the outer query is known as a **scalar subquery.**
#
# The benefit of using the subquery instead of the actual value is that if we want to do the same for another sub-region, we can just change the search string, “Middle Africa”, for example, to "Polynesia". It will process the same calculation using the Polynesian data. These types of calculations are known as **dynamic**. By changing some of the filters, we automatically calculate the corresponding sum.

# %% [markdown]
# ### 4. Calculate land area percentages for all the regions using a correlated subquery
#
# We replace **“Middle Africa”** with a reference to the field that will change for each row, that is, the `Sub_region`. In order for this to work, we have to give the table in our main query an alias, **`g`**, so that when we refer to it in the subquery, SQL knows we are talking about the outer query’s table.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     ROUND(Land_area / (
#                         SELECT
#                             SUM(Land_area)
#                         FROM
#                             Geographic_location
#                         WHERE
#                             Sub_region = g.Sub_region) * 100, 2) as Pct_regional_land
# FROM
#     Geographic_location AS g;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 182 rows affected.
# [('Afghanistan', Decimal('13.67')),
#  ('Algeria', Decimal('36.03')),
#  ('American Samoa', Decimal('2.77')),
#  ('Angola', Decimal('32.06')),
#  ('Anguilla', Decimal('0.00')),
#  ('Antigua and Barbuda', Decimal('0.21')),
#  ('Argentina', Decimal('17.77')),
#  ('Armenia', Decimal('0.82')),
#  ('Aruba', Decimal('0.09')),
#  ('Australia', Decimal('96.69')),
#  ('Azerbaijan', Decimal('2.37')),
#  ('Bahamas', Decimal('0.00')),
#  ('Bahrain', Decimal('0.02')),
#  ('Bangladesh', Decimal('2.73')),
#  ('Barbados', Decimal('0.21')),
#  ('Belize', Decimal('0.93')),
#  ('Benin', Decimal('1.97')),
#  ('Bermuda', Decimal('0.00')),
#  ('Bhutan', Decimal('0.80')),
#  ('Bolivia (Plurinational State of)', Decimal('0.00')),
#  ('Botswana', Decimal('21.38')),
#  ('Brazil', Decimal('54.27')),
#  ('British Virgin Islands', Decimal('0.07')),
#  ('Brunei Darussalam', Decimal('0.14')),
#  ('Burkina Faso', Decimal('4.77')),
#  ('Burundi', Decimal('0.43')),
#  ('Cabo Verde', Decimal('0.07')),
#  ('Cambodia', Decimal('4.57')),
#  ('Cameroon', Decimal('12.16')),
#  ('Canada', Decimal('95.62')),
#  ('Cayman Islands', Decimal('0.12')),
#  ('Central African Republic', Decimal('16.02')),
#  ('Chad', Decimal('32.38')),
#  ('Chile', Decimal('4.83')),
#  ('China', Decimal('83.06')),
#  ('Colombia', Decimal('7.20')),
#  ('Comoros', Decimal('0.03')),
#  ('Congo', Decimal('0.00')),
#  ('Cook Islands', Decimal('0.00')),
#  ('Costa Rica', Decimal('2.08')),
#  ("Côte d'Ivoire", Decimal('0.00')),
#  ('Cuba', Decimal('49.92')),
#  ('Curaçao', Decimal('0.00')),
#  ('Cyprus', Decimal('0.26')),
#  ("Democratic People's Republic of Korea", Decimal('0.00')),
#  ('Democratic Republic of the Congo', Decimal('0.00')),
#  ('Djibouti', Decimal('0.39')),
#  ('Dominica', Decimal('0.36')),
#  ('Dominican Republic', Decimal('23.21')),
#  ('Ecuador', Decimal('1.61')),
#  ('Egypt', Decimal('0.00')),
#  ('El Salvador', Decimal('0.84')),
#  ('Equatorial Guinea', Decimal('0.72')),
#  ('Eritrea', Decimal('2.04')),
#  ('Eswatini', Decimal('0.65')),
#  ('Ethiopia', Decimal('18.97')),
#  ('Falkland Islands (Malvinas)', Decimal('0.00')),
#  ('Fiji', Decimal('3.45')),
#  ('French Guiana', Decimal('0.00')),
#  ('French Polynesia', Decimal('48.09')),
#  ('Gabon', Decimal('6.63')),
#  ('Gambia', Decimal('0.00')),
#  ('Georgia', Decimal('1.99')),
#  ('Ghana', Decimal('3.97')),
#  ('Greenland', Decimal('4.38')),
#  ('Grenada', Decimal('0.16')),
#  ('Guadeloupe', Decimal('0.00')),
#  ('Guam', Decimal('21.86')),
#  ('Guatemala', Decimal('4.37')),
#  ('Guinea', Decimal('4.28')),
#  ('Guinea-Bissau', Decimal('0.49')),
#  ('Guyana', Decimal('1.28')),
#  ('Haiti', Decimal('13.24')),
#  ('Honduras', Decimal('4.56')),
#  ('India', Decimal('62.33')),
#  ('Indonesia', Decimal('48.57')),
#  ('Iran (Islamic Republic of)', Decimal('0.00')),
#  ('Iraq', Decimal('12.44')),
#  ('Israel', Decimal('0.62')),
#  ('Jamaica', Decimal('5.20')),
#  ('Japan', Decimal('3.21')),
#  ('Jordan', Decimal('2.55')),
#  ('Kazakhstan', Decimal('72.01')),
#  ('Kenya', Decimal('9.57')),
#  ('Kiribati', Decimal('32.79')),
#  ('Kuwait', Decimal('0.51')),
#  ('Kyrgyzstan', Decimal('0.00')),
#  ("Lao People's Democratic Republic", Decimal('0.00')),
#  ('Lebanon', Decimal('0.29')),
#  ('Lesotho', Decimal('1.15')),
#  ('Liberia', Decimal('1.68')),
#  ('Libya', Decimal('26.62')),
#  ('Madagascar', Decimal('9.78')),
#  ('Malawi', Decimal('1.58')),
#  ('Malaysia', Decimal('8.50')),
#  ('Maldives', Decimal('0.01')),
#  ('Mali', Decimal('21.27')),
#  ('Marshall Islands', Decimal('7.29')),
#  ('Martinique', Decimal('0.00')),
#  ('Mauritania', Decimal('17.97')),
#  ('Mauritius', Decimal('0.03')),
#  ('Mayotte', Decimal('0.00')),
#  ('Mexico', Decimal('79.28')),
#  ('Micronesia (Federated States of)', Decimal('0.00')),
#  ('Mongolia', Decimal('13.72')),
#  ('Montserrat', Decimal('0.00')),
#  ('Morocco', Decimal('6.75')),
#  ('Mozambique', Decimal('13.22')),
#  ('Myanmar', Decimal('16.89')),
#  ('Namibia', Decimal('31.06')),
#  ('Nauru', Decimal('0.81')),
#  ('Nepal', Decimal('3.01')),
#  ('New Caledonia', Decimal('3.45')),
#  ('New Zealand', Decimal('3.31')),
#  ('Nicaragua', Decimal('4.91')),
#  ('Niger', Decimal('22.09')),
#  ('Nigeria', Decimal('15.88')),
#  ('Niue', Decimal('0.00')),
#  ('Northern Mariana Islands', Decimal('18.62')),
#  ('Oman', Decimal('8.87')),
#  ('Pakistan', Decimal('16.16')),
#  ('Palau', Decimal('18.62')),
#  ('Panama', Decimal('3.02')),
#  ('Papua New Guinea', Decimal('85.51')),
#  ('Paraguay', Decimal('2.58')),
#  ('Peru', Decimal('8.31')),
#  ('Philippines', Decimal('7.71')),
#  ('Puerto Rico', Decimal('4.26')),
#  ('Qatar', Decimal('0.33')),
#  ('Republic of Korea', Decimal('0.00')),
#  ('Réunion', Decimal('0.00')),
#  ('Rwanda', Decimal('0.41')),
#  ('Saint Barthélemy', Decimal('0.00')),
#  ('Saint Helena', Decimal('0.00')),
#  ('Saint Kitts and Nevis', Decimal('0.00')),
#  ('Saint Lucia', Decimal('0.00')),
#  ('Saint Martin (French Part)', Decimal('0.00')),
#  ('Saint Pierre and Miquelon', Decimal('0.00')),
#  ('Saint Vincent and the Grenadines', Decimal('0.00')),
#  ('Samoa', Decimal('38.75')),
#  ('Sao Tome and Principe', Decimal('0.02')),
#  ('Saudi Arabia', Decimal('61.62')),
#  ('Senegal', Decimal('3.36')),
#  ('Seychelles', Decimal('0.01')),
#  ('Sierra Leone', Decimal('1.26')),
#  ('Singapore', Decimal('0.02')),
#  ('Sint Maarten (Dutch part)', Decimal('0.02')),
#  ('Solomon Islands', Decimal('5.29')),
#  ('Somalia', Decimal('10.55')),
#  ('South Africa', Decimal('45.77')),
#  ('South Sudan', Decimal('10.62')),
#  ('Sri Lanka', Decimal('1.30')),
#  ('State of Palestine', Decimal('0.00')),
#  ('Sudan', Decimal('28.26')),
#  ('Suriname', Decimal('1.01')),
#  ('Syrian Arab Republic', Decimal('5.26')),
#  ('Tajikistan', Decimal('3.70')),
#  ('Thailand', Decimal('13.22')),
#  ('Timor-Leste', Decimal('0.38')),
#  ('Togo', Decimal('0.95')),
#  ('Tokelau', Decimal('0.00')),
#  ('Tonga', Decimal('9.98')),
#  ('Trinidad and Tobago', Decimal('2.47')),
#  ('Tunisia', Decimal('2.35')),
#  ('Türkiye', Decimal('0.00')),
#  ('Turkmenistan', Decimal('12.53')),
#  ('Turks and Caicos Islands', Decimal('0.46')),
#  ('Tuvalu', Decimal('0.42')),
#  ('Uganda', Decimal('3.37')),
#  ('United Arab Emirates', Decimal('2.04')),
#  ('United Republic of Tanzania', Decimal('0.00')),
#  ('United States of America', Decimal('0.00')),
#  ('United States Virgin Islands', Decimal('0.00')),
#  ('Uruguay', Decimal('1.14')),
#  ('Uzbekistan', Decimal('11.75')),
#  ('Vanuatu', Decimal('2.30')),
#  ('Venezuela (Bolivarian Republic of)', Decimal('0.00')),
#  ('Viet Nam', Decimal('0.00')),
#  ('Wallis and Futuna Islands', Decimal('0.00')),
#  ('Yemen', Decimal('0.00')),
#  ('Zambia', Decimal('12.50')),
#  ('Zimbabwe', Decimal('6.50'))]

# %% [markdown]
# As SQL looks at the first row in **`g`**, the sub-region of the first row is **`g.sub-Region`**.
#
# So for the first row, the sub-region will be `Central and Southern Asia`. The inner query will then execute, filtering out the Central and Southern Asia data, and calculate the sum of the land area in Central and Southern Asia. The main query then uses that value to calculate the percentage. SQL then moves to the second row. This time, the sub-region is `Northern Africa and Western Asia`, which the subquery uses again, and passes back to the main query, and so on.

# %% [markdown]
# The downside of using correlated subqueries is that they can be quite inefficient. This is because the subquery may be evaluated once for each row processed by the outer query. For example, once we have calculated the total area for Middle Africa, the same calculation will be repeated for another row.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
