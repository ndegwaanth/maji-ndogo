# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Database views

# %% [markdown]
# A view is a virtual table that represents data derived from one or more base tables. It does not store data. It is basically a saved query that can be used as a table. Views allow you to simplify complex queries, abstract the underlying data structure, and provide some security by allowing access to specific columns or rows of data.
#
# In this lesson, we will construct a complex query and then create a view of that query.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# By the end of this lesson, you should know:
# - What a view is and why it's needed.
# - How to create a view.
# - How to join tables using views.
# - How to impute Null values using views.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in the `united_nations` database that we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace `password` with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://anthony:Sucess%4022@localhost:3306/united_nations

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line then add the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2015', Decimal('94.67'), Decimal('98.00'), Decimal('17.54'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2016', Decimal('94.67'), Decimal('98.00'), Decimal('17.79'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2017', Decimal('95.00'), Decimal('98.00'), Decimal('18.04'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2018', Decimal('95.00'), Decimal('98.00'), Decimal('18.28'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2019', Decimal('95.00'), Decimal('98.00'), Decimal('18.51'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %%
# %%sql
# select distinct region from Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 7 rows affected.
# [('Central and Southern Asia',),
#  ('Eastern and South-Eastern Asia',),
#  ('Europe and Northern America',),
#  ('Latin America and the Caribbean',),
#  ('Northern Africa and Western Asia',),
#  ('Oceania',),
#  ('Sub-Saharan Africa',)]

# %% [markdown]
# ## Exercise

# %% [markdown]
# We have decomposed the `united_nations.Access_to_Basic_Services` table into three tables. The `united_nations.Basic_Services` table, `united_nations.Economic_Indicators` table, and the `united_nations.Geographic_Locations` table. In this tutorial, we will be constructing a complex query to view the unemployment rate in Sub-Saharan Africa. We will then save that query as a VIEW.

# %%
# %%sql
# select * from economic_indicators limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Afghanistan', 2015, 20.0, 33.75, 0.0),
#  ('Afghanistan', 2016, 18.02, 34.64, 0.0),
#  ('Afghanistan', 2017, 18.9, 35.64, 11.18),
#  ('Afghanistan', 2018, 18.42, 36.69, 0.0),
#  ('Afghanistan', 2019, 18.9, 37.77, 0.0)]

# %%
# %%sql
# select * from geographic_location limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700')),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', Decimal('0'))]

# %% [markdown]
# ### Task 1
# To view the unemployment rate per region we will have to first join the `Economic_Indicators` table to the `Geographic_Locations` table.

# %%
# %%sql
# select
#     geo.Region,
#     geo.Country_name,
#     eco.Pct_unemployment
# from economic_indicators as eco
# join geographic_location as geo
#     on eco.Country_name = geo.Country_name
# limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Afghanistan', 0.0),
#  ('Central and Southern Asia', 'Afghanistan', 0.0),
#  ('Central and Southern Asia', 'Afghanistan', 11.18),
#  ('Central and Southern Asia', 'Afghanistan', 0.0),
#  ('Central and Southern Asia', 'Afghanistan', 0.0)]

# %% [markdown]
# ### Task 2
#
# After joining our tables, the query  now returns a table with the unemployment rate, country, and region. This allows us to filter for countries in Sub-Saharan Africa. So let's filter this table ensuring that we include Sub Sub-Saharan Africa only. Use the `WHERE` clause to filter our results for `Sub-Saharan Africa`. The table should include the following columns: `Country_name`, `Time_period`, and `Pct_unemployment`.

# %%
# %%sql
# select
#     geo.Country_name,
#     eco.Time_period,
#     eco.Pct_unemployment
# from economic_indicators as eco
# join geographic_location as geo
#     on eco.Country_name = geo.Country_name
# where geo.Region = 'Sub-Saharan Africa'
# limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Angola', 2015, 0.0),
#  ('Angola', 2016, 0.0),
#  ('Angola', 2017, 0.0),
#  ('Angola', 2018, 0.0),
#  ('Angola', 2019, 16.5)]

# %% [markdown]
# ### Task 3
#
# After filtering, we will notice that there are Null values in the `Pct_unemployment` column. Fill in the Null values with 33.65. Rename the imputed column, `Pct_unemployment_imputed`.

# %%
# %%sql
# select
#     geo.Country_name,
#     eco.Time_period,
#     IFNULL(eco.Pct_unemployment, 33.65) as Pct_unemployment_imputed
# from economic_indicators as eco
# join geographic_location as geo
#     on eco.Country_name = geo.Country_name
# where geo.Region = 'Sub-Saharan Africa'
# limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Angola', 2015, 0.0),
#  ('Angola', 2016, 0.0),
#  ('Angola', 2017, 0.0),
#  ('Angola', 2018, 0.0),
#  ('Angola', 2019, 16.5)]

# %% [markdown]
# ### Task 4
#
# Now that we have the query constructed, let's create a VIEW of that query. Name the VIEW, `united_nations.Country_Unemployment_Rate`.

# %%
# %%sql
# create view united_nations.Country_Unemployment_Rate AS
# select
#     geo.Country_name,
#     eco.Time_period,
#     IFNULL(eco.Pct_unemployment, 33.65) as Pct_unemployment_imputed
# from economic_indicators as eco
# join geographic_location as geo
#     on eco.Country_name = geo.Country_name
# where geo.Region = 'Sub-Saharan Africa'
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %% [markdown]
# ### Task 5
#
# Finally, let's have a look at the VIEW.

# %%
# %%sql
# select * from united_nations.Country_Unemployment_Rate limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Angola', 2015, 0.0),
#  ('Angola', 2016, 0.0),
#  ('Angola', 2017, 0.0),
#  ('Angola', 2018, 0.0),
#  ('Angola', 2019, 16.5)]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Task 1

# %%
# %%sql
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     eco.Pct_unemployment
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name;
#
# # Use LIMIT if you think the results set will be too large
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 1048 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ### Task 2

# %%
# %%sql
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     eco.Pct_unemployment
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name
# WHERE REGION = 'Sub-Saharan Africa';
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 297 rows affected.
# [('Angola', 2015, 0.0),
#  ('Angola', 2016, 0.0),
#  ('Angola', 2017, 0.0),
#  ('Angola', 2018, 0.0),
#  ('Angola', 2019, 16.5),
#  ('Angola', 2020, 0.0),
#  ('Benin', 2015, 0.0),
#  ('Benin', 2016, 0.0),
#  ('Benin', 2017, 0.0),
#  ('Benin', 2018, 1.47),
#  ('Benin', 2019, 0.0),
#  ('Benin', 2020, 0.0),
#  ('Botswana', 2015, 0.0),
#  ('Botswana', 2016, 0.0),
#  ('Botswana', 2017, 0.0),
#  ('Botswana', 2018, 0.0),
#  ('Botswana', 2019, 20.09),
#  ('Botswana', 2020, 21.02),
#  ('Burkina Faso', 2015, 0.0),
#  ('Burkina Faso', 2016, 0.0),
#  ('Burkina Faso', 2017, 0.0),
#  ('Burkina Faso', 2018, 4.69),
#  ('Burkina Faso', 2019, 0.0),
#  ('Burkina Faso', 2020, 0.0),
#  ('Burundi', 2015, 0.0),
#  ('Burundi', 2016, 0.0),
#  ('Burundi', 2017, 0.0),
#  ('Burundi', 2018, 0.0),
#  ('Burundi', 2019, 0.0),
#  ('Burundi', 2020, 1.03),
#  ('Cabo Verde', 2015, 31.31),
#  ('Cabo Verde', 2016, 0.0),
#  ('Cabo Verde', 2017, 12.24),
#  ('Cabo Verde', 2018, 12.17),
#  ('Cabo Verde', 2019, 11.29),
#  ('Cabo Verde', 2020, 0.0),
#  ('Cameroon', 2015, 0.0),
#  ('Cameroon', 2016, 0.0),
#  ('Cameroon', 2017, 0.0),
#  ('Cameroon', 2018, 0.0),
#  ('Cameroon', 2019, 0.0),
#  ('Cameroon', 2020, 0.0),
#  ('Central African Republic', 2015, 0.0),
#  ('Central African Republic', 2016, 0.0),
#  ('Central African Republic', 2017, 0.0),
#  ('Central African Republic', 2018, 0.0),
#  ('Central African Republic', 2019, 0.0),
#  ('Central African Republic', 2020, 0.0),
#  ('Chad', 2015, 0.0),
#  ('Chad', 2016, 0.0),
#  ('Chad', 2017, 0.0),
#  ('Chad', 2018, 1.13),
#  ('Chad', 2019, 0.0),
#  ('Chad', 2020, 0.0),
#  ('Comoros', 2015, 0.0),
#  ('Comoros', 2016, 0.0),
#  ('Comoros', 2017, 0.0),
#  ('Comoros', 2018, 0.0),
#  ('Comoros', 2019, 0.0),
#  ('Congo', 2015, 0.0),
#  ('Congo', 2016, 0.0),
#  ('Congo', 2017, 0.0),
#  ('Congo', 2018, 0.0),
#  ('Congo', 2019, 0.0),
#  ('Congo', 2020, 0.0),
#  ("Côte d'Ivoire", 2015, 0.0),
#  ("Côte d'Ivoire", 2016, 0.0),
#  ("Côte d'Ivoire", 2017, 0.0),
#  ("Côte d'Ivoire", 2018, 0.0),
#  ("Côte d'Ivoire", 2019, 0.0),
#  ("Côte d'Ivoire", 2020, 0.0),
#  ('Democratic Republic of the Congo', 2015, 0.0),
#  ('Democratic Republic of the Congo', 2016, 0.0),
#  ('Democratic Republic of the Congo', 2017, 0.0),
#  ('Democratic Republic of the Congo', 2018, 0.0),
#  ('Democratic Republic of the Congo', 2019, 0.0),
#  ('Democratic Republic of the Congo', 2020, 0.0),
#  ('Djibouti', 2015, 0.0),
#  ('Djibouti', 2016, 0.0),
#  ('Djibouti', 2017, 26.06),
#  ('Djibouti', 2018, 0.0),
#  ('Djibouti', 2019, 0.0),
#  ('Djibouti', 2020, 0.0),
#  ('Equatorial Guinea', 2015, 0.0),
#  ('Equatorial Guinea', 2016, 0.0),
#  ('Equatorial Guinea', 2017, 0.0),
#  ('Eritrea', 2015, 0.0),
#  ('Eritrea', 2016, 0.0),
#  ('Eswatini', 2015, 0.0),
#  ('Eswatini', 2016, 22.72),
#  ('Eswatini', 2017, 0.0),
#  ('Eswatini', 2018, 0.0),
#  ('Eswatini', 2019, 0.0),
#  ('Eswatini', 2020, 0.0),
#  ('Ethiopia', 2015, 0.0),
#  ('Ethiopia', 2016, 0.0),
#  ('Ethiopia', 2017, 0.0),
#  ('Ethiopia', 2018, 0.0),
#  ('Ethiopia', 2019, 0.0),
#  ('Ethiopia', 2020, 0.0),
#  ('Gabon', 2015, 0.0),
#  ('Gabon', 2016, 0.0),
#  ('Gabon', 2017, 0.0),
#  ('Gabon', 2018, 0.0),
#  ('Gabon', 2019, 0.0),
#  ('Gabon', 2020, 0.0),
#  ('Gambia', 2015, 0.0),
#  ('Gambia', 2016, 0.0),
#  ('Gambia', 2017, 0.0),
#  ('Gambia', 2018, 0.0),
#  ('Gambia', 2019, 0.0),
#  ('Gambia', 2020, 0.0),
#  ('Ghana', 2015, 6.81),
#  ('Ghana', 2016, 0.0),
#  ('Ghana', 2017, 3.37),
#  ('Ghana', 2018, 0.0),
#  ('Ghana', 2019, 0.0),
#  ('Ghana', 2020, 0.0),
#  ('Guinea', 2015, 0.0),
#  ('Guinea', 2016, 0.0),
#  ('Guinea', 2017, 0.0),
#  ('Guinea', 2018, 0.0),
#  ('Guinea', 2019, 5.02),
#  ('Guinea', 2020, 0.0),
#  ('Guinea-Bissau', 2015, 0.0),
#  ('Guinea-Bissau', 2016, 0.0),
#  ('Guinea-Bissau', 2017, 0.0),
#  ('Guinea-Bissau', 2018, 3.2),
#  ('Guinea-Bissau', 2019, 0.0),
#  ('Guinea-Bissau', 2020, 0.0),
#  ('Kenya', 2015, 0.0),
#  ('Kenya', 2016, 2.76),
#  ('Kenya', 2017, 0.0),
#  ('Kenya', 2018, 0.0),
#  ('Kenya', 2019, 5.01),
#  ('Kenya', 2020, 0.0),
#  ('Lesotho', 2015, 0.0),
#  ('Lesotho', 2016, 0.0),
#  ('Lesotho', 2017, 0.0),
#  ('Lesotho', 2018, 0.0),
#  ('Lesotho', 2019, 16.88),
#  ('Lesotho', 2020, 0.0),
#  ('Liberia', 2015, 0.0),
#  ('Liberia', 2016, 3.08),
#  ('Liberia', 2017, 5.95),
#  ('Liberia', 2018, 0.0),
#  ('Liberia', 2019, 0.0),
#  ('Liberia', 2020, 0.0),
#  ('Madagascar', 2015, 1.79),
#  ('Madagascar', 2016, 0.0),
#  ('Madagascar', 2017, 0.0),
#  ('Madagascar', 2018, 0.0),
#  ('Madagascar', 2019, 0.0),
#  ('Madagascar', 2020, 0.0),
#  ('Malawi', 2015, 0.0),
#  ('Malawi', 2016, 0.0),
#  ('Malawi', 2017, 3.54),
#  ('Malawi', 2018, 0.0),
#  ('Malawi', 2019, 0.0),
#  ('Malawi', 2020, 0.91),
#  ('Mali', 2015, 7.73),
#  ('Mali', 2016, 1.37),
#  ('Mali', 2017, 7.41),
#  ('Mali', 2018, 1.62),
#  ('Mali', 2019, 0.0),
#  ('Mali', 2020, 3.53),
#  ('Mauritania', 2015, 0.0),
#  ('Mauritania', 2016, 0.0),
#  ('Mauritania', 2017, 10.34),
#  ('Mauritania', 2018, 0.0),
#  ('Mauritania', 2019, 10.42),
#  ('Mauritania', 2020, 0.0),
#  ('Mauritius', 2015, 7.41),
#  ('Mauritius', 2016, 6.81),
#  ('Mauritius', 2017, 6.75),
#  ('Mauritius', 2018, 6.43),
#  ('Mauritius', 2019, 6.33),
#  ('Mauritius', 2020, 8.63),
#  ('Mayotte', 2015, 0.0),
#  ('Mayotte', 2016, 0.0),
#  ('Mayotte', 2017, 0.0),
#  ('Mayotte', 2018, 0.0),
#  ('Mayotte', 2019, 0.0),
#  ('Mayotte', 2020, 0.0),
#  ('Mozambique', 2015, 3.43),
#  ('Mozambique', 2016, 0.0),
#  ('Mozambique', 2017, 0.0),
#  ('Mozambique', 2018, 0.0),
#  ('Mozambique', 2019, 0.0),
#  ('Mozambique', 2020, 0.0),
#  ('Namibia', 2015, 0.0),
#  ('Namibia', 2016, 23.35),
#  ('Namibia', 2017, 0.0),
#  ('Namibia', 2018, 19.88),
#  ('Namibia', 2019, 0.0),
#  ('Namibia', 2020, 0.0),
#  ('Niger', 2015, 0.0),
#  ('Niger', 2016, 0.0),
#  ('Niger', 2017, 7.77),
#  ('Niger', 2018, 0.0),
#  ('Niger', 2019, 0.0),
#  ('Niger', 2020, 0.0),
#  ('Nigeria', 2015, 4.31),
#  ('Nigeria', 2016, 7.06),
#  ('Nigeria', 2017, 8.39),
#  ('Nigeria', 2018, 0.0),
#  ('Nigeria', 2019, 10.7),
#  ('Nigeria', 2020, 0.0),
#  ('Réunion', 2015, 0.0),
#  ('Réunion', 2016, 0.0),
#  ('Réunion', 2017, 0.0),
#  ('Réunion', 2018, 0.0),
#  ('Réunion', 2019, 0.0),
#  ('Réunion', 2020, 0.0),
#  ('Rwanda', 2015, 0.0),
#  ('Rwanda', 2016, 0.0),
#  ('Rwanda', 2017, 11.88),
#  ('Rwanda', 2018, 10.76),
#  ('Rwanda', 2019, 11.24),
#  ('Rwanda', 2020, 11.83),
#  ('Saint Helena', 2015, 0.0),
#  ('Saint Helena', 2016, 0.0),
#  ('Saint Helena', 2017, 0.0),
#  ('Saint Helena', 2018, 0.0),
#  ('Saint Helena', 2019, 0.0),
#  ('Saint Helena', 2020, 0.0),
#  ('Sao Tome and Principe', 2015, 0.0),
#  ('Sao Tome and Principe', 2016, 0.0),
#  ('Sao Tome and Principe', 2017, 0.0),
#  ('Sao Tome and Principe', 2018, 0.0),
#  ('Sao Tome and Principe', 2019, 0.0),
#  ('Sao Tome and Principe', 2020, 0.0),
#  ('Senegal', 2015, 6.76),
#  ('Senegal', 2016, 4.46),
#  ('Senegal', 2017, 4.08),
#  ('Senegal', 2018, 3.57),
#  ('Senegal', 2019, 2.86),
#  ('Senegal', 2020, 0.0),
#  ('Seychelles', 2015, 4.15),
#  ('Seychelles', 2016, 3.96),
#  ('Seychelles', 2017, 3.71),
#  ('Seychelles', 2018, 3.53),
#  ('Seychelles', 2019, 2.97),
#  ('Sierra Leone', 2015, 0.0),
#  ('Sierra Leone', 2016, 0.0),
#  ('Sierra Leone', 2017, 0.0),
#  ('Sierra Leone', 2018, 3.19),
#  ('Sierra Leone', 2019, 0.0),
#  ('Sierra Leone', 2020, 0.0),
#  ('Somalia', 2015, 0.0),
#  ('Somalia', 2016, 0.0),
#  ('Somalia', 2017, 0.0),
#  ('Somalia', 2018, 0.0),
#  ('Somalia', 2019, 18.83),
#  ('Somalia', 2020, 0.0),
#  ('South Africa', 2015, 22.87),
#  ('South Africa', 2016, 24.02),
#  ('South Africa', 2017, 23.99),
#  ('South Africa', 2018, 24.22),
#  ('South Africa', 2019, 25.54),
#  ('South Africa', 2020, 24.34),
#  ('South Sudan', 2015, 0.0),
#  ('South Sudan', 2016, 0.0),
#  ('South Sudan', 2017, 0.0),
#  ('South Sudan', 2018, 0.0),
#  ('South Sudan', 2019, 0.0),
#  ('South Sudan', 2020, 0.0),
#  ('Togo', 2015, 2.2),
#  ('Togo', 2016, 0.0),
#  ('Togo', 2017, 3.74),
#  ('Togo', 2018, 0.0),
#  ('Togo', 2019, 0.0),
#  ('Togo', 2020, 0.0),
#  ('Uganda', 2015, 0.0),
#  ('Uganda', 2016, 0.0),
#  ('Uganda', 2017, 3.64),
#  ('Uganda', 2018, 0.0),
#  ('Uganda', 2019, 0.0),
#  ('Uganda', 2020, 0.0),
#  ('United Republic of Tanzania', 2015, 0.0),
#  ('United Republic of Tanzania', 2016, 0.0),
#  ('United Republic of Tanzania', 2017, 0.0),
#  ('United Republic of Tanzania', 2018, 0.0),
#  ('United Republic of Tanzania', 2019, 0.0),
#  ('United Republic of Tanzania', 2020, 0.0),
#  ('Zambia', 2015, 0.0),
#  ('Zambia', 2016, 0.0),
#  ('Zambia', 2017, 8.52),
#  ('Zambia', 2018, 5.03),
#  ('Zambia', 2019, 5.54),
#  ('Zambia', 2020, 6.03),
#  ('Zimbabwe', 2015, 0.0),
#  ('Zimbabwe', 2016, 0.0),
#  ('Zimbabwe', 2017, 0.0),
#  ('Zimbabwe', 2018, 0.0),
#  ('Zimbabwe', 2019, 7.37),
#  ('Zimbabwe', 2020, 0.0)]

# %% [markdown]
# ### Task 3

# %%
# %%sql
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     IFNULL (eco.Pct_unemployment,33.65) as Pct_unemployment_imputed
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name
# WHERE REGION = 'Sub-Saharan Africa';
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 297 rows affected.
# [('Angola', 2015, 0.0),
#  ('Angola', 2016, 0.0),
#  ('Angola', 2017, 0.0),
#  ('Angola', 2018, 0.0),
#  ('Angola', 2019, 16.5),
#  ('Angola', 2020, 0.0),
#  ('Benin', 2015, 0.0),
#  ('Benin', 2016, 0.0),
#  ('Benin', 2017, 0.0),
#  ('Benin', 2018, 1.4700000286102295),
#  ('Benin', 2019, 0.0),
#  ('Benin', 2020, 0.0),
#  ('Botswana', 2015, 0.0),
#  ('Botswana', 2016, 0.0),
#  ('Botswana', 2017, 0.0),
#  ('Botswana', 2018, 0.0),
#  ('Botswana', 2019, 20.09000015258789),
#  ('Botswana', 2020, 21.020000457763672),
#  ('Burkina Faso', 2015, 0.0),
#  ('Burkina Faso', 2016, 0.0),
#  ('Burkina Faso', 2017, 0.0),
#  ('Burkina Faso', 2018, 4.690000057220459),
#  ('Burkina Faso', 2019, 0.0),
#  ('Burkina Faso', 2020, 0.0),
#  ('Burundi', 2015, 0.0),
#  ('Burundi', 2016, 0.0),
#  ('Burundi', 2017, 0.0),
#  ('Burundi', 2018, 0.0),
#  ('Burundi', 2019, 0.0),
#  ('Burundi', 2020, 1.0299999713897705),
#  ('Cabo Verde', 2015, 31.309999465942383),
#  ('Cabo Verde', 2016, 0.0),
#  ('Cabo Verde', 2017, 12.239999771118164),
#  ('Cabo Verde', 2018, 12.170000076293945),
#  ('Cabo Verde', 2019, 11.289999961853027),
#  ('Cabo Verde', 2020, 0.0),
#  ('Cameroon', 2015, 0.0),
#  ('Cameroon', 2016, 0.0),
#  ('Cameroon', 2017, 0.0),
#  ('Cameroon', 2018, 0.0),
#  ('Cameroon', 2019, 0.0),
#  ('Cameroon', 2020, 0.0),
#  ('Central African Republic', 2015, 0.0),
#  ('Central African Republic', 2016, 0.0),
#  ('Central African Republic', 2017, 0.0),
#  ('Central African Republic', 2018, 0.0),
#  ('Central African Republic', 2019, 0.0),
#  ('Central African Republic', 2020, 0.0),
#  ('Chad', 2015, 0.0),
#  ('Chad', 2016, 0.0),
#  ('Chad', 2017, 0.0),
#  ('Chad', 2018, 1.1299999952316284),
#  ('Chad', 2019, 0.0),
#  ('Chad', 2020, 0.0),
#  ('Comoros', 2015, 0.0),
#  ('Comoros', 2016, 0.0),
#  ('Comoros', 2017, 0.0),
#  ('Comoros', 2018, 0.0),
#  ('Comoros', 2019, 0.0),
#  ('Congo', 2015, 0.0),
#  ('Congo', 2016, 0.0),
#  ('Congo', 2017, 0.0),
#  ('Congo', 2018, 0.0),
#  ('Congo', 2019, 0.0),
#  ('Congo', 2020, 0.0),
#  ("Côte d'Ivoire", 2015, 0.0),
#  ("Côte d'Ivoire", 2016, 0.0),
#  ("Côte d'Ivoire", 2017, 0.0),
#  ("Côte d'Ivoire", 2018, 0.0),
#  ("Côte d'Ivoire", 2019, 0.0),
#  ("Côte d'Ivoire", 2020, 0.0),
#  ('Democratic Republic of the Congo', 2015, 0.0),
#  ('Democratic Republic of the Congo', 2016, 0.0),
#  ('Democratic Republic of the Congo', 2017, 0.0),
#  ('Democratic Republic of the Congo', 2018, 0.0),
#  ('Democratic Republic of the Congo', 2019, 0.0),
#  ('Democratic Republic of the Congo', 2020, 0.0),
#  ('Djibouti', 2015, 0.0),
#  ('Djibouti', 2016, 0.0),
#  ('Djibouti', 2017, 26.059999465942383),
#  ('Djibouti', 2018, 0.0),
#  ('Djibouti', 2019, 0.0),
#  ('Djibouti', 2020, 0.0),
#  ('Equatorial Guinea', 2015, 0.0),
#  ('Equatorial Guinea', 2016, 0.0),
#  ('Equatorial Guinea', 2017, 0.0),
#  ('Eritrea', 2015, 0.0),
#  ('Eritrea', 2016, 0.0),
#  ('Eswatini', 2015, 0.0),
#  ('Eswatini', 2016, 22.719999313354492),
#  ('Eswatini', 2017, 0.0),
#  ('Eswatini', 2018, 0.0),
#  ('Eswatini', 2019, 0.0),
#  ('Eswatini', 2020, 0.0),
#  ('Ethiopia', 2015, 0.0),
#  ('Ethiopia', 2016, 0.0),
#  ('Ethiopia', 2017, 0.0),
#  ('Ethiopia', 2018, 0.0),
#  ('Ethiopia', 2019, 0.0),
#  ('Ethiopia', 2020, 0.0),
#  ('Gabon', 2015, 0.0),
#  ('Gabon', 2016, 0.0),
#  ('Gabon', 2017, 0.0),
#  ('Gabon', 2018, 0.0),
#  ('Gabon', 2019, 0.0),
#  ('Gabon', 2020, 0.0),
#  ('Gambia', 2015, 0.0),
#  ('Gambia', 2016, 0.0),
#  ('Gambia', 2017, 0.0),
#  ('Gambia', 2018, 0.0),
#  ('Gambia', 2019, 0.0),
#  ('Gambia', 2020, 0.0),
#  ('Ghana', 2015, 6.809999942779541),
#  ('Ghana', 2016, 0.0),
#  ('Ghana', 2017, 3.369999885559082),
#  ('Ghana', 2018, 0.0),
#  ('Ghana', 2019, 0.0),
#  ('Ghana', 2020, 0.0),
#  ('Guinea', 2015, 0.0),
#  ('Guinea', 2016, 0.0),
#  ('Guinea', 2017, 0.0),
#  ('Guinea', 2018, 0.0),
#  ('Guinea', 2019, 5.019999980926514),
#  ('Guinea', 2020, 0.0),
#  ('Guinea-Bissau', 2015, 0.0),
#  ('Guinea-Bissau', 2016, 0.0),
#  ('Guinea-Bissau', 2017, 0.0),
#  ('Guinea-Bissau', 2018, 3.200000047683716),
#  ('Guinea-Bissau', 2019, 0.0),
#  ('Guinea-Bissau', 2020, 0.0),
#  ('Kenya', 2015, 0.0),
#  ('Kenya', 2016, 2.759999990463257),
#  ('Kenya', 2017, 0.0),
#  ('Kenya', 2018, 0.0),
#  ('Kenya', 2019, 5.010000228881836),
#  ('Kenya', 2020, 0.0),
#  ('Lesotho', 2015, 0.0),
#  ('Lesotho', 2016, 0.0),
#  ('Lesotho', 2017, 0.0),
#  ('Lesotho', 2018, 0.0),
#  ('Lesotho', 2019, 16.8799991607666),
#  ('Lesotho', 2020, 0.0),
#  ('Liberia', 2015, 0.0),
#  ('Liberia', 2016, 3.0799999237060547),
#  ('Liberia', 2017, 5.949999809265137),
#  ('Liberia', 2018, 0.0),
#  ('Liberia', 2019, 0.0),
#  ('Liberia', 2020, 0.0),
#  ('Madagascar', 2015, 1.7899999618530273),
#  ('Madagascar', 2016, 0.0),
#  ('Madagascar', 2017, 0.0),
#  ('Madagascar', 2018, 0.0),
#  ('Madagascar', 2019, 0.0),
#  ('Madagascar', 2020, 0.0),
#  ('Malawi', 2015, 0.0),
#  ('Malawi', 2016, 0.0),
#  ('Malawi', 2017, 3.5399999618530273),
#  ('Malawi', 2018, 0.0),
#  ('Malawi', 2019, 0.0),
#  ('Malawi', 2020, 0.9100000262260437),
#  ('Mali', 2015, 7.730000019073486),
#  ('Mali', 2016, 1.3700000047683716),
#  ('Mali', 2017, 7.409999847412109),
#  ('Mali', 2018, 1.6200000047683716),
#  ('Mali', 2019, 0.0),
#  ('Mali', 2020, 3.5299999713897705),
#  ('Mauritania', 2015, 0.0),
#  ('Mauritania', 2016, 0.0),
#  ('Mauritania', 2017, 10.34000015258789),
#  ('Mauritania', 2018, 0.0),
#  ('Mauritania', 2019, 10.420000076293945),
#  ('Mauritania', 2020, 0.0),
#  ('Mauritius', 2015, 7.409999847412109),
#  ('Mauritius', 2016, 6.809999942779541),
#  ('Mauritius', 2017, 6.75),
#  ('Mauritius', 2018, 6.429999828338623),
#  ('Mauritius', 2019, 6.329999923706055),
#  ('Mauritius', 2020, 8.630000114440918),
#  ('Mayotte', 2015, 0.0),
#  ('Mayotte', 2016, 0.0),
#  ('Mayotte', 2017, 0.0),
#  ('Mayotte', 2018, 0.0),
#  ('Mayotte', 2019, 0.0),
#  ('Mayotte', 2020, 0.0),
#  ('Mozambique', 2015, 3.430000066757202),
#  ('Mozambique', 2016, 0.0),
#  ('Mozambique', 2017, 0.0),
#  ('Mozambique', 2018, 0.0),
#  ('Mozambique', 2019, 0.0),
#  ('Mozambique', 2020, 0.0),
#  ('Namibia', 2015, 0.0),
#  ('Namibia', 2016, 23.350000381469727),
#  ('Namibia', 2017, 0.0),
#  ('Namibia', 2018, 19.8799991607666),
#  ('Namibia', 2019, 0.0),
#  ('Namibia', 2020, 0.0),
#  ('Niger', 2015, 0.0),
#  ('Niger', 2016, 0.0),
#  ('Niger', 2017, 7.769999980926514),
#  ('Niger', 2018, 0.0),
#  ('Niger', 2019, 0.0),
#  ('Niger', 2020, 0.0),
#  ('Nigeria', 2015, 4.309999942779541),
#  ('Nigeria', 2016, 7.059999942779541),
#  ('Nigeria', 2017, 8.390000343322754),
#  ('Nigeria', 2018, 0.0),
#  ('Nigeria', 2019, 10.699999809265137),
#  ('Nigeria', 2020, 0.0),
#  ('Réunion', 2015, 0.0),
#  ('Réunion', 2016, 0.0),
#  ('Réunion', 2017, 0.0),
#  ('Réunion', 2018, 0.0),
#  ('Réunion', 2019, 0.0),
#  ('Réunion', 2020, 0.0),
#  ('Rwanda', 2015, 0.0),
#  ('Rwanda', 2016, 0.0),
#  ('Rwanda', 2017, 11.880000114440918),
#  ('Rwanda', 2018, 10.760000228881836),
#  ('Rwanda', 2019, 11.239999771118164),
#  ('Rwanda', 2020, 11.829999923706055),
#  ('Saint Helena', 2015, 0.0),
#  ('Saint Helena', 2016, 0.0),
#  ('Saint Helena', 2017, 0.0),
#  ('Saint Helena', 2018, 0.0),
#  ('Saint Helena', 2019, 0.0),
#  ('Saint Helena', 2020, 0.0),
#  ('Sao Tome and Principe', 2015, 0.0),
#  ('Sao Tome and Principe', 2016, 0.0),
#  ('Sao Tome and Principe', 2017, 0.0),
#  ('Sao Tome and Principe', 2018, 0.0),
#  ('Sao Tome and Principe', 2019, 0.0),
#  ('Sao Tome and Principe', 2020, 0.0),
#  ('Senegal', 2015, 6.760000228881836),
#  ('Senegal', 2016, 4.460000038146973),
#  ('Senegal', 2017, 4.079999923706055),
#  ('Senegal', 2018, 3.569999933242798),
#  ('Senegal', 2019, 2.859999895095825),
#  ('Senegal', 2020, 0.0),
#  ('Seychelles', 2015, 4.150000095367432),
#  ('Seychelles', 2016, 3.9600000381469727),
#  ('Seychelles', 2017, 3.7100000381469727),
#  ('Seychelles', 2018, 3.5299999713897705),
#  ('Seychelles', 2019, 2.9700000286102295),
#  ('Sierra Leone', 2015, 0.0),
#  ('Sierra Leone', 2016, 0.0),
#  ('Sierra Leone', 2017, 0.0),
#  ('Sierra Leone', 2018, 3.190000057220459),
#  ('Sierra Leone', 2019, 0.0),
#  ('Sierra Leone', 2020, 0.0),
#  ('Somalia', 2015, 0.0),
#  ('Somalia', 2016, 0.0),
#  ('Somalia', 2017, 0.0),
#  ('Somalia', 2018, 0.0),
#  ('Somalia', 2019, 18.829999923706055),
#  ('Somalia', 2020, 0.0),
#  ('South Africa', 2015, 22.8700008392334),
#  ('South Africa', 2016, 24.020000457763672),
#  ('South Africa', 2017, 23.989999771118164),
#  ('South Africa', 2018, 24.219999313354492),
#  ('South Africa', 2019, 25.540000915527344),
#  ('South Africa', 2020, 24.34000015258789),
#  ('South Sudan', 2015, 0.0),
#  ('South Sudan', 2016, 0.0),
#  ('South Sudan', 2017, 0.0),
#  ('South Sudan', 2018, 0.0),
#  ('South Sudan', 2019, 0.0),
#  ('South Sudan', 2020, 0.0),
#  ('Togo', 2015, 2.200000047683716),
#  ('Togo', 2016, 0.0),
#  ('Togo', 2017, 3.740000009536743),
#  ('Togo', 2018, 0.0),
#  ('Togo', 2019, 0.0),
#  ('Togo', 2020, 0.0),
#  ('Uganda', 2015, 0.0),
#  ('Uganda', 2016, 0.0),
#  ('Uganda', 2017, 3.640000104904175),
#  ('Uganda', 2018, 0.0),
#  ('Uganda', 2019, 0.0),
#  ('Uganda', 2020, 0.0),
#  ('United Republic of Tanzania', 2015, 0.0),
#  ('United Republic of Tanzania', 2016, 0.0),
#  ('United Republic of Tanzania', 2017, 0.0),
#  ('United Republic of Tanzania', 2018, 0.0),
#  ('United Republic of Tanzania', 2019, 0.0),
#  ('United Republic of Tanzania', 2020, 0.0),
#  ('Zambia', 2015, 0.0),
#  ('Zambia', 2016, 0.0),
#  ('Zambia', 2017, 8.520000457763672),
#  ('Zambia', 2018, 5.03000020980835),
#  ('Zambia', 2019, 5.539999961853027),
#  ('Zambia', 2020, 6.03000020980835),
#  ('Zimbabwe', 2015, 0.0),
#  ('Zimbabwe', 2016, 0.0),
#  ('Zimbabwe', 2017, 0.0),
#  ('Zimbabwe', 2018, 0.0),
#  ('Zimbabwe', 2019, 7.369999885559082),
#  ('Zimbabwe', 2020, 0.0)]

# %% [markdown]
# ### Task 4

# %%
# %%sql
#
# CREATE VIEW united_nations.Country_Unemployment_Rate
# AS
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     IFNULL (eco.Pct_unemployment,33.65) as PCT_unemployment_imputed
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name
# WHERE REGION = 'Sub-Saharan Africa';

# %% [markdown]
# ### Task 5

# %%
# %%sql
#
# SELECT *
# FROM
#     united_nations.Country_unemployment_Rate
# LIMIT 10;

# %% [markdown]
# ## Summary

# %% [markdown]
# In this notebook, we created a join with the `Economic_Indicators` table and the `Geographical_Locations` table. This allowed us to filter our data by `Region`, specifically the `Sub-Saharan African` region. We then imputed the Null values in the `Pct_unemployment` column. Finally, we saved this complex query in a VIEW and named that VIEW `united_nations.Country_unemployment_Rate`.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
