# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# # clier - server connection

# %%
# %%sql
# mysql+pymysql://anthony:Sucess%4022@localhost:3306/united_nations

# %%
# %%sql
# SELECT CURRENT_DATE();
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 1 rows affected.
# [(datetime.date(2026, 2, 26),)]

# %%
# %%sql
# SHOW DATABASES;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 9 rows affected.
# [('information_schema',),
#  ('jobnix',),
#  ('md_water_services',),
#  ('mysql',),
#  ('performance_schema',),
#  ('poultry_users',),
#  ('sys',),
#  ('testing',),
#  ('united_nations',)]

# %%
# %%sql
# use united_nations;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 7 rows affected.
# [('access_to_basic_services',),
#  ('access_to_water',),
#  ('employees',),
#  ('location',),
#  ('no_duplicates_access_to_basic_services',),
#  ('regions',),
#  ('water_basic_services',)]

# %% [markdown]
# # 1. exploring the database

# %%
# %%sql
# select * from access_to_basic_services limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2015', Decimal('94.67'), Decimal('98.00'), Decimal('17.54'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2016', Decimal('94.67'), Decimal('98.00'), Decimal('17.79'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2017', Decimal('95.00'), Decimal('98.00'), Decimal('18.04'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2018', Decimal('95.00'), Decimal('98.00'), Decimal('18.28'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
# ...

# %% [markdown]
# # 2. Unique Country name

# %%
# %%sql
# select distinct country_name
# from access_to_basic_services;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 182 rows affected.
# [('Kazakhstan',),
#  ('Kyrgyzstan',),
#  ('Tajikistan',),
#  ('Turkmenistan',),
#  ('Uzbekistan',),
#  ('Afghanistan',),
#  ('Bangladesh',),
#  ('Bhutan',),
#  ('India',),
#  ('Iran (Islamic Republic of)',),
#  ('Maldives',),
#  ('Nepal',),
#  ('Pakistan',),
#  ('Sri Lanka',),
#  ('China',),
#  ("Democratic People's Republic of Korea",),
#  ('Japan',),
#  ('Mongolia',),
#  ('Republic of Korea',),
#  ('Brunei Darussalam',),
#  ('Cambodia',),
#  ('Indonesia',),
#  ("Lao People's Democratic Republic",),
#  ('Malaysia',),
#  ('Myanmar',),
#  ('Philippines',),
#  ('Singapore',),
#  ('Thailand',),
#  ('Timor-Leste',),
#  ('Viet Nam',),
#  ('Bermuda',),
#  ('Canada',),
#  ('Greenland',),
#  ('Saint Pierre and Miquelon',),
#  ('United States of America',),
#  ('Anguilla',),
#  ('Antigua and Barbuda',),
#  ('Aruba',),
#  ('Bahamas',),
#  ('Barbados',),
#  ('British Virgin Islands',),
#  ('Cayman Islands',),
# ...

# %%
# %%sql
# -- insert the country names into the country table
# create table country_list (
#     country varchar(255)
# )
#
# select distinct country_name
# from access_to_basic_services;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 182 rows affected.
# []

# %%
# %%sql
# select * from country_list limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Kazakhstan',),
#  ('Kyrgyzstan',),
#  ('Tajikistan',),
#  ('Turkmenistan',),
#  ('Uzbekistan',)]

# %% [markdown]
# # 3. selecting specifice field

# %%
# %%sql
# select Region, Country_name, Pct_managed_drinking_water_services AS pct_access_to_water, Time_period
# from access_to_basic_services
# where Pct_managed_drinking_water_services > 50
# order by Pct_managed_drinking_water_services desc
# limit 20;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 20 rows affected.
# [('Eastern and South-Eastern Asia', 'Singapore', Decimal('100.00'), '2016'),
#  ('Eastern and South-Eastern Asia', 'Brunei Darussalam', Decimal('100.00'), '2017'),
#  ('Eastern and South-Eastern Asia', 'Brunei Darussalam', Decimal('100.00'), '2020'),
#  ('Eastern and South-Eastern Asia', 'Singapore', Decimal('100.00'), '2019'),
#  ('Eastern and South-Eastern Asia', 'Brunei Darussalam', Decimal('100.00'), '2016'),
#  ('Eastern and South-Eastern Asia', 'Singapore', Decimal('100.00'), '2017'),
#  ('Eastern and South-Eastern Asia', 'Republic of Korea', Decimal('100.00'), '2018'),
#  ('Eastern and South-Eastern Asia', 'Republic of Korea', Decimal('100.00'), '2016'),
#  ('Eastern and South-Eastern Asia', 'Singapore', Decimal('100.00'), '2018'),
#  ('Eastern and South-Eastern Asia', 'Thailand', Decimal('100.00'), '2018'),
#  ('Eastern and South-Eastern Asia', 'Brunei Darussalam', Decimal('100.00'), '2018'),
# ...

# %% [markdown]
# # 4. Filtering and sorting

# %%
# %%sql
# select Region, Country_name, Pct_managed_drinking_water_services AS pct_access_to_water, Time_period
# from access_to_basic_services
# where Pct_managed_drinking_water_services > 50 and Time_period = 2020
# order by Pct_managed_drinking_water_services asc
# limit 20;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 20 rows affected.
# [('Sub-Saharan Africa', 'Angola', Decimal('52.33'), '2020'),
#  ('Sub-Saharan Africa', 'Chad', Decimal('52.67'), '2020'),
#  ('Sub-Saharan Africa', 'Burkina Faso', Decimal('53.33'), '2020'),
#  ('Sub-Saharan Africa', 'Madagascar', Decimal('56.33'), '2020'),
#  ('Oceania', 'Papua New Guinea', Decimal('56.67'), '2020'),
#  ('Sub-Saharan Africa', 'Niger', Decimal('57.33'), '2020'),
#  ('Sub-Saharan Africa', 'Somalia', Decimal('57.33'), '2020'),
#  ('Sub-Saharan Africa', 'Ethiopia', Decimal('58.00'), '2020'),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', Decimal('60.00'), '2020'),
#  ('Sub-Saharan Africa', 'Uganda', Decimal('61.00'), '2020'),
#  ('Northern Africa and Western Asia', 'Sudan', Decimal('62.33'), '2020'),
#  ('Northern Africa and Western Asia', 'Yemen', Decimal('63.00'), '2020'),
#  ('Sub-Saharan Africa', 'Cameroon', Decimal('64.00'), '2020'),
# ...

# %% [markdown]
# ## SECTION 2

# %% [markdown]
# # TASK 1. Basic Filtering with Comparison Operators
# You will be working with the united_nations.Access_to_Basic_Services table. The columns to SELECT include
#
# Country_name
# Time_period
# Pct_managed_drinking_water_services
# Pct_managed_sanitation_services
# Est_population_in_millions
# and Est_gdp_in_billions
# Use the WHERE clause to filter out records of specific countries:
#
# Nigeria,
# Ethiopia,
# Congo,
# Egypt,
# Tanzania,
# Kenya,
# and South Africa
# for the time period between 2019 and 2020. Utilize the OR operator to include multiple countries in your filter.

# %%
# %%sql
# SELECT Country_name,
#        Time_period,
#        Pct_managed_drinking_water_services,
#        Pct_managed_sanitation_services,
#        Est_population_in_millions,
#        Est_gdp_in_billions
# FROM access_to_basic_services
# WHERE Country_name = 'Nigeria' or Country_name = 'Ethiopia' or Country_name = 'Congo' or Country_name = 'Egypt' or Country_name = 'Tanzania' or Country_name = 'Kenya' or Country_name = 'South Africa'
# AND Time_period BETWEEN 2019 AND 2020
# order by Pct_managed_drinking_water_services desc
# limit 20;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 20 rows affected.
# [('Egypt', '2015', Decimal('99.33'), Decimal('96.33'), Decimal('0.00'), Decimal('0.00')),
#  ('Egypt', '2016', Decimal('99.33'), Decimal('96.33'), Decimal('0.00'), Decimal('0.00')),
#  ('Egypt', '2017', Decimal('99.33'), Decimal('96.33'), Decimal('0.00'), Decimal('0.00')),
#  ('Egypt', '2018', Decimal('99.33'), Decimal('97.00'), Decimal('0.00'), Decimal('0.00')),
#  ('Egypt', '2019', Decimal('99.33'), Decimal('97.00'), Decimal('0.00'), Decimal('0.00')),
#  ('Egypt', '2020', Decimal('99.33'), Decimal('97.67'), Decimal('0.00'), Decimal('0.00')),
#  ('South Africa', '2020', Decimal('92.00'), Decimal('78.67'), Decimal('58.80'), Decimal('337.62')),
#  ('South Africa', '2019', Decimal('91.67'), Decimal('78.00'), Decimal('58.09'), Decimal('388.53')),
#  ('Nigeria', '2020', Decimal('77.33'), Decimal('42.67'), Decimal('208.33'), Decimal('432.20')),
# ...

# %% [markdown]
# # Task 2: Streamlining with the IN Operator
#
# Building on the first task, you might have noticed that using multiple OR operators can make the query lengthy and a bit complicated. The 'IN' operator offers a more efficient way to achieve the same result. The IN operator allows you to specify multiple values in a WHERE clause, making the query more concise. Try to retrieve data for the same list of countries for the same time range, but this time, use the IN operator to simplify your query.

# %%
# %%sql
# SELECT Country_name,
#        Time_period,
#        Pct_managed_drinking_water_services,
#        Pct_managed_sanitation_services,
#        Est_population_in_millions,
#        Est_gdp_in_billions
# FROM access_to_basic_services
# WHERE Country_name IN (
#     'Nigeria',
#     'Ethiopia',
#     'Congo',
#     'Egypt',
#     'Tanzania',
#     'Kenya',
#     'South Africa'
# )
# AND Time_period BETWEEN 2019 AND 2020
# ORDER BY Pct_managed_drinking_water_services ASC
# LIMIT 20;

# %% [markdown]
# # Task 3: Combining Multiple Conditions
# The <= operator is a comparison operator that checks if the value on the left is less than or equal to the value on the right. In this task, you'll use it to filter countries based on specific service percentages. You'll continue working with the united_nations.Access_to_Basic_Services table. The columns to be selected for this task are
#
# Region,
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions, and
# Est_gdp_in_billions.
# Your goal is to extract data for the year 2020, focusing on countries where less than or equal to 50% of the population has access to sanitation services. This will help identify countries with critical sanitation needs. By using the <= operator with the Pct_managed_sanitation_services column, you can filter out countries that exceed this threshold, leaving only those with the most pressing sanitation challenges.

# %%
# %%sql
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_population_in_millions,
#     Est_gdp_in_billions
# FROM access_to_basic_services
# WHERE Country_name IN (
#     SELECT Country_name
#     FROM access_to_basic_services
#     WHERE Pct_managed_sanitation_services <= 50
# )
# AND Time_period = 2020
# ORDER BY Pct_managed_drinking_water_services DESC
# LIMIT 20;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 20 rows affected.
# [('Brunei Darussalam', '2020', Decimal('100.00'), Decimal('0.00'), Decimal('0.44'), Decimal('12.01')),
#  ('British Virgin Islands', '2020', Decimal('100.00'), Decimal('0.00'), Decimal('0.03'), Decimal('0.00')),
#  ('Guam', '2020', Decimal('100.00'), Decimal('0.00'), Decimal('0.17'), Decimal('5.89')),
#  ('Nauru', '2020', Decimal('100.00'), Decimal('0.00'), Decimal('0.01'), Decimal('0.11')),
#  ('Tuvalu', '2020', Decimal('100.00'), Decimal('0.00'), Decimal('0.01'), Decimal('0.06')),
#  ('Bangladesh', '2020', Decimal('97.67'), Decimal('54.00'), Decimal('167.42'), Decimal('373.90')),
#  ('Ghana', '2020', Decimal('84.67'), Decimal('23.00'), Decimal('32.18'), Decimal('70.04')),
#  ('Namibia', '2020', Decimal('83.67'), Decimal('35.00'), Decimal('2.49'), Decimal('10.58')),
#  ('Mali', '2020', Decimal('83.67'), Decimal('46.00'), Decimal('21.22'), Decimal('17.47')),
# ...

# %% [markdown]
# # USING LOGICAL AND COMPARISON OPERATOR

# %% [markdown]
# # Task 1
# Select data from the Sub-Saharan African region during the year 2020.

# %%
# %%sql
# select * from access_to_basic_services
# where Region = 'Sub-Saharan Africa' and Time_period = 2020
# limit 3;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 3 rows affected.
# [('Sub-Saharan Africa', 'Eastern Africa', 'Burundi', '2020', Decimal('70.33'), Decimal('44.33'), Decimal('12.22'), Decimal('2.65'), Decimal('25680.00'), Decimal('1.03')),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Djibouti', '2020', Decimal('69.00'), Decimal('56.00'), Decimal('1.09'), Decimal('3.18'), Decimal('23180.00'), Decimal('0.00')),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Ethiopia', '2020', Decimal('58.00'), Decimal('11.67'), Decimal('117.19'), Decimal('107.66'), Decimal('1128571.26'), Decimal('0.00'))]

# %% [markdown]
# # Task 2
# Sometimes there are null values in our entries. Any country having Null values for their GDP should not be included in our query as they will not help us determine if there is any correlation between GDP and access to basic services. For this task determine if there are any NULL values in the GDP column

# %%
# %%sql
# SELECT Country_name, COUNT(*) AS Count
# FROM access_to_basic_services
# WHERE Est_gdp_in_billions IS NOT NULL
# GROUP BY Country_name;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 182 rows affected.
# [('Kazakhstan', 6),
#  ('Kyrgyzstan', 6),
#  ('Tajikistan', 6),
#  ('Turkmenistan', 6),
#  ('Uzbekistan', 6),
#  ('Afghanistan', 6),
#  ('Bangladesh', 6),
#  ('Bhutan', 6),
#  ('India', 6),
#  ('Iran (Islamic Republic of)', 6),
#  ('Maldives', 6),
#  ('Nepal', 6),
#  ('Pakistan', 6),
#  ('Sri Lanka', 6),
#  ('China', 6),
#  ("Democratic People's Republic of Korea", 6),
#  ('Japan', 6),
#  ('Mongolia', 6),
#  ('Republic of Korea', 6),
#  ('Brunei Darussalam', 6),
#  ('Cambodia', 6),
#  ('Indonesia', 6),
#  ("Lao People's Democratic Republic", 6),
#  ('Malaysia', 6),
#  ('Myanmar', 6),
#  ('Philippines', 6),
#  ('Singapore', 6),
#  ('Thailand', 6),
#  ('Timor-Leste', 6),
#  ('Viet Nam', 6),
#  ('Bermuda', 6),
#  ('Canada', 6),
#  ('Greenland', 6),
#  ('Saint Pierre and Miquelon', 6),
#  ('United States of America', 6),
#  ('Anguilla', 3),
#  ('Antigua and Barbuda', 3),
#  ('Aruba', 2),
# ...

# %%
# %%sql
# select * from
# access_to_basic_services
# where Country_name IN (
#     select Country_name
#     from access_to_basic_services
#     where Est_gdp_in_billions is not null
#     group by Country_name
# )
# limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2015', Decimal('94.67'), Decimal('98.00'), Decimal('17.54'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2016', Decimal('94.67'), Decimal('98.00'), Decimal('17.79'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2017', Decimal('95.00'), Decimal('98.00'), Decimal('18.04'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2018', Decimal('95.00'), Decimal('98.00'), Decimal('18.28'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
# ...

# %% [markdown]
# # Task 3
# If there are any Null values exclude them from your query.

# %%
# %%sql
# drop table access_to_water;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %%
# %%sql
# -- create a copy of the access_to_basic_services table
# CREATE TABLE access_to_water
# LIKE access_to_basic_services;
#
# INSERT INTO access_to_water
# SELECT * FROM access_to_basic_services;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 0 rows affected.
# 1048 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 8 rows affected.
# [('access_to_basic_services',),
#  ('access_to_water',),
#  ('country_list',),
#  ('employees',),
#  ('location',),
#  ('no_duplicates_access_to_basic_services',),
#  ('regions',),
#  ('water_basic_services',)]

# %%
# %%sql
# SELECT * FROM access_to_water limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2015', Decimal('94.67'), Decimal('98.00'), Decimal('17.54'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2016', Decimal('94.67'), Decimal('98.00'), Decimal('17.79'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2017', Decimal('95.00'), Decimal('98.00'), Decimal('18.04'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2018', Decimal('95.00'), Decimal('98.00'), Decimal('18.28'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
# ...

# %%
# %%sql
# -- remove rows with null values
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_gdp_in_billions,
#     region
# FROM
# 	united_nations.Access_to_Basic_Services
# WHERE
# 	region = 'Sub-Saharan Africa'
# AND
# 	Time_period = 2020
# AND
# 	Est_gdp_in_billions IS NOT NULL
#
# limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Burundi', '2020', Decimal('70.33'), Decimal('44.33'), Decimal('2.65'), 'Sub-Saharan Africa'),
#  ('Djibouti', '2020', Decimal('69.00'), Decimal('56.00'), Decimal('3.18'), 'Sub-Saharan Africa'),
#  ('Ethiopia', '2020', Decimal('58.00'), Decimal('11.67'), Decimal('107.66'), 'Sub-Saharan Africa'),
#  ('Kenya', '2020', Decimal('67.00'), Decimal('33.67'), Decimal('100.67'), 'Sub-Saharan Africa'),
#  ('Madagascar', '2020', Decimal('56.33'), Decimal('13.00'), Decimal('13.05'), 'Sub-Saharan Africa')]

# %% [markdown]
# # Task 4
# Lets get an idea if there's any correlation between the GDP and access to basic services for the top 5 economies in Sub-Saharan Africr. The top 5 GDP's are : ('Nigeria','South Africa','Ethiopia','Kenya','Ghana'). Make sure your query only includes these countries.

# %%
# %%sql
# -- correlation between GDP and access to water
# SELECT
# 	Country_name,
# 	Est_gdp_in_billions,
# 	Pct_managed_drinking_water_services
# FROM
# 	united_nations.Access_to_Basic_Services
# WHERE
# 	region = 'Sub-Saharan Africa'
# AND
# 	Time_period = 2020
# AND
# 	Est_gdp_in_billions IS NOT NULL
# AND
# 	Pct_managed_drinking_water_services IS NOT NULL
# AND
#     Country_name  NOT IN ('Nigeria','South Africa','Ethiopia','Kenya','Ghana')
# order by Est_gdp_in_billions desc
# limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Angola', Decimal('53.62'), Decimal('52.33')),
#  ('Cameroon', Decimal('40.77'), Decimal('64.00')),
#  ('Uganda', Decimal('37.60'), Decimal('61.00')),
#  ('Senegal', Decimal('24.49'), Decimal('85.00')),
#  ('Zimbabwe', Decimal('21.51'), Decimal('68.00'))]

# %%
# %%sql
# -- correlation between GDP and access to water
# SELECT
# 	Country_name,
# 	Est_gdp_in_billions,
# 	Pct_managed_drinking_water_services
# FROM
# 	united_nations.Access_to_Basic_Services
# WHERE
# 	region = 'Sub-Saharan Africa'
# AND
# 	Time_period = 2020
# AND
# 	Est_gdp_in_billions IS NOT NULL
# AND
# 	Pct_managed_drinking_water_services IS NOT NULL
# AND
#     Country_name IN ('Nigeria','South Africa','Ethiopia','Kenya','Ghana')
# order by Est_gdp_in_billions desc
# limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Nigeria', Decimal('432.20'), Decimal('77.33')),
#  ('South Africa', Decimal('337.62'), Decimal('92.00')),
#  ('Ethiopia', Decimal('107.66'), Decimal('58.00')),
#  ('Kenya', Decimal('100.67'), Decimal('67.00')),
#  ('Ghana', Decimal('70.04'), Decimal('84.67'))]

# %% [markdown]
# # Task 5
# We only looked at 5 countries in the previous query. Lets have a look at the rest of Sub-Saharan Africa . Exclude the countries mentioned in the previous task

# %%
# %%sql
# -- correlation between GDP and access to water
# SELECT
# 	Country_name,
# 	Est_gdp_in_billions,
# 	Pct_managed_drinking_water_services
# FROM
# 	united_nations.Access_to_Basic_Services
# WHERE
# 	region = 'Sub-Saharan Africa'
# AND
# 	Time_period = 2020
# AND
# 	Est_gdp_in_billions IS NOT NULL
# AND
# 	Pct_managed_drinking_water_services IS NOT NULL
# order by Est_gdp_in_billions desc;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 47 rows affected.
# [('Nigeria', Decimal('432.20'), Decimal('77.33')),
#  ('South Africa', Decimal('337.62'), Decimal('92.00')),
#  ('Ethiopia', Decimal('107.66'), Decimal('58.00')),
#  ('Kenya', Decimal('100.67'), Decimal('67.00')),
#  ('Ghana', Decimal('70.04'), Decimal('84.67')),
#  ('Angola', Decimal('53.62'), Decimal('52.33')),
#  ('Cameroon', Decimal('40.77'), Decimal('64.00')),
#  ('Uganda', Decimal('37.60'), Decimal('61.00')),
#  ('Senegal', Decimal('24.49'), Decimal('85.00')),
#  ('Zimbabwe', Decimal('21.51'), Decimal('68.00')),
#  ('Zambia', Decimal('18.11'), Decimal('66.67')),
#  ('Burkina Faso', Decimal('17.93'), Decimal('53.33')),
#  ('Mali', Decimal('17.47'), Decimal('83.67')),
#  ('Benin', Decimal('15.65'), Decimal('65.33')),
#  ('Gabon', Decimal('15.31'), Decimal('73.33')),
#  ('Botswana', Decimal('14.93'), Decimal('89.67')),
#  ('Guinea', Decimal('14.18'), Decimal('67.33')),
# ...
