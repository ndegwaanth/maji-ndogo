# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://anthony:Sucess%4022@localhost/households

# %%
# %%sql
# CREATE TABLE household_individual (
#     ID INT PRIMARY KEY,
#     Sex VARCHAR(10) NOT NULL,
#     D_O_B DATETIME NOT NULL,
#     Age INT,
#     Weight DECIMAL(5,2),
#     Highest_ed VARCHAR(50),
#     Ed_institution VARCHAR(50),
#     Marital_status VARCHAR(20),
#     Spouse VARCHAR(10),
#     Spouse_ID INT
# );
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO household_individual
# (ID, Sex, D_O_B, Age, Weight, Highest_ed, Ed_institution, Marital_status, Spouse, Spouse_ID)
# VALUES
# (3901, 'Male', '2020-06-30 00:00:00', 0, 7.24, NULL, NULL, 'Single', 'N/A', NULL),
#
# (3821, 'Female', '1998-05-21 00:00:00', 22, 67.00, 'Diploma', 'Public', 'Single', 'N/A', NULL),
#
# (3961, 'Male', '1970-11-15 00:00:00', 35, 59.00, 'Masters', NULL, 'Married', 'Yes', 3331),
#
# (3741, 'Female', '2012-01-09 00:00:00', 14, 45.22, 'Primary', 'Private', 'Single', 'N/A', NULL),
#
# (3661, 'Male', '1989-10-04 00:00:00', 69, 77.00, 'PHD', NULL, 'Married', 'Yes', 3891),
#
# (63921, 'Female', '2020-06-30 00:00:00', 16, 45.99, 'Secondary', 'Public', 'Single', 'N/A', NULL);
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# []

# %%
# %%sql
# select * from household_individual;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# [(3661, 'Male', datetime.datetime(1989, 10, 4, 0, 0), 69, Decimal('77.00'), 'PHD', None, 'Married', 'Yes', 3891),
#  (3741, 'Female', datetime.datetime(2012, 1, 9, 0, 0), 14, Decimal('45.22'), 'Primary', 'Private', 'Single', 'N/A', None),
#  (3821, 'Female', datetime.datetime(1998, 5, 21, 0, 0), 22, Decimal('67.00'), 'Diploma', 'Public', 'Single', 'N/A', None),
#  (3901, 'Male', datetime.datetime(2020, 6, 30, 0, 0), 0, Decimal('7.24'), None, None, 'Single', 'N/A', None),
#  (3961, 'Male', datetime.datetime(1970, 11, 15, 0, 0), 35, Decimal('59.00'), 'Masters', None, 'Married', 'Yes', 3331),
#  (63921, 'Female', datetime.datetime(2020, 6, 30, 0, 0), 16, Decimal('45.99'), 'Secondary', 'Public', 'Single', 'N/A', None)]

# %%
# %%sql
# -- case D_O_B
# select
#     D_O_B,
#     cast(D_O_B as date) as date_of_birth
# from
#     household_individual;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# [(datetime.datetime(1989, 10, 4, 0, 0), datetime.date(1989, 10, 4)),
#  (datetime.datetime(2012, 1, 9, 0, 0), datetime.date(2012, 1, 9)),
#  (datetime.datetime(1998, 5, 21, 0, 0), datetime.date(1998, 5, 21)),
#  (datetime.datetime(2020, 6, 30, 0, 0), datetime.date(2020, 6, 30)),
#  (datetime.datetime(1970, 11, 15, 0, 0), datetime.date(1970, 11, 15)),
#  (datetime.datetime(2020, 6, 30, 0, 0), datetime.date(2020, 6, 30))]

# %%
# %%sql
# ALTER TABLE household_individual
# ADD COLUMN date_of_birth DATE;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 0 rows affected.
# []

# %%
# %%sql
# UPDATE household_individual
# SET date_of_birth = CAST(D_O_B AS DATE);
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# []

# %%
# %%sql
# -- drop the D_O_B column
# ALTER TABLE household_individual
# DROP COLUMN D_O_B;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 0 rows affected.
# []

# %%
# %%sql
# select * from household_individual;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# [(3661, 'Male', 69, Decimal('77.00'), 'PHD', None, 'Married', 'Yes', 3891, datetime.date(1989, 10, 4)),
#  (3741, 'Female', 14, Decimal('45.22'), 'Primary', 'Private', 'Single', 'N/A', None, datetime.date(2012, 1, 9)),
#  (3821, 'Female', 22, Decimal('67.00'), 'Diploma', 'Public', 'Single', 'N/A', None, datetime.date(1998, 5, 21)),
#  (3901, 'Male', 0, Decimal('7.24'), None, None, 'Single', 'N/A', None, datetime.date(2020, 6, 30)),
#  (3961, 'Male', 35, Decimal('59.00'), 'Masters', None, 'Married', 'Yes', 3331, datetime.date(1970, 11, 15)),
#  (63921, 'Female', 16, Decimal('45.99'), 'Secondary', 'Public', 'Single', 'N/A', None, datetime.date(2020, 6, 30))]

# %%
# %%sql
# alter table household_individual
# add column my_weight float
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 0 rows affected.
# []

# %%
# %%sql
# select * from household_individual;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# [(3661, 'Male', 69, Decimal('77.00'), 'PHD', None, 'Married', 'Yes', 3891, datetime.date(1989, 10, 4), None),
#  (3741, 'Female', 14, Decimal('45.22'), 'Primary', 'Private', 'Single', 'N/A', None, datetime.date(2012, 1, 9), None),
#  (3821, 'Female', 22, Decimal('67.00'), 'Diploma', 'Public', 'Single', 'N/A', None, datetime.date(1998, 5, 21), None),
#  (3901, 'Male', 0, Decimal('7.24'), None, None, 'Single', 'N/A', None, datetime.date(2020, 6, 30), None),
#  (3961, 'Male', 35, Decimal('59.00'), 'Masters', None, 'Married', 'Yes', 3331, datetime.date(1970, 11, 15), None),
#  (63921, 'Female', 16, Decimal('45.99'), 'Secondary', 'Public', 'Single', 'N/A', None, datetime.date(2020, 6, 30), None)]

# %%
# %%sql
# select
#     my_weight,
#     convert(my_weight, Decimal(5,2)) as weight_in_decimal
# from
#     household_individual;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# [(None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None)]

# %%
# %%sql
# select * from household_individual;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# [(3661, 'Male', 69, Decimal('77.00'), 'PHD', None, 'Married', 'Yes', 3891, datetime.date(1989, 10, 4), None),
#  (3741, 'Female', 14, Decimal('45.22'), 'Primary', 'Private', 'Single', 'N/A', None, datetime.date(2012, 1, 9), None),
#  (3821, 'Female', 22, Decimal('67.00'), 'Diploma', 'Public', 'Single', 'N/A', None, datetime.date(1998, 5, 21), None),
#  (3901, 'Male', 0, Decimal('7.24'), None, None, 'Single', 'N/A', None, datetime.date(2020, 6, 30), None),
#  (3961, 'Male', 35, Decimal('59.00'), 'Masters', None, 'Married', 'Yes', 3331, datetime.date(1970, 11, 15), None),
#  (63921, 'Female', 16, Decimal('45.99'), 'Secondary', 'Public', 'Single', 'N/A', None, datetime.date(2020, 6, 30), None)]

# %%
# %%sql
# -- IFNULL
# select
#     Highest_ed,
#     IFNULL(Highest_ed, 'No education') as highest_education
# from
#     household_individual;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# [('PHD', 'PHD'),
#  ('Primary', 'Primary'),
#  ('Diploma', 'Diploma'),
#  (None, 'No education'),
#  ('Masters', 'Masters'),
#  ('Secondary', 'Secondary')]

# %%
# %%sql
# update household_individual
# set Highest_ed = IFNULL(Highest_ed, 'No education');
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# []

# %%
# %%sql
# select * from household_individual;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# [(3661, 'Male', 69, Decimal('77.00'), 'PHD', None, 'Married', 'Yes', 3891, datetime.date(1989, 10, 4), None),
#  (3741, 'Female', 14, Decimal('45.22'), 'Primary', 'Private', 'Single', 'N/A', None, datetime.date(2012, 1, 9), None),
#  (3821, 'Female', 22, Decimal('67.00'), 'Diploma', 'Public', 'Single', 'N/A', None, datetime.date(1998, 5, 21), None),
#  (3901, 'Male', 0, Decimal('7.24'), 'No education', None, 'Single', 'N/A', None, datetime.date(2020, 6, 30), None),
#  (3961, 'Male', 35, Decimal('59.00'), 'Masters', None, 'Married', 'Yes', 3331, datetime.date(1970, 11, 15), None),
#  (63921, 'Female', 16, Decimal('45.99'), 'Secondary', 'Public', 'Single', 'N/A', None, datetime.date(2020, 6, 30), None)]

# %%
# %%sql
# update household_individual
# set Spouse_ID = 0099
# where ID = 3741;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 1 rows affected.
# []

# %%
# %%sql
# update household_individual
# set Spouse_ID = 4444
# where ID = 3901;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 1 rows affected.
# []

# %%
# %%sql
# -- NULLIF
# select
#     age,
#     ID,
#     NULLIF(age, 0) as age_with_nulls
# from
#     household_individual;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# [(69, 3661, 69),
#  (14, 3741, 14),
#  (22, 3821, 22),
#  (0, 3901, None),
#  (35, 3961, 35),
#  (16, 63921, 16)]

# %%
# %%sql
# -- Coalesce
# select
#     age,
#     ID,
#     COALESCE(NULLIF(age, 0), 'Unknown') as age_with_unknowns
# from
#     household_individual;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# [(69, 3661, '69'),
#  (14, 3741, '14'),
#  (22, 3821, '22'),
#  (0, 3901, 'Unknown'),
#  (35, 3961, '35'),
#  (16, 63921, '16')]

# %%
# %%sql
# select * from household_individual;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# [(3661, 'Male', 69, Decimal('77.00'), 'PHD', None, 'Married', 'Yes', 3891, datetime.date(1989, 10, 4), None),
#  (3741, 'Female', 14, Decimal('45.22'), 'Primary', 'Private', 'Single', 'N/A', 99, datetime.date(2012, 1, 9), None),
#  (3821, 'Female', 22, Decimal('67.00'), 'Diploma', 'Public', 'Single', 'N/A', None, datetime.date(1998, 5, 21), None),
#  (3901, 'Male', 0, Decimal('7.24'), 'No education', None, 'Single', 'N/A', 4444, datetime.date(2020, 6, 30), None),
#  (3961, 'Male', 35, Decimal('59.00'), 'Masters', None, 'Married', 'Yes', 3331, datetime.date(1970, 11, 15), None),
#  (63921, 'Female', 16, Decimal('45.99'), 'Secondary', 'Public', 'Single', 'N/A', None, datetime.date(2020, 6, 30), None)]

# %%
# %%sql
# select
#     Marital_status,
#     Spouse_ID,
#     Spouse,
#     COALESCE(Spouse_ID, Spouse) as spouse_info
# from
#     household_individual;
# Out:
#  * mysql+pymysql://anthony:***@localhost/households
# 6 rows affected.
# [('Married', 3891, 'Yes', '3891'),
#  ('Single', 99, 'N/A', '99'),
#  ('Single', None, 'N/A', 'N/A'),
#  ('Single', 4444, 'N/A', '4444'),
#  ('Married', 3331, 'Yes', '3331'),
#  ('Single', None, 'N/A', 'N/A')]
