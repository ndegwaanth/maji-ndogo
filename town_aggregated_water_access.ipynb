# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///data/town_aggregate_water_access.db

# %%
# %%sql
# select name
# from sqlite_master
# where type='table';
# Out:
#    sqlite:///data/town_aggregate_water_access.db
#    sqlite:///data/town_water_source_percentage.db
#  * sqlite:///town_water_source_percentage.db
# Done.
# [('data/town_water_source_percentages',),
#  ('data/town_water_source_percentage',)]

# %%
# %%sql
# select * from town_water_source_percentage;
# Out:
#    sqlite:///data/town_aggregate_water_access.db
#    sqlite:///data/town_water_source_percentage.db
#  * sqlite:///town_water_source_percentage.db
# (sqlite3.OperationalError) no such table: town_water_source_percentage
# [SQL: select * from town_water_source_percentage;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
