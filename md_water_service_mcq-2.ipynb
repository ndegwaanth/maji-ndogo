# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://anthony:Sucess%4022@localhost:3306/md_water_services

# %%
# %%sql
# show tables;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 9 rows affected.
# [('data_dictionary',),
#  ('employee',),
#  ('employee_backup',),
#  ('global_water_access',),
#  ('location',),
#  ('visits',),
#  ('water_quality',),
#  ('water_source',),
#  ('well_pollution',)]

# %%
# %%sql
# describe visits;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 7 rows affected.
# [('record_id', 'int', 'NO', 'PRI', None, ''),
#  ('location_id', 'varchar(255)', 'YES', 'MUL', None, ''),
#  ('source_id', 'varchar(510)', 'YES', 'MUL', None, ''),
#  ('time_of_record', 'datetime', 'YES', '', None, ''),
#  ('visit_count', 'int', 'YES', '', None, ''),
#  ('time_in_queue', 'int', 'YES', '', None, ''),
#  ('assigned_employee_id', 'int', 'YES', 'MUL', None, '')]

# %%
# %%sql
# select * from visits limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 5 rows affected.
# [(0, 'SoIl32582', 'SoIl32582224', datetime.datetime(2021, 1, 1, 9, 10), 1, 15, 12),
#  (1, 'KiRu28935', 'KiRu28935224', datetime.datetime(2021, 1, 1, 9, 17), 1, 0, 46),
#  (2, 'HaRu19752', 'HaRu19752224', datetime.datetime(2021, 1, 1, 9, 36), 1, 62, 40),
#  (3, 'AkLu01628', 'AkLu01628224', datetime.datetime(2021, 1, 1, 9, 53), 1, 0, 1),
#  (4, 'AkRu03357', 'AkRu03357224', datetime.datetime(2021, 1, 1, 10, 11), 1, 28, 14)]

# %%
# %%sql
# /*
# roduce the date format "DD Month YYYY" from the time_of_record column in the visits table, as a single column? Note: Monthname() acts in a similar way to DAYNAME().
# */
# -- select date_format(time_of_record, '%d %M %Y') as date from visits limit 5;
# -- SELECT day(time_of_record), monthname(time_of_record), year(time_of_record) FROM visits;
# -- SELECT CONCAT(day(time_of_record), " ", month(time_of_record), " ", year-----(time_of_record)) FROM visits;
# -- SELECT CONCAT(monthname(time_of_record), " ", day(time_of_record), ", ", year(time_of_record)) as formatted_date FROM visits;
#
# SELECT CONCAT(day(time_of_record), " ", monthname(time_of_record), " ", year(time_of_record)) as formatted_date FROM visits limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 5 rows affected.
# [('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',)]

# %%
# %%sql
# show tables;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 9 rows affected.
# [('data_dictionary',),
#  ('employee',),
#  ('employee_backup',),
#  ('global_water_access',),
#  ('location',),
#  ('visits',),
#  ('water_quality',),
#  ('water_source',),
#  ('well_pollution',)]

# %%
# %%sql
# select * from water_services limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# (pymysql.err.ProgrammingError) (1146, "Table 'md_water_services.water_services' doesn't exist")
# [SQL: select * from water_services limit 5;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# -- calculate the Annual Rate of Change (ARC) for basic rural water services:
# SELECT
#     name,
#     wat_bas_r - LAG(wat_bas_r)
#         OVER (PARTITION BY name ORDER BY year)
# FROM global_water_access
# ORDER BY name;

# %%
# %%sql
# show tables;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 9 rows affected.
# [('data_dictionary',),
#  ('employee',),
#  ('employee_backup',),
#  ('global_water_access',),
#  ('location',),
#  ('visits',),
#  ('water_quality',),
#  ('water_source',),
#  ('well_pollution',)]

# %%
# %%sql
# describe employee;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 8 rows affected.
# [('assigned_employee_id', 'int', 'NO', 'PRI', None, ''),
#  ('employee_name', 'varchar(255)', 'YES', '', None, ''),
#  ('phone_number', 'varchar(15)', 'YES', '', None, ''),
#  ('email', 'varchar(255)', 'YES', '', None, ''),
#  ('address', 'varchar(255)', 'YES', '', None, ''),
#  ('province_name', 'varchar(255)', 'YES', '', None, ''),
#  ('town_name', 'varchar(255)', 'YES', '', None, ''),
#  ('position', 'varchar(255)', 'YES', '', None, '')]

# %%
# %%sql
# select * from employee limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 5 rows affected.
# [(0, 'Amara Jengo', '+99637993287 ', None, '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Field Surveyor'),
#  (1, 'Bello Azibo', '+99643864786 ', None, '129 Ziwa La Kioo Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (2, 'Bakari Iniko', '+99222599041 ', None, '18 Mlima Tazama Avenue', 'Hawassa', 'Rural', 'Field Surveyor'),
#  (3, 'Malachi Mavuso', '+99945849900 ', None, '100 Mogadishu Road', 'Akatsi', 'Lusaka', 'Field Surveyor'),
#  (4, 'Cheche Buhle', '+99381679640 ', None, '1 Savanna Street', 'Akatsi', 'Rural', 'Field Surveyor')]

# %%
# %%sql
# select * from visits limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 5 rows affected.
# [(0, 'SoIl32582', 'SoIl32582224', datetime.datetime(2021, 1, 1, 9, 10), 1, 15, 12),
#  (1, 'KiRu28935', 'KiRu28935224', datetime.datetime(2021, 1, 1, 9, 17), 1, 0, 46),
#  (2, 'HaRu19752', 'HaRu19752224', datetime.datetime(2021, 1, 1, 9, 36), 1, 62, 40),
#  (3, 'AkLu01628', 'AkLu01628224', datetime.datetime(2021, 1, 1, 9, 53), 1, 0, 1),
#  (4, 'AkRu03357', 'AkRu03357224', datetime.datetime(2021, 1, 1, 10, 11), 1, 28, 14)]

# %%
# %%sql
# SELECT
#     assigned_employee_id,
#     COUNT(*) AS total_visits
# FROM visits
# GROUP BY assigned_employee_id
# ORDER BY total_visits ASC;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 29 rows affected.
# [(20, 15),
#  (22, 143),
#  (44, 218),
#  (26, 719),
#  (16, 802),
#  (0, 1099),
#  (4, 1136),
#  (6, 1182),
#  (7, 1259),
#  (14, 1441),
#  (46, 1632),
#  (18, 1749),
#  (32, 1852),
#  (24, 2015),
#  (2, 2033),
#  (38, 2121),
#  (40, 2344),
#  (42, 2496),
#  (12, 2561),
#  (28, 2762),
#  (48, 2933),
#  (36, 3249),
#  (5, 3284),
#  (8, 3351),
#  (10, 3407),
#  (3, 3420),
#  (34, 3539),
#  (30, 3676),
#  (1, 3708)]

# %%
# %%sql
# /*What are the names of the two worst-performing employees who visited the fewest sites, and how many sites did the worst-performing employee visit? Modify your queries from the “Honouring the workers” section.*/
# SELECT
#     e.employee_name,
#     COUNT(DISTINCT v.location_id) AS total_sites_visited
# FROM employee e
# JOIN visits v
#     ON e.assigned_employee_id = v.assigned_employee_id
# GROUP BY e.assigned_employee_id, e.employee_name
# ORDER BY total_sites_visited ASC
# LIMIT 2;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 2 rows affected.
# [('Kunto Asha', 8), ('Lesedi Kofi', 94)]

# %%
# %%sql
# select * from employee limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 5 rows affected.
# [(0, 'Amara Jengo', '+99637993287 ', None, '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Field Surveyor'),
#  (1, 'Bello Azibo', '+99643864786 ', None, '129 Ziwa La Kioo Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (2, 'Bakari Iniko', '+99222599041 ', None, '18 Mlima Tazama Avenue', 'Hawassa', 'Rural', 'Field Surveyor'),
#  (3, 'Malachi Mavuso', '+99945849900 ', None, '100 Mogadishu Road', 'Akatsi', 'Lusaka', 'Field Surveyor'),
#  (4, 'Cheche Buhle', '+99381679640 ', None, '1 Savanna Street', 'Akatsi', 'Rural', 'Field Surveyor')]

# %%
# %%sql
# select
#     assigned_employee_id,
#     employee_name
# from employee
# where assigned_employee_id IN (20, 22);
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 2 rows affected.
# [(20, 'Kunto Asha'), (22, 'Lesedi Kofi')]

# %%
# %%sql
# select * from visits limit 3;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 3 rows affected.
# [(0, 'SoIl32582', 'SoIl32582224', datetime.datetime(2021, 1, 1, 9, 10), 1, 15, 12),
#  (1, 'KiRu28935', 'KiRu28935224', datetime.datetime(2021, 1, 1, 9, 17), 1, 0, 46),
#  (2, 'HaRu19752', 'HaRu19752224', datetime.datetime(2021, 1, 1, 9, 36), 1, 62, 40)]

# %%
# %%sql
# SELECT
#     location_id,
#     time_in_queue,
#     AVG(time_in_queue) OVER (PARTITION BY location_id ORDER BY visit_count) AS total_avg_queue_time
# FROM
#     visits
# WHERE
# visit_count > 1 -- Only shared taps were visited > 1
# ORDER BY
#     location_id, time_of_record
# LIMIT 10;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 10 rows affected.
# [('AkHa00036', 113, Decimal('113.0000')),
#  ('AkHa00036', 229, Decimal('171.0000')),
#  ('AkHa00036', 400, Decimal('247.3333')),
#  ('AkHa00036', 120, Decimal('215.5000')),
#  ('AkHa00036', 185, Decimal('209.4000')),
#  ('AkHa00036', 158, Decimal('200.8333')),
#  ('AkHa00036', 226, Decimal('204.4286')),
#  ('AkHa00090', 50, Decimal('50.0000')),
#  ('AkHa00090', 63, Decimal('56.5000')),
#  ('AkHa00090', 12, Decimal('41.6667'))]

# %%
# %%sql
# select * from employee limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 5 rows affected.
# [(0, 'Amara Jengo', '+99637993287 ', None, '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Field Surveyor'),
#  (1, 'Bello Azibo', '+99643864786 ', None, '129 Ziwa La Kioo Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (2, 'Bakari Iniko', '+99222599041 ', None, '18 Mlima Tazama Avenue', 'Hawassa', 'Rural', 'Field Surveyor'),
#  (3, 'Malachi Mavuso', '+99945849900 ', None, '100 Mogadishu Road', 'Akatsi', 'Lusaka', 'Field Surveyor'),
#  (4, 'Cheche Buhle', '+99381679640 ', None, '1 Savanna Street', 'Akatsi', 'Rural', 'Field Surveyor')]

# %%
# %%sql
# select
#     town_name,
#     count(*) as town_counts
# from employee
# where
#     town_name = "Dahabu";
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/md_water_services
# 1 rows affected.
# [('Dahabu', 6)]
