# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Converting between data types

# %% [markdown]
# In this notebook, we will learn how to convert one data type to another using the `CAST()` function.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to convert from one data type to another using the `CAST()` function.

# %% [markdown]
# ## Overview
#
# All the columns in our database have been assigned a data type during the creation of the database schema. When we query our data using the `SELECT` statement, the retrieved data will be returned in the same data type as specified in the schema.
#
# Suppose we want to retrieve the data in a different data type, we can use the `CAST` function, which allows us to change from one data type to another.

# %% [markdown]
# ## Connecting to our MySQL database
#
# We will use our `Access_to_Basic_Services` table in our `united_nations` database that we created in MySQL Workbench. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://anthony:Sucess%4022@localhost:3306/united_nations

# %% [markdown]
# ## Exercise

# %% [markdown]
# We can use the following command to check the data types of all the columns in our table.

# %%
# %%sql
#
# SHOW
#     COLUMNS
# FROM
#     united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 10 rows affected.
# [('Region', 'varchar(255)', 'NO', '', None, ''),
#  ('Sub_region', 'varchar(255)', 'NO', '', None, ''),
#  ('Country_name', 'varchar(255)', 'NO', '', None, ''),
#  ('Time_period', 'varchar(255)', 'NO', '', None, ''),
#  ('Pct_managed_drinking_water_services', 'decimal(10,2)', 'NO', '', None, ''),
#  ('Pct_managed_sanitation_services', 'decimal(10,2)', 'YES', '', None, ''),
#  ('Est_population_in_millions', 'decimal(10,2)', 'YES', '', None, ''),
#  ('Est_gdp_in_billions', 'decimal(10,2)', 'YES', '', None, ''),
#  ('Land_area_in_sq_km', 'decimal(10,2)', 'YES', '', None, ''),
#  ('Pct_unemployment_rate', 'decimal(10,2)', 'YES', '', None, '')]

# %% [markdown]
# We can see that the column values are in their respective data types, that is, `VARCHAR` for Country_name, `INT` for Time_period, and `DECIMAL` for the estimated population.

# %% [markdown]
# Let us type in the following query which will give us the estimated population for each distinct country, per year.

# %%
# %%sql
#
# SELECT DISTINCT
#     Country_name,
#     Time_period,
#     Est_population_in_millions
# FROM
#     united_nations.Access_to_Basic_Services
# limit 10;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 10 rows affected.
# [('Kazakhstan', '2015', Decimal('17.54')),
#  ('Kazakhstan', '2016', Decimal('17.79')),
#  ('Kazakhstan', '2017', Decimal('18.04')),
#  ('Kazakhstan', '2018', Decimal('18.28')),
#  ('Kazakhstan', '2019', Decimal('18.51')),
#  ('Kazakhstan', '2020', Decimal('18.76')),
#  ('Kyrgyzstan', '2015', Decimal('0.00')),
#  ('Kyrgyzstan', '2016', Decimal('0.00')),
#  ('Kyrgyzstan', '2017', Decimal('0.00')),
#  ('Kyrgyzstan', '2018', Decimal('0.00'))]

# %% [markdown]
# ### 1. Determine the appropriate precision

# %% [markdown]
# Looking at `Est_population_in_millions`, it has been given the `DECIMAL(11,6)` numeric data type, which has a **precision of 11** and a **scale of 6**. This means that the number can have a total of 11 digits, with 6 digits allowed after the decimal point.
#
# This makes the values too long and hard to read.
#
# Instead, we can alter its data type such that it is retrieved with **only 2 decimal values** to improve readability and efficiency.

# %% [markdown]
# We know we want to give a scale of 2, but what about the precision?
# We can find the maximum value in the estimated population column, which we can then use to help us determine the most appropriate precision for the column.

# %%
# %%sql
#
# SELECT DISTINCT
#     max(Est_population_in_millions) as Max_population_in_millions
# FROM
#     united_nations.Access_to_Basic_Services
# limit 10;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('1411.10'),)]

# %% [markdown]
# ### 2. Convert to the DECIMAL data type with the preferred scale and precision
#
# Once we have determined the appropriate precision to give to the `Est_population_in_millions` column values, we can then convert to the preferred data type.

# %%
# %%sql
#
# SELECT DISTINCT
#     Country_name,
#     Time_period,
#     cast(Est_population_in_millions as Decimal(6,2)) as Est_population_in_millions_decimal
# FROM
#     united_nations.Access_to_Basic_Services
# limit 10;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 10 rows affected.
# [('Kazakhstan', '2015', Decimal('17.54')),
#  ('Kazakhstan', '2016', Decimal('17.79')),
#  ('Kazakhstan', '2017', Decimal('18.04')),
#  ('Kazakhstan', '2018', Decimal('18.28')),
#  ('Kazakhstan', '2019', Decimal('18.51')),
#  ('Kazakhstan', '2020', Decimal('18.76')),
#  ('Kyrgyzstan', '2015', Decimal('0.00')),
#  ('Kyrgyzstan', '2016', Decimal('0.00')),
#  ('Kyrgyzstan', '2017', Decimal('0.00')),
#  ('Kyrgyzstan', '2018', Decimal('0.00'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Determine the appropriate precision
# We use the `MAX` function to help us find the maximum value in the `Est_population_in_millions` column.

# %%
# %%sql
#
# SELECT DISTINCT
#     MAX(Est_population_in_millions)
# FROM
#     united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('1411.10'),)]

# %% [markdown]
# Since the highest value in the column has 4 digits before the decimal point, we can safely assign a precision of 6, with a scale of 2 to the column.

# %% [markdown]
# ### 2.  Convert to the DECIMAL data type with the preferred scale and precision
#
# We use the `CAST` function to convert the `Estimated population in millions` column to the new data type and the results are returned in a new column, `Est_population_in_millions_2dp`.

# %%
# %%sql
#
# SELECT DISTINCT
#     Country_name,
#     Time_period,
#     CAST(Est_population_in_millions AS DECIMAL(6,2)) AS Est_population_in_millions_2dp
# FROM
#     united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Kazakhstan', '2015', Decimal('17.54')),
#  ('Kazakhstan', '2016', Decimal('17.79')),
#  ('Kazakhstan', '2017', Decimal('18.04')),
#  ('Kazakhstan', '2018', Decimal('18.28')),
#  ('Kazakhstan', '2019', Decimal('18.51')),
#  ('Kazakhstan', '2020', Decimal('18.76')),
#  ('Kyrgyzstan', '2015', Decimal('0.00')),
#  ('Kyrgyzstan', '2016', Decimal('0.00')),
#  ('Kyrgyzstan', '2017', Decimal('0.00')),
#  ('Kyrgyzstan', '2018', Decimal('0.00')),
#  ('Kyrgyzstan', '2019', Decimal('0.00')),
#  ('Kyrgyzstan', '2020', Decimal('0.00')),
#  ('Tajikistan', '2015', Decimal('8.52')),
#  ('Tajikistan', '2016', Decimal('8.73')),
#  ('Tajikistan', '2017', Decimal('8.93')),
#  ('Tajikistan', '2018', Decimal('9.13')),
#  ('Tajikistan', '2019', Decimal('9.34')),
#  ('Tajikistan', '2020', Decimal('9.54')),
#  ('Turkmenistan', '2015', Decimal('5.77')),
#  ('Turkmenistan', '2016', Decimal('5.87')),
#  ('Turkmenistan', '2017', Decimal('5.97')),
#  ('Turkmenistan', '2018', Decimal('6.07')),
#  ('Turkmenistan', '2019', Decimal('6.16')),
#  ('Turkmenistan', '2020', Decimal('6.25')),
#  ('Uzbekistan', '2015', Decimal('31.30')),
#  ('Uzbekistan', '2016', Decimal('31.85')),
#  ('Uzbekistan', '2017', Decimal('32.39')),
#  ('Uzbekistan', '2018', Decimal('32.96')),
#  ('Uzbekistan', '2019', Decimal('33.58')),
#  ('Uzbekistan', '2020', Decimal('34.23')),
#  ('Afghanistan', '2015', Decimal('33.75')),
#  ('Afghanistan', '2016', Decimal('34.64')),
#  ('Afghanistan', '2017', Decimal('35.64')),
#  ('Afghanistan', '2018', Decimal('36.69')),
#  ('Afghanistan', '2019', Decimal('37.77')),
#  ('Afghanistan', '2020', Decimal('38.97')),
#  ('Bangladesh', '2015', Decimal('157.83')),
#  ('Bangladesh', '2016', Decimal('159.78')),
#  ('Bangladesh', '2017', Decimal('161.79')),
#  ('Bangladesh', '2018', Decimal('163.68')),
#  ('Bangladesh', '2019', Decimal('165.52')),
#  ('Bangladesh', '2020', Decimal('167.42')),
#  ('Bhutan', '2015', Decimal('0.74')),
#  ('Bhutan', '2016', Decimal('0.75')),
#  ('Bhutan', '2017', Decimal('0.76')),
#  ('Bhutan', '2018', Decimal('0.76')),
#  ('Bhutan', '2019', Decimal('0.77')),
#  ('Bhutan', '2020', Decimal('0.77')),
#  ('India', '2015', Decimal('1322.87')),
#  ('India', '2016', Decimal('1338.64')),
#  ('India', '2017', Decimal('1354.20')),
#  ('India', '2018', Decimal('1369.00')),
#  ('India', '2019', Decimal('1383.11')),
#  ('India', '2020', Decimal('1396.39')),
#  ('Iran (Islamic Republic of)', '2015', Decimal('0.00')),
#  ('Iran (Islamic Republic of)', '2016', Decimal('0.00')),
#  ('Iran (Islamic Republic of)', '2017', Decimal('0.00')),
#  ('Iran (Islamic Republic of)', '2018', Decimal('0.00')),
#  ('Iran (Islamic Republic of)', '2019', Decimal('0.00')),
#  ('Iran (Islamic Republic of)', '2020', Decimal('0.00')),
#  ('Maldives', '2015', Decimal('0.44')),
#  ('Maldives', '2016', Decimal('0.45')),
#  ('Maldives', '2017', Decimal('0.47')),
#  ('Maldives', '2018', Decimal('0.49')),
#  ('Maldives', '2019', Decimal('0.50')),
#  ('Maldives', '2020', Decimal('0.51')),
#  ('Nepal', '2015', Decimal('27.61')),
#  ('Nepal', '2016', Decimal('27.86')),
#  ('Nepal', '2017', Decimal('28.18')),
#  ('Nepal', '2018', Decimal('28.51')),
#  ('Nepal', '2019', Decimal('28.83')),
#  ('Nepal', '2020', Decimal('29.35')),
#  ('Pakistan', '2015', Decimal('210.97')),
#  ('Pakistan', '2016', Decimal('213.52')),
#  ('Pakistan', '2017', Decimal('216.38')),
#  ('Pakistan', '2018', Decimal('219.73')),
#  ('Pakistan', '2019', Decimal('223.29')),
#  ('Pakistan', '2020', Decimal('227.20')),
#  ('Sri Lanka', '2015', Decimal('20.97')),
#  ('Sri Lanka', '2016', Decimal('21.20')),
#  ('Sri Lanka', '2017', Decimal('21.44')),
#  ('Sri Lanka', '2018', Decimal('21.67')),
#  ('Sri Lanka', '2019', Decimal('21.80')),
#  ('Sri Lanka', '2020', Decimal('21.92')),
#  ('China', '2015', Decimal('1379.86')),
#  ('China', '2016', Decimal('1387.79')),
#  ('China', '2017', Decimal('1396.22')),
#  ('China', '2018', Decimal('1402.76')),
#  ('China', '2019', Decimal('1407.75')),
#  ('China', '2020', Decimal('1411.10')),
#  ("Democratic People's Republic of Korea", '2015', Decimal('0.00')),
#  ("Democratic People's Republic of Korea", '2016', Decimal('0.00')),
#  ("Democratic People's Republic of Korea", '2017', Decimal('0.00')),
#  ("Democratic People's Republic of Korea", '2018', Decimal('0.00')),
#  ("Democratic People's Republic of Korea", '2019', Decimal('0.00')),
#  ("Democratic People's Republic of Korea", '2020', Decimal('0.00')),
#  ('Japan', '2015', Decimal('127.14')),
#  ('Japan', '2016', Decimal('127.08')),
#  ('Japan', '2017', Decimal('126.97')),
#  ('Japan', '2018', Decimal('126.81')),
#  ('Japan', '2019', Decimal('126.63')),
#  ('Japan', '2020', Decimal('126.26')),
#  ('Mongolia', '2015', Decimal('2.96')),
#  ('Mongolia', '2016', Decimal('3.03')),
#  ('Mongolia', '2017', Decimal('3.10')),
#  ('Mongolia', '2018', Decimal('3.16')),
#  ('Mongolia', '2019', Decimal('3.23')),
#  ('Mongolia', '2020', Decimal('3.29')),
#  ('Republic of Korea', '2015', Decimal('0.00')),
#  ('Republic of Korea', '2016', Decimal('0.00')),
#  ('Republic of Korea', '2017', Decimal('0.00')),
#  ('Republic of Korea', '2018', Decimal('0.00')),
#  ('Republic of Korea', '2019', Decimal('0.00')),
#  ('Republic of Korea', '2020', Decimal('0.00')),
#  ('Brunei Darussalam', '2015', Decimal('0.42')),
#  ('Brunei Darussalam', '2016', Decimal('0.43')),
#  ('Brunei Darussalam', '2017', Decimal('0.43')),
#  ('Brunei Darussalam', '2018', Decimal('0.43')),
#  ('Brunei Darussalam', '2019', Decimal('0.44')),
#  ('Brunei Darussalam', '2020', Decimal('0.44')),
#  ('Cambodia', '2015', Decimal('15.42')),
#  ('Cambodia', '2016', Decimal('15.62')),
#  ('Cambodia', '2017', Decimal('15.83')),
#  ('Cambodia', '2018', Decimal('16.03')),
#  ('Cambodia', '2019', Decimal('16.21')),
#  ('Cambodia', '2020', Decimal('16.40')),
#  ('Indonesia', '2015', Decimal('259.09')),
#  ('Indonesia', '2016', Decimal('261.85')),
#  ('Indonesia', '2017', Decimal('264.50')),
#  ('Indonesia', '2018', Decimal('267.07')),
#  ('Indonesia', '2019', Decimal('269.58')),
#  ('Indonesia', '2020', Decimal('271.86')),
#  ("Lao People's Democratic Republic", '2015', Decimal('0.00')),
#  ("Lao People's Democratic Republic", '2016', Decimal('0.00')),
#  ("Lao People's Democratic Republic", '2017', Decimal('0.00')),
#  ("Lao People's Democratic Republic", '2018', Decimal('0.00')),
#  ("Lao People's Democratic Republic", '2019', Decimal('0.00')),
#  ("Lao People's Democratic Republic", '2020', Decimal('0.00')),
#  ('Malaysia', '2015', Decimal('31.07')),
#  ('Malaysia', '2016', Decimal('31.53')),
#  ('Malaysia', '2017', Decimal('31.98')),
#  ('Malaysia', '2018', Decimal('32.40')),
#  ('Malaysia', '2019', Decimal('32.80')),
#  ('Malaysia', '2020', Decimal('33.20')),
#  ('Myanmar', '2015', Decimal('51.48')),
#  ('Myanmar', '2016', Decimal('51.89')),
#  ('Myanmar', '2017', Decimal('52.29')),
#  ('Myanmar', '2018', Decimal('52.67')),
#  ('Myanmar', '2019', Decimal('53.04')),
#  ('Myanmar', '2020', Decimal('53.42')),
#  ('Philippines', '2015', Decimal('103.03')),
#  ('Philippines', '2016', Decimal('104.88')),
#  ('Philippines', '2017', Decimal('106.74')),
#  ('Philippines', '2018', Decimal('108.57')),
#  ('Philippines', '2019', Decimal('110.38')),
#  ('Philippines', '2020', Decimal('112.19')),
#  ('Singapore', '2015', Decimal('5.54')),
#  ('Singapore', '2016', Decimal('5.61')),
#  ('Singapore', '2017', Decimal('5.61')),
#  ('Singapore', '2018', Decimal('5.64')),
#  ('Singapore', '2019', Decimal('5.70')),
#  ('Singapore', '2020', Decimal('5.69')),
#  ('Thailand', '2015', Decimal('70.29')),
#  ('Thailand', '2016', Decimal('70.61')),
#  ('Thailand', '2017', Decimal('70.90')),
#  ('Thailand', '2018', Decimal('71.13')),
#  ('Thailand', '2019', Decimal('71.31')),
#  ('Thailand', '2020', Decimal('71.48')),
#  ('Timor-Leste', '2015', Decimal('1.21')),
#  ('Timor-Leste', '2016', Decimal('1.22')),
#  ('Timor-Leste', '2017', Decimal('1.24')),
#  ('Timor-Leste', '2018', Decimal('1.26')),
#  ('Timor-Leste', '2019', Decimal('1.28')),
#  ('Timor-Leste', '2020', Decimal('1.30')),
#  ('Viet Nam', '2015', Decimal('0.00')),
#  ('Viet Nam', '2016', Decimal('0.00')),
#  ('Viet Nam', '2017', Decimal('0.00')),
#  ('Viet Nam', '2018', Decimal('0.00')),
#  ('Viet Nam', '2019', Decimal('0.00')),
#  ('Viet Nam', '2020', Decimal('0.00')),
#  ('Bermuda', '2015', Decimal('0.07')),
#  ('Bermuda', '2016', Decimal('0.06')),
#  ('Bermuda', '2017', Decimal('0.06')),
#  ('Bermuda', '2018', Decimal('0.06')),
#  ('Bermuda', '2019', Decimal('0.06')),
#  ('Bermuda', '2020', Decimal('0.06')),
#  ('Canada', '2015', Decimal('35.70')),
#  ('Canada', '2016', Decimal('36.11')),
#  ('Canada', '2017', Decimal('36.55')),
#  ('Canada', '2018', Decimal('37.07')),
#  ('Canada', '2019', Decimal('37.60')),
#  ('Canada', '2020', Decimal('38.04')),
#  ('Greenland', '2015', Decimal('0.06')),
#  ('Greenland', '2016', Decimal('0.06')),
#  ('Greenland', '2017', Decimal('0.06')),
#  ('Greenland', '2018', Decimal('0.06')),
#  ('Greenland', '2019', Decimal('0.06')),
#  ('Greenland', '2020', Decimal('0.06')),
#  ('Saint Pierre and Miquelon', '2015', Decimal('0.00')),
#  ('Saint Pierre and Miquelon', '2016', Decimal('0.00')),
#  ('Saint Pierre and Miquelon', '2017', Decimal('0.00')),
#  ('Saint Pierre and Miquelon', '2018', Decimal('0.00')),
#  ('Saint Pierre and Miquelon', '2019', Decimal('0.00')),
#  ('Saint Pierre and Miquelon', '2020', Decimal('0.00')),
#  ('United States of America', '2015', Decimal('0.00')),
#  ('United States of America', '2016', Decimal('0.00')),
#  ('United States of America', '2017', Decimal('0.00')),
#  ('United States of America', '2018', Decimal('0.00')),
#  ('United States of America', '2019', Decimal('0.00')),
#  ('United States of America', '2020', Decimal('0.00')),
#  ('Anguilla', '2015', Decimal('0.00')),
#  ('Anguilla', '2016', Decimal('0.00')),
#  ('Anguilla', '2017', Decimal('0.00')),
#  ('Antigua and Barbuda', '2015', Decimal('0.09')),
#  ('Antigua and Barbuda', '2016', Decimal('0.09')),
#  ('Antigua and Barbuda', '2017', Decimal('0.09')),
#  ('Aruba', '2015', Decimal('0.10')),
#  ('Aruba', '2016', Decimal('0.10')),
#  ('Bahamas', '2015', Decimal('0.00')),
#  ('Bahamas', '2016', Decimal('0.00')),
#  ('Bahamas', '2017', Decimal('0.00')),
#  ('Bahamas', '2018', Decimal('0.00')),
#  ('Bahamas', '2019', Decimal('0.00')),
#  ('Barbados', '2015', Decimal('0.28')),
#  ('Barbados', '2016', Decimal('0.28')),
#  ('Barbados', '2017', Decimal('0.28')),
#  ('Barbados', '2018', Decimal('0.28')),
#  ('Barbados', '2019', Decimal('0.28')),
#  ('Barbados', '2020', Decimal('0.28')),
#  ('British Virgin Islands', '2015', Decimal('0.03')),
#  ('British Virgin Islands', '2016', Decimal('0.03')),
#  ('British Virgin Islands', '2017', Decimal('0.03')),
#  ('British Virgin Islands', '2018', Decimal('0.03')),
#  ('British Virgin Islands', '2019', Decimal('0.03')),
#  ('British Virgin Islands', '2020', Decimal('0.03')),
#  ('Cayman Islands', '2015', Decimal('0.06')),
#  ('Cayman Islands', '2016', Decimal('0.06')),
#  ('Cuba', '2015', Decimal('11.34')),
#  ('Cuba', '2016', Decimal('11.34')),
#  ('Cuba', '2017', Decimal('11.34')),
#  ('Cuba', '2018', Decimal('11.33')),
#  ('Cuba', '2019', Decimal('11.32')),
#  ('Cuba', '2020', Decimal('11.30')),
#  ('Curaçao', '2015', Decimal('0.00')),
#  ('Curaçao', '2016', Decimal('0.00')),
#  ('Curaçao', '2017', Decimal('0.00')),
#  ('Dominica', '2015', Decimal('0.07')),
#  ('Dominica', '2016', Decimal('0.07')),
#  ('Dominica', '2017', Decimal('0.07')),
#  ('Dominican Republic', '2015', Decimal('10.41')),
#  ('Dominican Republic', '2016', Decimal('10.53')),
#  ('Dominican Republic', '2017', Decimal('10.65')),
#  ('Dominican Republic', '2018', Decimal('10.77')),
#  ('Dominican Republic', '2019', Decimal('10.88')),
#  ('Dominican Republic', '2020', Decimal('11.00')),
#  ('Grenada', '2015', Decimal('0.12')),
#  ('Grenada', '2016', Decimal('0.12')),
#  ('Grenada', '2017', Decimal('0.12')),
#  ('Guadeloupe', '2015', Decimal('0.00')),
#  ('Guadeloupe', '2016', Decimal('0.00')),
#  ('Guadeloupe', '2017', Decimal('0.00')),
#  ('Guadeloupe', '2018', Decimal('0.00')),
#  ('Guadeloupe', '2019', Decimal('0.00')),
#  ('Guadeloupe', '2020', Decimal('0.00')),
#  ('Haiti', '2015', Decimal('10.56')),
#  ('Haiti', '2016', Decimal('10.71')),
#  ('Haiti', '2017', Decimal('10.86')),
#  ('Haiti', '2018', Decimal('11.01')),
#  ('Haiti', '2019', Decimal('11.16')),
#  ('Haiti', '2020', Decimal('11.31')),
#  ('Jamaica', '2015', Decimal('2.79')),
#  ('Jamaica', '2016', Decimal('2.80')),
#  ('Jamaica', '2017', Decimal('2.81')),
#  ('Jamaica', '2018', Decimal('2.81')),
#  ('Jamaica', '2019', Decimal('2.81')),
#  ('Jamaica', '2020', Decimal('2.82')),
#  ('Martinique', '2015', Decimal('0.00')),
#  ('Martinique', '2016', Decimal('0.00')),
#  ('Martinique', '2017', Decimal('0.00')),
#  ('Martinique', '2018', Decimal('0.00')),
#  ('Martinique', '2019', Decimal('0.00')),
#  ('Martinique', '2020', Decimal('0.00')),
#  ('Montserrat', '2015', Decimal('0.00')),
#  ('Montserrat', '2016', Decimal('0.00')),
#  ('Montserrat', '2017', Decimal('0.00')),
#  ('Montserrat', '2018', Decimal('0.00')),
#  ('Montserrat', '2019', Decimal('0.00')),
#  ('Montserrat', '2020', Decimal('0.00')),
#  ('Puerto Rico', '2015', Decimal('3.47')),
#  ('Puerto Rico', '2016', Decimal('3.41')),
#  ('Puerto Rico', '2017', Decimal('3.33')),
#  ('Puerto Rico', '2018', Decimal('3.19')),
#  ('Puerto Rico', '2019', Decimal('3.19')),
#  ('Puerto Rico', '2020', Decimal('3.28')),
#  ('Saint Barthélemy', '2015', Decimal('0.00')),
#  ('Saint Barthélemy', '2016', Decimal('0.00')),
#  ('Saint Barthélemy', '2017', Decimal('0.00')),
#  ('Saint Barthélemy', '2018', Decimal('0.00')),
#  ('Saint Barthélemy', '2019', Decimal('0.00')),
#  ('Saint Barthélemy', '2020', Decimal('0.00')),
#  ('Saint Kitts and Nevis', '2015', Decimal('0.00')),
#  ('Saint Kitts and Nevis', '2016', Decimal('0.00')),
#  ('Saint Kitts and Nevis', '2017', Decimal('0.00')),
#  ('Saint Lucia', '2015', Decimal('0.00')),
#  ('Saint Lucia', '2016', Decimal('0.00')),
#  ('Saint Lucia', '2017', Decimal('0.00')),
#  ('Saint Lucia', '2018', Decimal('0.00')),
#  ('Saint Lucia', '2019', Decimal('0.00')),
#  ('Saint Lucia', '2020', Decimal('0.00')),
#  ('Saint Martin (French Part)', '2015', Decimal('0.00')),
#  ('Saint Martin (French Part)', '2016', Decimal('0.00')),
#  ('Saint Martin (French Part)', '2017', Decimal('0.00')),
#  ('Saint Martin (French Part)', '2018', Decimal('0.00')),
#  ('Saint Martin (French Part)', '2019', Decimal('0.00')),
#  ('Saint Martin (French Part)', '2020', Decimal('0.00')),
#  ('Saint Vincent and the Grenadines', '2015', Decimal('0.00')),
#  ('Saint Vincent and the Grenadines', '2016', Decimal('0.00')),
#  ('Saint Vincent and the Grenadines', '2017', Decimal('0.00')),
#  ('Saint Vincent and the Grenadines', '2018', Decimal('0.00')),
#  ('Sint Maarten (Dutch part)', '2015', Decimal('0.04')),
#  ('Sint Maarten (Dutch part)', '2016', Decimal('0.04')),
#  ('Sint Maarten (Dutch part)', '2017', Decimal('0.04')),
#  ('Trinidad and Tobago', '2015', Decimal('1.46')),
#  ('Trinidad and Tobago', '2016', Decimal('1.47')),
#  ('Trinidad and Tobago', '2017', Decimal('1.48')),
#  ('Trinidad and Tobago', '2018', Decimal('1.50')),
#  ('Trinidad and Tobago', '2019', Decimal('1.52')),
#  ('Trinidad and Tobago', '2020', Decimal('1.52')),
#  ('Turks and Caicos Islands', '2015', Decimal('0.04')),
#  ('Turks and Caicos Islands', '2016', Decimal('0.04')),
#  ('Turks and Caicos Islands', '2017', Decimal('0.04')),
#  ('Turks and Caicos Islands', '2018', Decimal('0.04')),
#  ('United States Virgin Islands', '2015', Decimal('0.00')),
#  ('United States Virgin Islands', '2016', Decimal('0.00')),
#  ('United States Virgin Islands', '2017', Decimal('0.00')),
#  ('United States Virgin Islands', '2018', Decimal('0.00')),
#  ('United States Virgin Islands', '2019', Decimal('0.00')),
#  ('United States Virgin Islands', '2020', Decimal('0.00')),
#  ('Belize', '2015', Decimal('0.36')),
#  ('Belize', '2016', Decimal('0.37')),
#  ('Belize', '2017', Decimal('0.37')),
#  ('Belize', '2018', Decimal('0.38')),
#  ('Belize', '2019', Decimal('0.39')),
#  ('Belize', '2020', Decimal('0.39')),
#  ('Costa Rica', '2015', Decimal('4.90')),
#  ('Costa Rica', '2016', Decimal('4.95')),
#  ('Costa Rica', '2017', Decimal('4.99')),
#  ('Costa Rica', '2018', Decimal('5.04')),
#  ('Costa Rica', '2019', Decimal('5.08')),
#  ('Costa Rica', '2020', Decimal('5.12')),
#  ('El Salvador', '2015', Decimal('6.23')),
#  ('El Salvador', '2016', Decimal('6.25')),
#  ('El Salvador', '2017', Decimal('6.27')),
#  ('El Salvador', '2018', Decimal('6.28')),
#  ('El Salvador', '2019', Decimal('6.28')),
#  ('El Salvador', '2020', Decimal('6.29')),
#  ('Guatemala', '2015', Decimal('15.57')),
#  ('Guatemala', '2016', Decimal('15.83')),
#  ('Guatemala', '2017', Decimal('16.09')),
#  ('Guatemala', '2018', Decimal('16.35')),
#  ('Guatemala', '2019', Decimal('16.60')),
#  ('Guatemala', '2020', Decimal('16.86')),
#  ('Honduras', '2015', Decimal('9.29')),
#  ('Honduras', '2016', Decimal('9.46')),
#  ('Honduras', '2017', Decimal('9.63')),
#  ('Honduras', '2018', Decimal('9.79')),
#  ('Honduras', '2019', Decimal('9.96')),
#  ('Honduras', '2020', Decimal('10.12')),
#  ('Mexico', '2015', Decimal('120.15')),
#  ('Mexico', '2016', Decimal('121.52')),
#  ('Mexico', '2017', Decimal('122.84')),
#  ('Mexico', '2018', Decimal('124.01')),
#  ('Mexico', '2019', Decimal('125.09')),
#  ('Mexico', '2020', Decimal('126.00')),
#  ('Nicaragua', '2015', Decimal('6.30')),
#  ('Nicaragua', '2016', Decimal('6.39')),
#  ('Nicaragua', '2017', Decimal('6.48')),
#  ('Nicaragua', '2018', Decimal('6.57')),
#  ('Nicaragua', '2019', Decimal('6.66')),
#  ('Nicaragua', '2020', Decimal('6.76')),
#  ('Panama', '2015', Decimal('3.96')),
#  ('Panama', '2016', Decimal('4.03')),
#  ('Panama', '2017', Decimal('4.10')),
#  ('Panama', '2018', Decimal('4.17')),
#  ('Panama', '2019', Decimal('4.23')),
#  ('Panama', '2020', Decimal('4.29')),
#  ('Argentina', '2015', Decimal('43.13')),
#  ('Argentina', '2016', Decimal('43.59')),
#  ('Argentina', '2017', Decimal('44.04')),
#  ('Argentina', '2018', Decimal('44.49')),
#  ('Argentina', '2019', Decimal('44.94')),
#  ('Argentina', '2020', Decimal('45.38')),
#  ('Bolivia (Plurinational State of)', '2015', Decimal('0.00')),
#  ('Bolivia (Plurinational State of)', '2016', Decimal('0.00')),
#  ('Bolivia (Plurinational State of)', '2017', Decimal('0.00')),
#  ('Bolivia (Plurinational State of)', '2018', Decimal('0.00')),
#  ('Bolivia (Plurinational State of)', '2019', Decimal('0.00')),
#  ('Bolivia (Plurinational State of)', '2020', Decimal('0.00')),
#  ('Brazil', '2015', Decimal('205.19')),
#  ('Brazil', '2016', Decimal('206.86')),
#  ('Brazil', '2017', Decimal('208.50')),
#  ('Brazil', '2018', Decimal('210.17')),
#  ('Brazil', '2019', Decimal('211.78')),
#  ('Brazil', '2020', Decimal('213.20')),
#  ('Chile', '2015', Decimal('17.87')),
#  ('Chile', '2016', Decimal('18.08')),
#  ('Chile', '2017', Decimal('18.37')),
#  ('Chile', '2018', Decimal('18.70')),
#  ('Chile', '2019', Decimal('19.04')),
#  ('Chile', '2020', Decimal('19.30')),
#  ('Colombia', '2015', Decimal('47.12')),
#  ('Colombia', '2016', Decimal('47.63')),
#  ('Colombia', '2017', Decimal('48.35')),
#  ('Colombia', '2018', Decimal('49.28')),
#  ('Colombia', '2019', Decimal('50.19')),
#  ('Colombia', '2020', Decimal('50.93')),
#  ('Ecuador', '2015', Decimal('16.20')),
#  ('Ecuador', '2016', Decimal('16.44')),
#  ('Ecuador', '2017', Decimal('16.70')),
#  ('Ecuador', '2018', Decimal('17.02')),
#  ('Ecuador', '2019', Decimal('17.34')),
#  ('Ecuador', '2020', Decimal('17.59')),
#  ('Falkland Islands (Malvinas)', '2015', Decimal('0.00')),
#  ('Falkland Islands (Malvinas)', '2016', Decimal('0.00')),
#  ('Falkland Islands (Malvinas)', '2017', Decimal('0.00')),
#  ('Falkland Islands (Malvinas)', '2018', Decimal('0.00')),
#  ('Falkland Islands (Malvinas)', '2019', Decimal('0.00')),
#  ('Falkland Islands (Malvinas)', '2020', Decimal('0.00')),
#  ('French Guiana', '2015', Decimal('0.00')),
#  ('French Guiana', '2016', Decimal('0.00')),
#  ('French Guiana', '2017', Decimal('0.00')),
#  ('French Guiana', '2018', Decimal('0.00')),
#  ('French Guiana', '2019', Decimal('0.00')),
#  ('French Guiana', '2020', Decimal('0.00')),
#  ('Guyana', '2015', Decimal('0.76')),
#  ('Guyana', '2016', Decimal('0.76')),
#  ('Guyana', '2017', Decimal('0.76')),
#  ('Guyana', '2018', Decimal('0.79')),
#  ('Guyana', '2019', Decimal('0.80')),
#  ('Guyana', '2020', Decimal('0.80')),
#  ('Paraguay', '2015', Decimal('6.18')),
#  ('Paraguay', '2016', Decimal('6.27')),
#  ('Paraguay', '2017', Decimal('6.36')),
#  ('Paraguay', '2018', Decimal('6.44')),
#  ('Paraguay', '2019', Decimal('6.53')),
#  ('Paraguay', '2020', Decimal('6.62')),
#  ('Peru', '2015', Decimal('30.71')),
#  ('Peru', '2016', Decimal('31.13')),
#  ('Peru', '2017', Decimal('31.61')),
#  ('Peru', '2018', Decimal('32.20')),
#  ('Peru', '2019', Decimal('32.82')),
#  ('Peru', '2020', Decimal('33.30')),
#  ('Suriname', '2015', Decimal('0.58')),
#  ('Suriname', '2016', Decimal('0.58')),
#  ('Suriname', '2017', Decimal('0.59')),
#  ('Suriname', '2018', Decimal('0.59')),
#  ('Suriname', '2019', Decimal('0.60')),
#  ('Suriname', '2020', Decimal('0.61')),
#  ('Uruguay', '2015', Decimal('3.40')),
#  ('Uruguay', '2016', Decimal('3.41')),
#  ('Uruguay', '2017', Decimal('3.42')),
#  ('Uruguay', '2018', Decimal('3.43')),
#  ('Uruguay', '2019', Decimal('3.43')),
#  ('Uruguay', '2020', Decimal('3.43')),
#  ('Venezuela (Bolivarian Republic of)', '2015', Decimal('0.00')),
#  ('Venezuela (Bolivarian Republic of)', '2016', Decimal('0.00')),
#  ('Venezuela (Bolivarian Republic of)', '2017', Decimal('0.00')),
#  ('Venezuela (Bolivarian Republic of)', '2018', Decimal('0.00')),
#  ('Venezuela (Bolivarian Republic of)', '2019', Decimal('0.00')),
#  ('Venezuela (Bolivarian Republic of)', '2020', Decimal('0.00')),
#  ('Algeria', '2015', Decimal('39.54')),
#  ('Algeria', '2016', Decimal('40.34')),
#  ('Algeria', '2017', Decimal('41.14')),
#  ('Algeria', '2018', Decimal('41.93')),
#  ('Algeria', '2019', Decimal('42.71')),
#  ('Algeria', '2020', Decimal('43.45')),
#  ('Egypt', '2015', Decimal('0.00')),
#  ('Egypt', '2016', Decimal('0.00')),
#  ('Egypt', '2017', Decimal('0.00')),
#  ('Egypt', '2018', Decimal('0.00')),
#  ('Egypt', '2019', Decimal('0.00')),
#  ('Egypt', '2020', Decimal('0.00')),
#  ('Libya', '2015', Decimal('6.19')),
#  ('Libya', '2016', Decimal('6.28')),
#  ('Libya', '2017', Decimal('6.38')),
#  ('Libya', '2018', Decimal('6.48')),
#  ('Libya', '2019', Decimal('6.57')),
#  ('Libya', '2020', Decimal('6.65')),
#  ('Morocco', '2015', Decimal('34.68')),
#  ('Morocco', '2016', Decimal('35.11')),
#  ('Morocco', '2017', Decimal('35.53')),
#  ('Morocco', '2018', Decimal('35.93')),
#  ('Morocco', '2019', Decimal('36.30')),
#  ('Morocco', '2020', Decimal('36.69')),
#  ('Sudan', '2015', Decimal('38.17')),
#  ('Sudan', '2016', Decimal('39.38')),
#  ('Sudan', '2017', Decimal('40.68')),
#  ('Sudan', '2018', Decimal('42.00')),
#  ('Sudan', '2019', Decimal('43.23')),
#  ('Sudan', '2020', Decimal('44.44')),
#  ('Tunisia', '2015', Decimal('11.56')),
#  ('Tunisia', '2016', Decimal('11.69')),
#  ('Tunisia', '2017', Decimal('11.81')),
#  ('Tunisia', '2018', Decimal('11.93')),
#  ('Tunisia', '2019', Decimal('12.05')),
#  ('Tunisia', '2020', Decimal('12.16')),
#  ('Armenia', '2015', Decimal('2.88')),
#  ('Armenia', '2016', Decimal('2.87')),
#  ('Armenia', '2017', Decimal('2.85')),
#  ('Armenia', '2018', Decimal('2.84')),
#  ('Armenia', '2019', Decimal('2.82')),
#  ('Armenia', '2020', Decimal('2.81')),
#  ('Azerbaijan', '2015', Decimal('9.65')),
#  ('Azerbaijan', '2016', Decimal('9.76')),
#  ('Azerbaijan', '2017', Decimal('9.85')),
#  ('Azerbaijan', '2018', Decimal('9.94')),
#  ('Azerbaijan', '2019', Decimal('10.02')),
#  ('Azerbaijan', '2020', Decimal('10.09')),
#  ('Bahrain', '2015', Decimal('1.36')),
#  ('Bahrain', '2016', Decimal('1.41')),
#  ('Bahrain', '2017', Decimal('1.46')),
#  ('Bahrain', '2018', Decimal('1.49')),
#  ('Bahrain', '2019', Decimal('1.49')),
#  ('Bahrain', '2020', Decimal('1.48')),
#  ('Cyprus', '2015', Decimal('1.19')),
#  ('Cyprus', '2016', Decimal('1.20')),
#  ('Cyprus', '2017', Decimal('1.21')),
#  ('Cyprus', '2018', Decimal('1.22')),
#  ('Cyprus', '2019', Decimal('1.23')),
#  ('Cyprus', '2020', Decimal('1.24')),
#  ('Georgia', '2015', Decimal('3.73')),
#  ('Georgia', '2016', Decimal('3.73')),
#  ('Georgia', '2017', Decimal('3.73')),
#  ('Georgia', '2018', Decimal('3.73')),
#  ('Georgia', '2019', Decimal('3.72')),
#  ('Georgia', '2020', Decimal('3.72')),
#  ('Iraq', '2015', Decimal('37.76')),
#  ('Iraq', '2016', Decimal('38.70')),
#  ('Iraq', '2017', Decimal('39.62')),
#  ('Iraq', '2018', Decimal('40.59')),
#  ('Iraq', '2019', Decimal('41.56')),
#  ('Iraq', '2020', Decimal('42.56')),
#  ('Israel', '2015', Decimal('8.38')),
#  ('Israel', '2016', Decimal('8.55')),
#  ('Israel', '2017', Decimal('8.71')),
#  ('Israel', '2018', Decimal('8.88')),
#  ('Israel', '2019', Decimal('9.05')),
#  ('Israel', '2020', Decimal('9.22')),
#  ('Jordan', '2015', Decimal('9.49')),
#  ('Jordan', '2016', Decimal('9.96')),
#  ('Jordan', '2017', Decimal('10.22')),
#  ('Jordan', '2018', Decimal('10.46')),
#  ('Jordan', '2019', Decimal('10.70')),
#  ('Jordan', '2020', Decimal('10.93')),
#  ('Kuwait', '2015', Decimal('3.91')),
#  ('Kuwait', '2016', Decimal('4.05')),
#  ('Kuwait', '2017', Decimal('4.12')),
#  ('Kuwait', '2018', Decimal('4.32')),
#  ('Kuwait', '2019', Decimal('4.44')),
#  ('Kuwait', '2020', Decimal('4.36')),
#  ('Lebanon', '2015', Decimal('6.40')),
#  ('Lebanon', '2016', Decimal('6.26')),
#  ('Lebanon', '2017', Decimal('6.11')),
#  ('Lebanon', '2018', Decimal('5.95')),
#  ('Lebanon', '2019', Decimal('5.78')),
#  ('Lebanon', '2020', Decimal('5.66')),
#  ('Oman', '2015', Decimal('4.19')),
#  ('Oman', '2016', Decimal('4.40')),
#  ('Oman', '2017', Decimal('4.54')),
#  ('Oman', '2018', Decimal('4.60')),
#  ('Oman', '2019', Decimal('4.60')),
#  ('Oman', '2020', Decimal('4.54')),
#  ('Qatar', '2015', Decimal('2.41')),
#  ('Qatar', '2016', Decimal('2.60')),
#  ('Qatar', '2017', Decimal('2.71')),
#  ('Qatar', '2018', Decimal('2.77')),
#  ('Qatar', '2019', Decimal('2.81')),
#  ('Qatar', '2020', Decimal('2.76')),
#  ('Saudi Arabia', '2015', Decimal('32.75')),
#  ('Saudi Arabia', '2016', Decimal('33.42')),
#  ('Saudi Arabia', '2017', Decimal('34.19')),
#  ('Saudi Arabia', '2018', Decimal('35.02')),
#  ('Saudi Arabia', '2019', Decimal('35.83')),
#  ('Saudi Arabia', '2020', Decimal('36.00')),
#  ('State of Palestine', '2015', Decimal('0.00')),
#  ('State of Palestine', '2016', Decimal('0.00')),
#  ('State of Palestine', '2017', Decimal('0.00')),
#  ('State of Palestine', '2018', Decimal('0.00')),
#  ('State of Palestine', '2019', Decimal('0.00')),
#  ('State of Palestine', '2020', Decimal('0.00')),
#  ('Syrian Arab Republic', '2015', Decimal('19.21')),
#  ('Syrian Arab Republic', '2016', Decimal('18.96')),
#  ('Syrian Arab Republic', '2017', Decimal('18.98')),
#  ('Syrian Arab Republic', '2018', Decimal('19.33')),
#  ('Syrian Arab Republic', '2019', Decimal('20.10')),
#  ('Syrian Arab Republic', '2020', Decimal('20.77')),
#  ('Türkiye', '2015', Decimal('0.00')),
#  ('Türkiye', '2016', Decimal('0.00')),
#  ('Türkiye', '2017', Decimal('0.00')),
#  ('Türkiye', '2018', Decimal('0.00')),
#  ('Türkiye', '2019', Decimal('0.00')),
#  ('Türkiye', '2020', Decimal('0.00')),
#  ('United Arab Emirates', '2015', Decimal('8.92')),
#  ('United Arab Emirates', '2016', Decimal('8.99')),
#  ('United Arab Emirates', '2017', Decimal('9.07')),
#  ('United Arab Emirates', '2018', Decimal('9.14')),
#  ('United Arab Emirates', '2019', Decimal('9.21')),
#  ('United Arab Emirates', '2020', Decimal('9.29')),
#  ('Yemen', '2015', Decimal('0.00')),
#  ('Yemen', '2016', Decimal('0.00')),
#  ('Yemen', '2017', Decimal('0.00')),
#  ('Yemen', '2018', Decimal('0.00')),
#  ('Yemen', '2019', Decimal('0.00')),
#  ('Yemen', '2020', Decimal('0.00')),
#  ('Australia', '2015', Decimal('23.82')),
#  ('Australia', '2016', Decimal('24.19')),
#  ('Australia', '2017', Decimal('24.59')),
#  ('Australia', '2018', Decimal('24.97')),
#  ('Australia', '2019', Decimal('25.34')),
#  ('Australia', '2020', Decimal('25.66')),
#  ('New Zealand', '2015', Decimal('4.61')),
#  ('New Zealand', '2016', Decimal('4.71')),
#  ('New Zealand', '2017', Decimal('4.81')),
#  ('New Zealand', '2018', Decimal('4.90')),
#  ('New Zealand', '2019', Decimal('4.98')),
#  ('New Zealand', '2020', Decimal('5.09')),
#  ('Fiji', '2015', Decimal('0.92')),
#  ('Fiji', '2016', Decimal('0.92')),
#  ('Fiji', '2017', Decimal('0.92')),
#  ('Fiji', '2018', Decimal('0.92')),
#  ('Fiji', '2019', Decimal('0.92')),
#  ('Fiji', '2020', Decimal('0.92')),
#  ('New Caledonia', '2015', Decimal('0.27')),
#  ('New Caledonia', '2016', Decimal('0.27')),
#  ('New Caledonia', '2017', Decimal('0.27')),
#  ('New Caledonia', '2018', Decimal('0.27')),
#  ('New Caledonia', '2019', Decimal('0.27')),
#  ('New Caledonia', '2020', Decimal('0.27')),
#  ('Papua New Guinea', '2015', Decimal('8.68')),
#  ('Papua New Guinea', '2016', Decimal('8.90')),
#  ('Papua New Guinea', '2017', Decimal('9.11')),
#  ('Papua New Guinea', '2018', Decimal('9.33')),
#  ('Papua New Guinea', '2019', Decimal('9.54')),
#  ('Papua New Guinea', '2020', Decimal('9.75')),
#  ('Solomon Islands', '2015', Decimal('0.61')),
#  ('Solomon Islands', '2016', Decimal('0.63')),
#  ('Solomon Islands', '2017', Decimal('0.64')),
#  ('Solomon Islands', '2018', Decimal('0.66')),
#  ('Solomon Islands', '2019', Decimal('0.67')),
#  ('Solomon Islands', '2020', Decimal('0.69')),
#  ('Vanuatu', '2015', Decimal('0.28')),
#  ('Vanuatu', '2016', Decimal('0.28')),
#  ('Vanuatu', '2017', Decimal('0.29')),
#  ('Vanuatu', '2018', Decimal('0.30')),
#  ('Vanuatu', '2019', Decimal('0.30')),
#  ('Vanuatu', '2020', Decimal('0.31')),
#  ('Guam', '2015', Decimal('0.17')),
#  ('Guam', '2016', Decimal('0.17')),
#  ('Guam', '2017', Decimal('0.17')),
#  ('Guam', '2018', Decimal('0.17')),
#  ('Guam', '2019', Decimal('0.17')),
#  ('Guam', '2020', Decimal('0.17')),
#  ('Kiribati', '2015', Decimal('0.12')),
#  ('Kiribati', '2016', Decimal('0.12')),
#  ('Kiribati', '2017', Decimal('0.12')),
#  ('Kiribati', '2018', Decimal('0.12')),
#  ('Kiribati', '2019', Decimal('0.12')),
#  ('Kiribati', '2020', Decimal('0.13')),
#  ('Marshall Islands', '2015', Decimal('0.05')),
#  ('Marshall Islands', '2016', Decimal('0.05')),
#  ('Marshall Islands', '2017', Decimal('0.05')),
#  ('Marshall Islands', '2018', Decimal('0.05')),
#  ('Marshall Islands', '2019', Decimal('0.04')),
#  ('Marshall Islands', '2020', Decimal('0.04')),
#  ('Micronesia (Federated States of)', '2015', Decimal('0.00')),
#  ('Micronesia (Federated States of)', '2016', Decimal('0.00')),
#  ('Micronesia (Federated States of)', '2017', Decimal('0.00')),
#  ('Micronesia (Federated States of)', '2018', Decimal('0.00')),
#  ('Micronesia (Federated States of)', '2019', Decimal('0.00')),
#  ('Nauru', '2015', Decimal('0.01')),
#  ('Nauru', '2016', Decimal('0.01')),
#  ('Nauru', '2017', Decimal('0.01')),
#  ('Nauru', '2018', Decimal('0.01')),
#  ('Nauru', '2019', Decimal('0.01')),
#  ('Nauru', '2020', Decimal('0.01')),
#  ('Northern Mariana Islands', '2015', Decimal('0.05')),
#  ('Northern Mariana Islands', '2016', Decimal('0.05')),
#  ('Northern Mariana Islands', '2017', Decimal('0.05')),
#  ('Northern Mariana Islands', '2018', Decimal('0.05')),
#  ('Northern Mariana Islands', '2019', Decimal('0.05')),
#  ('Northern Mariana Islands', '2020', Decimal('0.05')),
#  ('Palau', '2015', Decimal('0.02')),
#  ('Palau', '2016', Decimal('0.02')),
#  ('Palau', '2017', Decimal('0.02')),
#  ('Palau', '2018', Decimal('0.02')),
#  ('Palau', '2019', Decimal('0.02')),
#  ('Palau', '2020', Decimal('0.02')),
#  ('American Samoa', '2015', Decimal('0.05')),
#  ('American Samoa', '2016', Decimal('0.05')),
#  ('American Samoa', '2017', Decimal('0.05')),
#  ('American Samoa', '2018', Decimal('0.05')),
#  ('American Samoa', '2019', Decimal('0.05')),
#  ('American Samoa', '2020', Decimal('0.05')),
#  ('Cook Islands', '2015', Decimal('0.00')),
#  ('Cook Islands', '2016', Decimal('0.00')),
#  ('Cook Islands', '2017', Decimal('0.00')),
#  ('Cook Islands', '2018', Decimal('0.00')),
#  ('Cook Islands', '2019', Decimal('0.00')),
#  ('Cook Islands', '2020', Decimal('0.00')),
#  ('French Polynesia', '2015', Decimal('0.29')),
#  ('French Polynesia', '2016', Decimal('0.29')),
#  ('French Polynesia', '2017', Decimal('0.30')),
#  ('French Polynesia', '2018', Decimal('0.30')),
#  ('French Polynesia', '2019', Decimal('0.30')),
#  ('French Polynesia', '2020', Decimal('0.30')),
#  ('Niue', '2015', Decimal('0.00')),
#  ('Niue', '2016', Decimal('0.00')),
#  ('Niue', '2017', Decimal('0.00')),
#  ('Niue', '2018', Decimal('0.00')),
#  ('Niue', '2019', Decimal('0.00')),
#  ('Niue', '2020', Decimal('0.00')),
#  ('Samoa', '2015', Decimal('0.20')),
#  ('Samoa', '2016', Decimal('0.21')),
#  ('Samoa', '2017', Decimal('0.21')),
#  ('Samoa', '2018', Decimal('0.21')),
#  ('Samoa', '2019', Decimal('0.21')),
#  ('Samoa', '2020', Decimal('0.21')),
#  ('Tokelau', '2015', Decimal('0.00')),
#  ('Tokelau', '2016', Decimal('0.00')),
#  ('Tokelau', '2017', Decimal('0.00')),
#  ('Tokelau', '2018', Decimal('0.00')),
#  ('Tokelau', '2019', Decimal('0.00')),
#  ('Tokelau', '2020', Decimal('0.00')),
#  ('Tonga', '2015', Decimal('0.11')),
#  ('Tonga', '2016', Decimal('0.11')),
#  ('Tonga', '2017', Decimal('0.11')),
#  ('Tonga', '2018', Decimal('0.11')),
#  ('Tonga', '2019', Decimal('0.10')),
#  ('Tonga', '2020', Decimal('0.11')),
#  ('Tuvalu', '2015', Decimal('0.01')),
#  ('Tuvalu', '2016', Decimal('0.01')),
#  ('Tuvalu', '2017', Decimal('0.01')),
#  ('Tuvalu', '2018', Decimal('0.01')),
#  ('Tuvalu', '2019', Decimal('0.01')),
#  ('Tuvalu', '2020', Decimal('0.01')),
#  ('Wallis and Futuna Islands', '2015', Decimal('0.00')),
#  ('Wallis and Futuna Islands', '2016', Decimal('0.00')),
#  ('Wallis and Futuna Islands', '2017', Decimal('0.00')),
#  ('Wallis and Futuna Islands', '2018', Decimal('0.00')),
#  ('Wallis and Futuna Islands', '2019', Decimal('0.00')),
#  ('Wallis and Futuna Islands', '2020', Decimal('0.00')),
#  ('Burundi', '2015', Decimal('10.73')),
#  ('Burundi', '2016', Decimal('10.90')),
#  ('Burundi', '2017', Decimal('11.16')),
#  ('Burundi', '2018', Decimal('11.49')),
#  ('Burundi', '2019', Decimal('11.87')),
#  ('Burundi', '2020', Decimal('12.22')),
#  ('Comoros', '2015', Decimal('0.73')),
#  ('Comoros', '2016', Decimal('0.75')),
#  ('Comoros', '2017', Decimal('0.76')),
#  ('Comoros', '2018', Decimal('0.78')),
#  ('Comoros', '2019', Decimal('0.79')),
#  ('Djibouti', '2015', Decimal('1.01')),
#  ('Djibouti', '2016', Decimal('1.02')),
#  ('Djibouti', '2017', Decimal('1.04')),
#  ('Djibouti', '2018', Decimal('1.06')),
#  ('Djibouti', '2019', Decimal('1.07')),
#  ('Djibouti', '2020', Decimal('1.09')),
#  ('Eritrea', '2015', Decimal('3.34')),
#  ('Eritrea', '2016', Decimal('3.37')),
#  ('Ethiopia', '2015', Decimal('102.47')),
#  ('Ethiopia', '2016', Decimal('105.29')),
#  ('Ethiopia', '2017', Decimal('108.20')),
#  ('Ethiopia', '2018', Decimal('111.13')),
#  ('Ethiopia', '2019', Decimal('114.12')),
#  ('Ethiopia', '2020', Decimal('117.19')),
#  ('Kenya', '2015', Decimal('46.85')),
#  ('Kenya', '2016', Decimal('47.89')),
#  ('Kenya', '2017', Decimal('48.95')),
#  ('Kenya', '2018', Decimal('49.95')),
#  ('Kenya', '2019', Decimal('50.95')),
#  ('Kenya', '2020', Decimal('51.99')),
#  ('Madagascar', '2015', Decimal('24.85')),
#  ('Madagascar', '2016', Decimal('25.50')),
#  ('Madagascar', '2017', Decimal('26.17')),
#  ('Madagascar', '2018', Decimal('26.85')),
#  ('Madagascar', '2019', Decimal('27.53')),
#  ('Madagascar', '2020', Decimal('28.23')),
#  ('Malawi', '2015', Decimal('16.94')),
#  ('Malawi', '2016', Decimal('17.41')),
#  ('Malawi', '2017', Decimal('17.88')),
#  ('Malawi', '2018', Decimal('18.37')),
#  ('Malawi', '2019', Decimal('18.87')),
#  ('Malawi', '2020', Decimal('19.38')),
#  ('Mauritius', '2015', Decimal('1.26')),
#  ('Mauritius', '2016', Decimal('1.26')),
#  ('Mauritius', '2017', Decimal('1.26')),
#  ('Mauritius', '2018', Decimal('1.27')),
#  ('Mauritius', '2019', Decimal('1.27')),
#  ('Mauritius', '2020', Decimal('1.27')),
#  ('Mayotte', '2015', Decimal('0.00')),
#  ('Mayotte', '2016', Decimal('0.00')),
#  ('Mayotte', '2017', Decimal('0.00')),
#  ('Mayotte', '2018', Decimal('0.00')),
#  ('Mayotte', '2019', Decimal('0.00')),
#  ('Mayotte', '2020', Decimal('0.00')),
#  ('Mozambique', '2015', Decimal('26.84')),
#  ('Mozambique', '2016', Decimal('27.70')),
#  ('Mozambique', '2017', Decimal('28.57')),
#  ('Mozambique', '2018', Decimal('29.42')),
#  ('Mozambique', '2019', Decimal('30.29')),
#  ('Mozambique', '2020', Decimal('31.18')),
#  ('Rwanda', '2015', Decimal('11.64')),
#  ('Rwanda', '2016', Decimal('11.93')),
#  ('Rwanda', '2017', Decimal('12.23')),
#  ('Rwanda', '2018', Decimal('12.53')),
#  ('Rwanda', '2019', Decimal('12.84')),
#  ('Rwanda', '2020', Decimal('13.15')),
#  ('Réunion', '2015', Decimal('0.00')),
#  ('Réunion', '2016', Decimal('0.00')),
#  ('Réunion', '2017', Decimal('0.00')),
#  ('Réunion', '2018', Decimal('0.00')),
#  ('Réunion', '2019', Decimal('0.00')),
#  ('Réunion', '2020', Decimal('0.00')),
#  ('Seychelles', '2015', Decimal('0.09')),
#  ('Seychelles', '2016', Decimal('0.09')),
#  ('Seychelles', '2017', Decimal('0.10')),
#  ('Seychelles', '2018', Decimal('0.10')),
#  ('Seychelles', '2019', Decimal('0.10')),
#  ('Somalia', '2015', Decimal('13.76')),
#  ('Somalia', '2016', Decimal('14.29')),
#  ('Somalia', '2017', Decimal('14.86')),
#  ('Somalia', '2018', Decimal('15.41')),
#  ('Somalia', '2019', Decimal('15.98')),
#  ('Somalia', '2020', Decimal('16.54')),
#  ('South Sudan', '2015', Decimal('11.19')),
#  ('South Sudan', '2016', Decimal('11.07')),
#  ('South Sudan', '2017', Decimal('10.66')),
#  ('South Sudan', '2018', Decimal('10.40')),
#  ('South Sudan', '2019', Decimal('10.45')),
#  ('South Sudan', '2020', Decimal('10.61')),
#  ('Uganda', '2015', Decimal('37.48')),
#  ('Uganda', '2016', Decimal('38.75')),
#  ('Uganda', '2017', Decimal('40.13')),
#  ('Uganda', '2018', Decimal('41.52')),
#  ('Uganda', '2019', Decimal('42.95')),
#  ('Uganda', '2020', Decimal('44.40')),
#  ('United Republic of Tanzania', '2015', Decimal('0.00')),
#  ('United Republic of Tanzania', '2016', Decimal('0.00')),
#  ('United Republic of Tanzania', '2017', Decimal('0.00')),
#  ('United Republic of Tanzania', '2018', Decimal('0.00')),
#  ('United Republic of Tanzania', '2019', Decimal('0.00')),
#  ('United Republic of Tanzania', '2020', Decimal('0.00')),
#  ('Zambia', '2015', Decimal('16.25')),
#  ('Zambia', '2016', Decimal('16.77')),
#  ('Zambia', '2017', Decimal('17.30')),
#  ('Zambia', '2018', Decimal('17.84')),
#  ('Zambia', '2019', Decimal('18.38')),
#  ('Zambia', '2020', Decimal('18.93')),
#  ('Zimbabwe', '2015', Decimal('14.15')),
#  ('Zimbabwe', '2016', Decimal('14.45')),
#  ('Zimbabwe', '2017', Decimal('14.75')),
#  ('Zimbabwe', '2018', Decimal('15.05')),
#  ('Zimbabwe', '2019', Decimal('15.35')),
#  ('Zimbabwe', '2020', Decimal('15.67')),
#  ('Angola', '2015', Decimal('28.13')),
#  ('Angola', '2016', Decimal('29.15')),
#  ('Angola', '2017', Decimal('30.21')),
#  ('Angola', '2018', Decimal('31.27')),
#  ('Angola', '2019', Decimal('32.35')),
#  ('Angola', '2020', Decimal('33.43')),
#  ('Cameroon', '2015', Decimal('23.01')),
#  ('Cameroon', '2016', Decimal('23.71')),
#  ('Cameroon', '2017', Decimal('24.39')),
#  ('Cameroon', '2018', Decimal('25.08')),
#  ('Cameroon', '2019', Decimal('25.78')),
#  ('Cameroon', '2020', Decimal('26.49')),
#  ('Central African Republic', '2015', Decimal('4.82')),
#  ('Central African Republic', '2016', Decimal('4.90')),
#  ('Central African Republic', '2017', Decimal('5.00')),
#  ('Central African Republic', '2018', Decimal('5.09')),
#  ('Central African Republic', '2019', Decimal('5.21')),
#  ('Central African Republic', '2020', Decimal('5.34')),
#  ('Chad', '2015', Decimal('14.14')),
#  ('Chad', '2016', Decimal('14.59')),
#  ('Chad', '2017', Decimal('15.09')),
#  ('Chad', '2018', Decimal('15.60')),
#  ('Chad', '2019', Decimal('16.13')),
#  ('Chad', '2020', Decimal('16.64')),
#  ('Congo', '2015', Decimal('0.00')),
#  ('Congo', '2016', Decimal('0.00')),
#  ('Congo', '2017', Decimal('0.00')),
#  ('Congo', '2018', Decimal('0.00')),
#  ('Congo', '2019', Decimal('0.00')),
#  ('Congo', '2020', Decimal('0.00')),
#  ('Democratic Republic of the Congo', '2015', Decimal('0.00')),
#  ('Democratic Republic of the Congo', '2016', Decimal('0.00')),
#  ('Democratic Republic of the Congo', '2017', Decimal('0.00')),
#  ('Democratic Republic of the Congo', '2018', Decimal('0.00')),
#  ('Democratic Republic of the Congo', '2019', Decimal('0.00')),
#  ('Democratic Republic of the Congo', '2020', Decimal('0.00')),
#  ('Equatorial Guinea', '2015', Decimal('1.35')),
#  ('Equatorial Guinea', '2016', Decimal('1.40')),
#  ('Equatorial Guinea', '2017', Decimal('1.45')),
#  ('Gabon', '2015', Decimal('2.03')),
#  ('Gabon', '2016', Decimal('2.09')),
#  ('Gabon', '2017', Decimal('2.14')),
#  ('Gabon', '2018', Decimal('2.19')),
#  ('Gabon', '2019', Decimal('2.24')),
#  ('Gabon', '2020', Decimal('2.29')),
#  ('Sao Tome and Principe', '2015', Decimal('0.20')),
#  ('Sao Tome and Principe', '2016', Decimal('0.20')),
#  ('Sao Tome and Principe', '2017', Decimal('0.21')),
#  ('Sao Tome and Principe', '2018', Decimal('0.21')),
#  ('Sao Tome and Principe', '2019', Decimal('0.21')),
#  ('Sao Tome and Principe', '2020', Decimal('0.22')),
#  ('Botswana', '2015', Decimal('2.31')),
#  ('Botswana', '2016', Decimal('2.35')),
#  ('Botswana', '2017', Decimal('2.40')),
#  ('Botswana', '2018', Decimal('2.45')),
#  ('Botswana', '2019', Decimal('2.50')),
#  ('Botswana', '2020', Decimal('2.55')),
#  ('Eswatini', '2015', Decimal('1.13')),
#  ('Eswatini', '2016', Decimal('1.14')),
#  ('Eswatini', '2017', Decimal('1.15')),
#  ('Eswatini', '2018', Decimal('1.16')),
#  ('Eswatini', '2019', Decimal('1.17')),
#  ('Eswatini', '2020', Decimal('1.18')),
#  ('Lesotho', '2015', Decimal('2.12')),
#  ('Lesotho', '2016', Decimal('2.14')),
#  ('Lesotho', '2017', Decimal('2.17')),
#  ('Lesotho', '2018', Decimal('2.20')),
#  ('Lesotho', '2019', Decimal('2.23')),
#  ('Lesotho', '2020', Decimal('2.25')),
#  ('Namibia', '2015', Decimal('2.28')),
#  ('Namibia', '2016', Decimal('2.32')),
#  ('Namibia', '2017', Decimal('2.36')),
#  ('Namibia', '2018', Decimal('2.41')),
#  ('Namibia', '2019', Decimal('2.45')),
#  ('Namibia', '2020', Decimal('2.49')),
#  ('South Africa', '2015', Decimal('55.88')),
#  ('South Africa', '2016', Decimal('56.42')),
#  ('South Africa', '2017', Decimal('56.64')),
#  ('South Africa', '2018', Decimal('57.34')),
#  ('South Africa', '2019', Decimal('58.09')),
#  ('South Africa', '2020', Decimal('58.80')),
#  ('Benin', '2015', Decimal('10.93')),
#  ('Benin', '2016', Decimal('11.26')),
#  ('Benin', '2017', Decimal('11.60')),
#  ('Benin', '2018', Decimal('11.94')),
#  ('Benin', '2019', Decimal('12.29')),
#  ('Benin', '2020', Decimal('12.64')),
#  ('Burkina Faso', '2015', Decimal('18.72')),
#  ('Burkina Faso', '2016', Decimal('19.28')),
#  ('Burkina Faso', '2017', Decimal('19.84')),
#  ('Burkina Faso', '2018', Decimal('20.39')),
#  ('Burkina Faso', '2019', Decimal('20.95')),
#  ('Burkina Faso', '2020', Decimal('21.52')),
#  ('Cabo Verde', '2015', Decimal('0.55')),
#  ('Cabo Verde', '2016', Decimal('0.56')),
#  ('Cabo Verde', '2017', Decimal('0.56')),
#  ('Cabo Verde', '2018', Decimal('0.57')),
#  ('Cabo Verde', '2019', Decimal('0.58')),
#  ('Cabo Verde', '2020', Decimal('0.58')),
#  ("Côte d'Ivoire", '2015', Decimal('0.00')),
#  ("Côte d'Ivoire", '2016', Decimal('0.00')),
#  ("Côte d'Ivoire", '2017', Decimal('0.00')),
#  ("Côte d'Ivoire", '2018', Decimal('0.00')),
#  ("Côte d'Ivoire", '2019', Decimal('0.00')),
#  ("Côte d'Ivoire", '2020', Decimal('0.00')),
#  ('Gambia', '2015', Decimal('0.00')),
#  ('Gambia', '2016', Decimal('0.00')),
#  ('Gambia', '2017', Decimal('0.00')),
#  ('Gambia', '2018', Decimal('0.00')),
#  ('Gambia', '2019', Decimal('0.00')),
#  ('Gambia', '2020', Decimal('0.00')),
#  ('Ghana', '2015', Decimal('28.87')),
#  ('Ghana', '2016', Decimal('29.55')),
#  ('Ghana', '2017', Decimal('30.22')),
#  ('Ghana', '2018', Decimal('30.87')),
#  ('Ghana', '2019', Decimal('31.52')),
#  ('Ghana', '2020', Decimal('32.18')),
#  ('Guinea', '2015', Decimal('11.63')),
#  ('Guinea', '2016', Decimal('11.93')),
#  ('Guinea', '2017', Decimal('12.24')),
#  ('Guinea', '2018', Decimal('12.55')),
#  ('Guinea', '2019', Decimal('12.88')),
#  ('Guinea', '2020', Decimal('13.21')),
#  ('Guinea-Bissau', '2015', Decimal('1.79')),
#  ('Guinea-Bissau', '2016', Decimal('1.83')),
#  ('Guinea-Bissau', '2017', Decimal('1.88')),
#  ('Guinea-Bissau', '2018', Decimal('1.92')),
#  ('Guinea-Bissau', '2019', Decimal('1.97')),
#  ('Guinea-Bissau', '2020', Decimal('2.02')),
#  ('Liberia', '2015', Decimal('4.61')),
#  ('Liberia', '2016', Decimal('4.71')),
#  ('Liberia', '2017', Decimal('4.80')),
#  ('Liberia', '2018', Decimal('4.89')),
#  ('Liberia', '2019', Decimal('4.99')),
#  ('Liberia', '2020', Decimal('5.09')),
#  ...]

# %% [markdown]
# ## Summary
#
# We have successfully performed the conversion and our values now have only two decimal places.
#
# **NOTE:** The `CAST()` function will only change the data type of the expression in the results set. It does not alter the actual data type specified in the database schema.
#
# To permanently change the data type of a column, the `ALTER TABLE` statement is used.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
