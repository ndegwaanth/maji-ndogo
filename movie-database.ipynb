# %%
# %load_ext sql

# %%
# %sql sqlite:///data/TMDB-a-4006.db

# %%
# %%sql
# select name
# from sqlite_master
# where type='table';
# Out:
#  * sqlite:///data/TMDB-a-4006.db
# Done.
# [('actors',),
#  ('casts',),
#  ('genremap',),
#  ('genres',),
#  ('keywordmap',),
#  ('keywords',),
#  ('languagemap',),
#  ('languages',),
#  ('movies',),
#  ('oscars',),
#  ('productioncompanies',),
#  ('productioncompanymap',),
#  ('productioncountries',),
#  ('productioncountrymap',),
#  ('sysdiagrams',)]
