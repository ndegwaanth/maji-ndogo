# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Subquery in FROM

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Description

# %% [markdown]
# In this lesson we will use a subquery like a temporary table, meaning we will do a calculation, and then reference the result of that calculation in another query.

# %% [markdown]
# ## Learning objectives
#
# In this train we will learn:
# - How to create a query using the FROM clause.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in our `united_nations` database we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.
#
# Note that before, for this tutorial, we will already have worked through the lessons where the `united_nations.Basic_Services` table, `united_nations.Economic_Indicators` table, and the `united_nations.Geographic_Locations` table have been created.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://anthony:Sucess%4022@localhost:3306/united_nations

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2015', Decimal('94.67'), Decimal('98.00'), Decimal('17.54'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2016', Decimal('94.67'), Decimal('98.00'), Decimal('17.79'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2017', Decimal('95.00'), Decimal('98.00'), Decimal('18.04'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2018', Decimal('95.00'), Decimal('98.00'), Decimal('18.28'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2019', Decimal('95.00'), Decimal('98.00'), Decimal('18.51'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise

# %% [markdown]
# In this exercise. We will use a subquery to answer the following question: What is the average GDP and population for countries with unemployment rates above 5%?

# %% [markdown]
# ### Creating the subquery
# Construct the subquery that displays the average GDP and average population of countries for 2020. The query should have the following columns: `Country_name`, `Avg_GDP`, `Avg_Population`.

# %%
# %%sql
# select
#     Country_name,
#     avg(Est_gdp_in_billions) as avg_gdp,
#     avg(Est_population_in_millions) as avg_population
# from access_to_basic_services
# where Pct_unemployment_rate > 5 and Time_period = 2020
# group by Country_name
# order by avg_gdp desc;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 37 rows affected.
# [('China', Decimal('14687.670000'), Decimal('1411.100000')),
#  ('India', Decimal('2667.690000'), Decimal('1396.390000')),
#  ('Canada', Decimal('1645.420000'), Decimal('38.040000')),
#  ('Brazil', Decimal('1448.560000'), Decimal('213.200000')),
#  ('Australia', Decimal('1326.900000'), Decimal('25.660000')),
#  ('Saudi Arabia', Decimal('703.370000'), Decimal('36.000000')),
#  ('Argentina', Decimal('385.540000'), Decimal('45.380000')),
#  ('South Africa', Decimal('337.620000'), Decimal('58.800000')),
#  ('Colombia', Decimal('270.300000'), Decimal('50.930000')),
#  ('Chile', Decimal('252.730000'), Decimal('19.300000')),
#  ('Peru', Decimal('201.710000'), Decimal('33.300000')),
#  ('Ecuador', Decimal('99.290000'), Decimal('17.590000')),
#  ('Sri Lanka', Decimal('85.350000'), Decimal('21.920000')),
#  ('Dominican Republic', Decimal('78.840000'), Decimal('11.000000')),
#  ('Costa Rica', Decimal('62.160000'), Decimal('5.120000')),
#  ('Uzbekistan', Decimal('59.890000'), Decimal('34.230000')),
#  ('Panama', Decimal('53.980000'), Decimal('4.290000')),
#  ('Uruguay', Decimal('53.560000'), Decimal('3.430000')),
#  ('Jordan', Decimal('44.180000'), Decimal('10.930000')),
#  ('Azerbaijan', Decimal('42.690000'), Decimal('10.090000')),
#  ('Paraguay', Decimal('35.430000'), Decimal('6.620000')),
#  ('Cyprus', Decimal('25.010000'), Decimal('1.240000')),
#  ('El Salvador', Decimal('24.560000'), Decimal('6.290000')),
#  ('Honduras', Decimal('23.830000'), Decimal('10.120000')),
#  ('Afghanistan', Decimal('20.140000'), Decimal('38.970000')),
#  ('Zambia', Decimal('18.110000'), Decimal('18.930000')),
#  ('Georgia', Decimal('15.840000'), Decimal('3.720000')),
#  ('Botswana', Decimal('14.930000'), Decimal('2.550000')),
#  ('Jamaica', Decimal('13.810000'), Decimal('2.820000')),
#  ('Mongolia', Decimal('13.310000'), Decimal('3.290000')),
#  ('Armenia', Decimal('12.640000'), Decimal('2.810000')),
#  ('Brunei Darussalam', Decimal('12.010000'), Decimal('0.440000')),
#  ('Mauritius', Decimal('11.400000'), Decimal('1.270000')),
#  ('Rwanda', Decimal('10.180000'), Decimal('13.150000')),
#  ('New Caledonia', Decimal('9.440000'), Decimal('0.270000')),
#  ('Bhutan', Decimal('2.330000'), Decimal('0.770000')),
#  ('Kiribati', Decimal('0.180000'), Decimal('0.130000'))]

# %% [markdown]
# ### Creating the main query
# Construct a query that filters out countries with unemployment rates above 5%. The query should include the following columns: `Country_name`, `Est_gdp_in_billions`,  `Est_population_in_millions`.

# %%
# %%sql
# SELECT
#     Country_name,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM (
#     SELECT
#         Country_name,
#         AVG(Est_gdp_in_billions) AS Est_gdp_in_billions,
#         AVG(Est_population_in_millions) AS Est_population_in_millions
#     FROM access_to_basic_services
#     WHERE Pct_unemployment_rate > 5
#       AND Time_period = 2020
#     GROUP BY Country_name
# ) AS country_stats
# ORDER BY Est_gdp_in_billions DESC;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 37 rows affected.
# [('China', Decimal('14687.670000'), Decimal('1411.100000')),
#  ('India', Decimal('2667.690000'), Decimal('1396.390000')),
#  ('Canada', Decimal('1645.420000'), Decimal('38.040000')),
#  ('Brazil', Decimal('1448.560000'), Decimal('213.200000')),
#  ('Australia', Decimal('1326.900000'), Decimal('25.660000')),
#  ('Saudi Arabia', Decimal('703.370000'), Decimal('36.000000')),
#  ('Argentina', Decimal('385.540000'), Decimal('45.380000')),
#  ('South Africa', Decimal('337.620000'), Decimal('58.800000')),
#  ('Colombia', Decimal('270.300000'), Decimal('50.930000')),
#  ('Chile', Decimal('252.730000'), Decimal('19.300000')),
#  ('Peru', Decimal('201.710000'), Decimal('33.300000')),
#  ('Ecuador', Decimal('99.290000'), Decimal('17.590000')),
#  ('Sri Lanka', Decimal('85.350000'), Decimal('21.920000')),
#  ('Dominican Republic', Decimal('78.840000'), Decimal('11.000000')),
#  ('Costa Rica', Decimal('62.160000'), Decimal('5.120000')),
#  ('Uzbekistan', Decimal('59.890000'), Decimal('34.230000')),
#  ('Panama', Decimal('53.980000'), Decimal('4.290000')),
#  ('Uruguay', Decimal('53.560000'), Decimal('3.430000')),
#  ('Jordan', Decimal('44.180000'), Decimal('10.930000')),
#  ('Azerbaijan', Decimal('42.690000'), Decimal('10.090000')),
#  ('Paraguay', Decimal('35.430000'), Decimal('6.620000')),
#  ('Cyprus', Decimal('25.010000'), Decimal('1.240000')),
#  ('El Salvador', Decimal('24.560000'), Decimal('6.290000')),
#  ('Honduras', Decimal('23.830000'), Decimal('10.120000')),
#  ('Afghanistan', Decimal('20.140000'), Decimal('38.970000')),
#  ('Zambia', Decimal('18.110000'), Decimal('18.930000')),
#  ('Georgia', Decimal('15.840000'), Decimal('3.720000')),
#  ('Botswana', Decimal('14.930000'), Decimal('2.550000')),
#  ('Jamaica', Decimal('13.810000'), Decimal('2.820000')),
#  ('Mongolia', Decimal('13.310000'), Decimal('3.290000')),
#  ('Armenia', Decimal('12.640000'), Decimal('2.810000')),
#  ('Brunei Darussalam', Decimal('12.010000'), Decimal('0.440000')),
#  ('Mauritius', Decimal('11.400000'), Decimal('1.270000')),
#  ('Rwanda', Decimal('10.180000'), Decimal('13.150000')),
#  ('New Caledonia', Decimal('9.440000'), Decimal('0.270000')),
#  ('Bhutan', Decimal('2.330000'), Decimal('0.770000')),
#  ('Kiribati', Decimal('0.180000'), Decimal('0.130000'))]

# %% [markdown]
# ### Combining the queries
#
# Using the query and the subquery, determine the average GDP and population for countries with unemployment rates above 5%. Group the results by `Country_name`.

# %%
# %%sql
# # Add your code here

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Creating the subquery

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM
#     Economic_Indicators
# WHERE
#     Pct_unemployment > 5
#     AND Time_period = 2020;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 37 rows affected.
# [('Afghanistan', 20.14, 38.97),
#  ('Argentina', 385.54, 45.38),
#  ('Armenia', 12.64, 2.81),
#  ('Australia', 1326.9, 25.66),
#  ('Azerbaijan', 42.69, 10.09),
#  ('Bhutan', 2.33, 0.77),
#  ('Botswana', 14.93, 2.55),
#  ('Brazil', 1448.56, 213.2),
#  ('Brunei Darussalam', 12.01, 0.44),
#  ('Canada', 1645.42, 38.04),
#  ('Chile', 252.73, 19.3),
#  ('China', 14687.7, 1411.1),
#  ('Colombia', 270.3, 50.93),
#  ('Costa Rica', 62.16, 5.12),
#  ('Cyprus', 25.01, 1.24),
#  ('Dominican Republic', 78.84, 11.0),
#  ('Ecuador', 99.29, 17.59),
#  ('El Salvador', 24.56, 6.29),
#  ('Georgia', 15.84, 3.72),
#  ('Honduras', 23.83, 10.12),
#  ('India', 2667.69, 1396.39),
#  ('Jamaica', 13.81, 2.82),
#  ('Jordan', 44.18, 10.93),
#  ('Kiribati', 0.18, 0.13),
#  ('Mauritius', 11.4, 1.27),
#  ('Mongolia', 13.31, 3.29),
#  ('New Caledonia', 9.44, 0.27),
#  ('Panama', 53.98, 4.29),
#  ('Paraguay', 35.43, 6.62),
#  ('Peru', 201.71, 33.3),
#  ('Rwanda', 10.18, 13.15),
#  ('Saudi Arabia', 703.37, 36.0),
#  ('South Africa', 337.62, 58.8),
#  ('Sri Lanka', 85.35, 21.92),
#  ('Uruguay', 53.56, 3.43),
#  ('Uzbekistan', 59.89, 34.23),
#  ('Zambia', 18.11, 18.93)]

# %% [markdown]
# This table simply filters the `Economic_Indicators` table to only display countries with unemployment > 5. This is the input table the main query will use.

# %% [markdown]
# ### Creating the main query

# %%
# %%sql
#
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     Economic_Indicators
# GROUP BY
#     Country_name;

# %% [markdown]
# Note that this query calculates the averages for **all** years, and for **all** countries.

# %% [markdown]
# ### Combining the queries

# %%
# %%sql
#
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     (SELECT
#         Country_name,
#         Est_gdp_in_billions,
#         Est_population_in_millions
#     FROM
#         Economic_Indicators
#     WHERE
#         Pct_unemployment > 5
#         AND Time_period = 2020) AS FilteredCountries
# GROUP BY
#     Country_name;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 37 rows affected.
# [('Afghanistan', 20.139999389648438, 38.970001220703125),
#  ('Argentina', 385.5400085449219, 45.380001068115234),
#  ('Armenia', 12.640000343322754, 2.809999942779541),
#  ('Australia', 1326.9000244140625, 25.65999984741211),
#  ('Azerbaijan', 42.689998626708984, 10.09000015258789),
#  ('Bhutan', 2.3299999237060547, 0.7699999809265137),
#  ('Botswana', 14.930000305175781, 2.549999952316284),
#  ('Brazil', 1448.56005859375, 213.1999969482422),
#  ('Brunei Darussalam', 12.010000228881836, 0.4399999976158142),
#  ('Canada', 1645.4200439453125, 38.040000915527344),
#  ('Chile', 252.72999572753906, 19.299999237060547),
#  ('China', 14687.669921875, 1411.0999755859375),
#  ('Colombia', 270.29998779296875, 50.93000030517578),
#  ('Costa Rica', 62.15999984741211, 5.119999885559082),
#  ('Cyprus', 25.010000228881836, 1.2400000095367432),
#  ('Dominican Republic', 78.83999633789062, 11.0),
#  ('Ecuador', 99.29000091552734, 17.59000015258789),
#  ('El Salvador', 24.559999465942383, 6.289999961853027),
#  ('Georgia', 15.84000015258789, 3.7200000286102295),
#  ('Honduras', 23.829999923706055, 10.119999885559082),
#  ('India', 2667.68994140625, 1396.3900146484375),
#  ('Jamaica', 13.8100004196167, 2.819999933242798),
#  ('Jordan', 44.18000030517578, 10.930000305175781),
#  ('Kiribati', 0.18000000715255737, 0.12999999523162842),
#  ('Mauritius', 11.399999618530273, 1.2699999809265137),
#  ('Mongolia', 13.3100004196167, 3.2899999618530273),
#  ('New Caledonia', 9.4399995803833, 0.27000001072883606),
#  ('Panama', 53.97999954223633, 4.289999961853027),
#  ('Paraguay', 35.43000030517578, 6.619999885559082),
#  ('Peru', 201.7100067138672, 33.29999923706055),
#  ('Rwanda', 10.180000305175781, 13.149999618530273),
#  ('Saudi Arabia', 703.3699951171875, 36.0),
#  ('South Africa', 337.6199951171875, 58.79999923706055),
#  ('Sri Lanka', 85.3499984741211, 21.920000076293945),
#  ('Uruguay', 53.560001373291016, 3.430000066757202),
#  ('Uzbekistan', 59.88999938964844, 34.22999954223633),
#  ('Zambia', 18.110000610351562, 18.93000030517578)]

# %% [markdown]
# Using the subquery filters the data first into a derived table, which the main query uses to aggregate with.

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lesson, we used a subquery to determine the average GDP and populations of countries where the unemployment rate is above 5%. We made use of the `FROM` clause. In essence, the subquery in the `FROM` clause can be thought of as creating an intermediate or derived table for the main query to operate upon, even if this table exists only for the duration of the query execution.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
