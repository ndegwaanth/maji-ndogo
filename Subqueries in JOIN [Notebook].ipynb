# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Subquery in the JOIN clause

# %% [markdown]
# In this notebook we will look at subqueries, which are powerful tools to enable more in-depth analysis in SQL. They are essentially intermediate results sets that we access with another query, so **a query inside another query**. We can use subqueries in various places in a query, and those subquery results also have various forms. Here, we look at the **use of a subquery in the `JOIN` clause.**

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to use the result set of a subquery in the main query by joining the main table to the subquery on a related column.

# %% [markdown]
# ## Overview
#
# Imagine we want to calculate the percentage of land area that a specific country in a sub-region occupies, as a percentage of the total land area in that sub-region. We would need to divide each country’s land area with the sum of all countries in that sub-region.
#
# Previously, we created a correlated subquery that calculated the land area for each row. Let’s improve on that. It would be more efficient if we calculated the total land area once for each sub-region. **We can then run a query that would just retrieve the land area value from the result of the inner query.**

# %% [markdown]
# ## Connecting to our MySQL database
#
# We will use our `Geographic_location` table in our `united_nations` database that we created in MySQL Workbench. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://anthony:Sucess%4022@localhost:3306/united_nations

# %%
# %%sql
# select * from geographic_location limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700')),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', Decimal('0'))]

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. Calculate the total land area for each sub-region
#
# Write a query that will aggregate the data by summing the `land area` and then grouping the sums by `sub-region`. Give the sums the alias `TotalLandArea`.

# %%
# %%sql
# select
#     Sub_region,
#     sum(Land_area) as total_land_area
# from geographic_location as gl
# where Sub_region = gl.Sub_region
# group by Sub_region;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 18 rows affected.
# [('Southern Asia', Decimal('4770136')),
#  ('Northern Africa', Decimal('6610941')),
#  ('Polynesia', Decimal('7218')),
#  ('Middle Africa', Decimal('3888270')),
#  ('Caribbean', Decimal('208104')),
#  ('South America', Decimal('15401392')),
#  ('Western Asia', Decimal('3488572')),
#  ('Australia and New Zealand', Decimal('7953710')),
#  ('Central America', Decimal('2452080')),
#  ('Western Africa', Decimal('5735549')),
#  ('Northern America', Decimal('9376094')),
#  ('Southern Africa', Decimal('2650670')),
#  ('South-Eastern Asia', Decimal('3865282')),
#  ('Eastern Africa', Decimal('5949153')),
#  ('Eastern Asia', Decimal('11346500')),
#  ('Melanesia', Decimal('529590')),
#  ('Micronesia', Decimal('2470')),
#  ('Central Asia', Decimal('3749015'))]

# %% [markdown]
# ### 2. Calculate country land area percentages for all the regions using a subquery in the JOIN clause
#
# Create a query with a main query that selects, from the `Geographic_location` table, the columns `Country_name`, `Land_area`, and `Sub_region`. The next line should then divide the `Land area` by the land area totals named, `TotalLandArea`, gotten from the subquery. Give this calculated column the alias `Pct_of_region_land`.
#
# The query should also have a `JOIN` clause where we will add the query we created in Exercise 1 as a subquery named `Land_per_region`. This join occurs between the `Geographic_location` table and the `Land_per_region` subquery on the `Sub_region` column.

# %%
# %%sql
# SELECT
#     g.Country_name,
#     g.Land_area,
#     g.Sub_region,
#     (g.Land_area / lpr.TotalLandArea) * 100 AS Pct_of_region_land
# FROM geographic_location AS g
# JOIN (
#     SELECT
#         Sub_region,
#         SUM(Land_area) AS TotalLandArea
#     FROM geographic_location
#     GROUP BY Sub_region
# ) AS lpr
#     ON g.Sub_region = lpr.Sub_region
# ORDER BY Pct_of_region_land DESC;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 182 rows affected.
# [('Australia', Decimal('7690400'), 'Australia and New Zealand', Decimal('96.6895')),
#  ('Canada', Decimal('8965590'), 'Northern America', Decimal('95.6218')),
#  ('Papua New Guinea', Decimal('452860'), 'Melanesia', Decimal('85.5114')),
#  ('China', Decimal('9424702'), 'Eastern Asia', Decimal('83.0626')),
#  ('Mexico', Decimal('1943950'), 'Central America', Decimal('79.2776')),
#  ('Kazakhstan', Decimal('2699700'), 'Central Asia', Decimal('72.0109')),
#  ('India', Decimal('2973190'), 'Southern Asia', Decimal('62.3293')),
#  ('Saudi Arabia', Decimal('2149690'), 'Western Asia', Decimal('61.6209')),
#  ('Brazil', Decimal('8358140'), 'South America', Decimal('54.2687')),
#  ('Cuba', Decimal('103890'), 'Caribbean', Decimal('49.9222')),
#  ('Indonesia', Decimal('1877519'), 'South-Eastern Asia', Decimal('48.5739')),
#  ('French Polynesia', Decimal('3471'), 'Polynesia', Decimal('48.0881')),
#  ('South Africa', Decimal('1213090'), 'Southern Africa', Decimal('45.7654')),
#  ('Samoa', Decimal('2797'), 'Polynesia', Decimal('38.7503')),
#  ('Algeria', Decimal('2381741'), 'Northern Africa', Decimal('36.0273')),
#  ('Kiribati', Decimal('810'), 'Micronesia', Decimal('32.7935')),
#  ('Chad', Decimal('1259200'), 'Middle Africa', Decimal('32.3846')),
#  ('Angola', Decimal('1246700'), 'Middle Africa', Decimal('32.0631')),
#  ('Namibia', Decimal('823290'), 'Southern Africa', Decimal('31.0597')),
#  ('Sudan', Decimal('1868000'), 'Northern Africa', Decimal('28.2562')),
#  ('Libya', Decimal('1759540'), 'Northern Africa', Decimal('26.6156')),
#  ('Dominican Republic', Decimal('48310'), 'Caribbean', Decimal('23.2144')),
#  ('Niger', Decimal('1266700'), 'Western Africa', Decimal('22.0851')),
#  ('Guam', Decimal('540'), 'Micronesia', Decimal('21.8623')),
#  ('Botswana', Decimal('566730'), 'Southern Africa', Decimal('21.3806')),
#  ('Mali', Decimal('1220190'), 'Western Africa', Decimal('21.2742')),
#  ('Ethiopia', Decimal('1128559'), 'Eastern Africa', Decimal('18.9701')),
#  ('Palau', Decimal('460'), 'Micronesia', Decimal('18.6235')),
#  ('Northern Mariana Islands', Decimal('460'), 'Micronesia', Decimal('18.6235')),
#  ('Mauritania', Decimal('1030700'), 'Western Africa', Decimal('17.9704')),
#  ('Argentina', Decimal('2736690'), 'South America', Decimal('17.7691')),
#  ('Myanmar', Decimal('652780'), 'South-Eastern Asia', Decimal('16.8883')),
#  ('Pakistan', Decimal('770880'), 'Southern Asia', Decimal('16.1605')),
#  ('Central African Republic', Decimal('622980'), 'Middle Africa', Decimal('16.0220')),
#  ('Nigeria', Decimal('910770'), 'Western Africa', Decimal('15.8794')),
#  ('Mongolia', Decimal('1557298'), 'Eastern Asia', Decimal('13.7249')),
#  ('Afghanistan', Decimal('652230'), 'Southern Asia', Decimal('13.6732')),
#  ('Haiti', Decimal('27560'), 'Caribbean', Decimal('13.2434')),
#  ('Mozambique', Decimal('786380'), 'Eastern Africa', Decimal('13.2184')),
#  ('Thailand', Decimal('510890'), 'South-Eastern Asia', Decimal('13.2174')),
#  ('Turkmenistan', Decimal('469930'), 'Central Asia', Decimal('12.5348')),
#  ('Zambia', Decimal('743390'), 'Eastern Africa', Decimal('12.4957')),
#  ('Iraq', Decimal('434128'), 'Western Asia', Decimal('12.4443')),
#  ('Cameroon', Decimal('472710'), 'Middle Africa', Decimal('12.1573')),
#  ('Uzbekistan', Decimal('440595'), 'Central Asia', Decimal('11.7523')),
#  ('South Sudan', Decimal('631930'), 'Eastern Africa', Decimal('10.6222')),
#  ('Somalia', Decimal('627340'), 'Eastern Africa', Decimal('10.5450')),
#  ('Tonga', Decimal('720'), 'Polynesia', Decimal('9.9751')),
#  ('Madagascar', Decimal('581800'), 'Eastern Africa', Decimal('9.7795')),
#  ('Kenya', Decimal('569140'), 'Eastern Africa', Decimal('9.5667')),
#  ('Oman', Decimal('309500'), 'Western Asia', Decimal('8.8718')),
#  ('Malaysia', Decimal('328550'), 'South-Eastern Asia', Decimal('8.5000')),
#  ('Peru', Decimal('1280000'), 'South America', Decimal('8.3109')),
#  ('Philippines', Decimal('298170'), 'South-Eastern Asia', Decimal('7.7141')),
#  ('Marshall Islands', Decimal('180'), 'Micronesia', Decimal('7.2874')),
#  ('Colombia', Decimal('1109500'), 'South America', Decimal('7.2039')),
#  ('Morocco', Decimal('446300'), 'Northern Africa', Decimal('6.7509')),
#  ('Gabon', Decimal('257670'), 'Middle Africa', Decimal('6.6269')),
#  ('Zimbabwe', Decimal('386850'), 'Eastern Africa', Decimal('6.5026')),
#  ('Solomon Islands', Decimal('27990'), 'Melanesia', Decimal('5.2852')),
#  ('Syrian Arab Republic', Decimal('183630'), 'Western Asia', Decimal('5.2638')),
#  ('Jamaica', Decimal('10830'), 'Caribbean', Decimal('5.2041')),
#  ('Nicaragua', Decimal('120340'), 'Central America', Decimal('4.9077')),
#  ('Chile', Decimal('743532'), 'South America', Decimal('4.8277')),
#  ('Burkina Faso', Decimal('273600'), 'Western Africa', Decimal('4.7702')),
#  ('Cambodia', Decimal('176520'), 'South-Eastern Asia', Decimal('4.5668')),
#  ('Honduras', Decimal('111890'), 'Central America', Decimal('4.5631')),
#  ('Greenland', Decimal('410450'), 'Northern America', Decimal('4.3776')),
#  ('Guatemala', Decimal('107160'), 'Central America', Decimal('4.3702')),
#  ('Guinea', Decimal('245720'), 'Western Africa', Decimal('4.2842')),
#  ('Puerto Rico', Decimal('8870'), 'Caribbean', Decimal('4.2623')),
#  ('Ghana', Decimal('227539'), 'Western Africa', Decimal('3.9672')),
#  ('Tajikistan', Decimal('138790'), 'Central Asia', Decimal('3.7020')),
#  ('New Caledonia', Decimal('18280'), 'Melanesia', Decimal('3.4517')),
#  ('Fiji', Decimal('18270'), 'Melanesia', Decimal('3.4498')),
#  ('Uganda', Decimal('200520'), 'Eastern Africa', Decimal('3.3706')),
#  ('Senegal', Decimal('192530'), 'Western Africa', Decimal('3.3568')),
#  ('New Zealand', Decimal('263310'), 'Australia and New Zealand', Decimal('3.3105')),
#  ('Japan', Decimal('364500'), 'Eastern Asia', Decimal('3.2124')),
#  ('Panama', Decimal('74150'), 'Central America', Decimal('3.0240')),
#  ('Nepal', Decimal('143350'), 'Southern Asia', Decimal('3.0052')),
#  ('American Samoa', Decimal('200'), 'Polynesia', Decimal('2.7709')),
#  ('Bangladesh', Decimal('130170'), 'Southern Asia', Decimal('2.7289')),
#  ('Paraguay', Decimal('397300'), 'South America', Decimal('2.5796')),
#  ('Jordan', Decimal('88785'), 'Western Asia', Decimal('2.5450')),
#  ('Trinidad and Tobago', Decimal('5130'), 'Caribbean', Decimal('2.4651')),
#  ('Azerbaijan', Decimal('82658'), 'Western Asia', Decimal('2.3694')),
#  ('Tunisia', Decimal('155360'), 'Northern Africa', Decimal('2.3500')),
#  ('Vanuatu', Decimal('12190'), 'Melanesia', Decimal('2.3018')),
#  ('Costa Rica', Decimal('51060'), 'Central America', Decimal('2.0823')),
#  ('United Arab Emirates', Decimal('71020'), 'Western Asia', Decimal('2.0358')),
#  ('Eritrea', Decimal('121083'), 'Eastern Africa', Decimal('2.0353')),
#  ('Georgia', Decimal('69490'), 'Western Asia', Decimal('1.9919')),
#  ('Benin', Decimal('112760'), 'Western Africa', Decimal('1.9660')),
#  ('Liberia', Decimal('96320'), 'Western Africa', Decimal('1.6794')),
#  ('Ecuador', Decimal('248360'), 'South America', Decimal('1.6126')),
#  ('Malawi', Decimal('94280'), 'Eastern Africa', Decimal('1.5848')),
#  ('Sri Lanka', Decimal('61878'), 'Southern Asia', Decimal('1.2972')),
#  ('Guyana', Decimal('196850'), 'South America', Decimal('1.2781')),
#  ('Sierra Leone', Decimal('72180'), 'Western Africa', Decimal('1.2585')),
#  ('Lesotho', Decimal('30360'), 'Southern Africa', Decimal('1.1454')),
#  ('Uruguay', Decimal('175020'), 'South America', Decimal('1.1364')),
#  ('Suriname', Decimal('156000'), 'South America', Decimal('1.0129')),
#  ('Togo', Decimal('54390'), 'Western Africa', Decimal('0.9483')),
#  ('Belize', Decimal('22810'), 'Central America', Decimal('0.9302')),
#  ('El Salvador', Decimal('20720'), 'Central America', Decimal('0.8450')),
#  ('Armenia', Decimal('28470'), 'Western Asia', Decimal('0.8161')),
#  ('Nauru', Decimal('20'), 'Micronesia', Decimal('0.8097')),
#  ('Bhutan', Decimal('38138'), 'Southern Asia', Decimal('0.7995')),
#  ('Equatorial Guinea', Decimal('28050'), 'Middle Africa', Decimal('0.7214')),
#  ('Eswatini', Decimal('17200'), 'Southern Africa', Decimal('0.6489')),
#  ('Israel', Decimal('21640'), 'Western Asia', Decimal('0.6203')),
#  ('Kuwait', Decimal('17820'), 'Western Asia', Decimal('0.5108')),
#  ('Guinea-Bissau', Decimal('28120'), 'Western Africa', Decimal('0.4903')),
#  ('Turks and Caicos Islands', Decimal('950'), 'Caribbean', Decimal('0.4565')),
#  ('Burundi', Decimal('25680'), 'Eastern Africa', Decimal('0.4317')),
#  ('Tuvalu', Decimal('30'), 'Polynesia', Decimal('0.4156')),
#  ('Rwanda', Decimal('24670'), 'Eastern Africa', Decimal('0.4147')),
#  ('Djibouti', Decimal('23180'), 'Eastern Africa', Decimal('0.3896')),
#  ('Timor-Leste', Decimal('14870'), 'South-Eastern Asia', Decimal('0.3847')),
#  ('Dominica', Decimal('750'), 'Caribbean', Decimal('0.3604')),
#  ('Qatar', Decimal('11490'), 'Western Asia', Decimal('0.3294')),
#  ('Lebanon', Decimal('10230'), 'Western Asia', Decimal('0.2932')),
#  ('Cyprus', Decimal('9240'), 'Western Asia', Decimal('0.2649')),
#  ('Antigua and Barbuda', Decimal('440'), 'Caribbean', Decimal('0.2114')),
#  ('Barbados', Decimal('430'), 'Caribbean', Decimal('0.2066')),
#  ('Grenada', Decimal('340'), 'Caribbean', Decimal('0.1634')),
#  ('Brunei Darussalam', Decimal('5270'), 'South-Eastern Asia', Decimal('0.1363')),
#  ('Cayman Islands', Decimal('240'), 'Caribbean', Decimal('0.1153')),
#  ('Aruba', Decimal('180'), 'Caribbean', Decimal('0.0865')),
#  ('British Virgin Islands', Decimal('150'), 'Caribbean', Decimal('0.0721')),
#  ('Cabo Verde', Decimal('4030'), 'Western Africa', Decimal('0.0703')),
#  ('Mauritius', Decimal('2030'), 'Eastern Africa', Decimal('0.0341')),
#  ('Comoros', Decimal('1861'), 'Eastern Africa', Decimal('0.0313')),
#  ('Sao Tome and Principe', Decimal('960'), 'Middle Africa', Decimal('0.0247')),
#  ('Bahrain', Decimal('781'), 'Western Asia', Decimal('0.0224')),
#  ('Singapore', Decimal('713'), 'South-Eastern Asia', Decimal('0.0184')),
#  ('Sint Maarten (Dutch part)', Decimal('34'), 'Caribbean', Decimal('0.0163')),
#  ('Seychelles', Decimal('460'), 'Eastern Africa', Decimal('0.0077')),
#  ('Maldives', Decimal('300'), 'Southern Asia', Decimal('0.0063')),
#  ('Bermuda', Decimal('54'), 'Northern America', Decimal('0.0006')),
#  ('Iran (Islamic Republic of)', Decimal('0'), 'Southern Asia', Decimal('0.0000')),
#  ('Egypt', Decimal('0'), 'Northern Africa', Decimal('0.0000')),
#  ('Wallis and Futuna Islands', Decimal('0'), 'Polynesia', Decimal('0.0000')),
#  ('Tokelau', Decimal('0'), 'Polynesia', Decimal('0.0000')),
#  ('Niue', Decimal('0'), 'Polynesia', Decimal('0.0000')),
#  ('Cook Islands', Decimal('0'), 'Polynesia', Decimal('0.0000')),
#  ('Democratic Republic of the Congo', Decimal('0'), 'Middle Africa', Decimal('0.0000')),
#  ('Congo', Decimal('0'), 'Middle Africa', Decimal('0.0000')),
#  ('United States Virgin Islands', Decimal('0'), 'Caribbean', Decimal('0.0000')),
#  ('Saint Vincent and the Grenadines', Decimal('0'), 'Caribbean', Decimal('0.0000')),
#  ('Saint Martin (French Part)', Decimal('0'), 'Caribbean', Decimal('0.0000')),
#  ('Saint Lucia', Decimal('0'), 'Caribbean', Decimal('0.0000')),
#  ('Saint Kitts and Nevis', Decimal('0'), 'Caribbean', Decimal('0.0000')),
#  ('Saint Barthélemy', Decimal('0'), 'Caribbean', Decimal('0.0000')),
#  ('Montserrat', Decimal('0'), 'Caribbean', Decimal('0.0000')),
#  ('Martinique', Decimal('0'), 'Caribbean', Decimal('0.0000')),
#  ('Guadeloupe', Decimal('0'), 'Caribbean', Decimal('0.0000')),
#  ('Curaçao', Decimal('0'), 'Caribbean', Decimal('0.0000')),
#  ('Bahamas', Decimal('0'), 'Caribbean', Decimal('0.0000')),
#  ('Anguilla', Decimal('0'), 'Caribbean', Decimal('0.0000')),
#  ('Venezuela (Bolivarian Republic of)', Decimal('0'), 'South America', Decimal('0.0000')),
#  ('French Guiana', Decimal('0'), 'South America', Decimal('0.0000')),
#  ('Falkland Islands (Malvinas)', Decimal('0'), 'South America', Decimal('0.0000')),
#  ('Bolivia (Plurinational State of)', Decimal('0'), 'South America', Decimal('0.0000')),
#  ('Yemen', Decimal('0'), 'Western Asia', Decimal('0.0000')),
#  ('Türkiye', Decimal('0'), 'Western Asia', Decimal('0.0000')),
#  ('State of Palestine', Decimal('0'), 'Western Asia', Decimal('0.0000')),
#  ('Saint Helena', Decimal('0'), 'Western Africa', Decimal('0.0000')),
#  ('Gambia', Decimal('0'), 'Western Africa', Decimal('0.0000')),
#  ("Côte d'Ivoire", Decimal('0'), 'Western Africa', Decimal('0.0000')),
#  ('United States of America', Decimal('0'), 'Northern America', Decimal('0.0000')),
#  ('Saint Pierre and Miquelon', Decimal('0'), 'Northern America', Decimal('0.0000')),
#  ('Viet Nam', Decimal('0'), 'South-Eastern Asia', Decimal('0.0000')),
#  ("Lao People's Democratic Republic", Decimal('0'), 'South-Eastern Asia', Decimal('0.0000')),
#  ('United Republic of Tanzania', Decimal('0'), 'Eastern Africa', Decimal('0.0000')),
#  ('Réunion', Decimal('0'), 'Eastern Africa', Decimal('0.0000')),
#  ('Mayotte', Decimal('0'), 'Eastern Africa', Decimal('0.0000')),
#  ('Republic of Korea', Decimal('0'), 'Eastern Asia', Decimal('0.0000')),
#  ("Democratic People's Republic of Korea", Decimal('0'), 'Eastern Asia', Decimal('0.0000')),
#  ('Micronesia (Federated States of)', Decimal('0'), 'Micronesia', Decimal('0.0000')),
#  ('Kyrgyzstan', Decimal('0'), 'Central Asia', Decimal('0.0000'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Calculate the total land area for each sub-region

# %%
# %%sql
#
# SELECT
#     Sub_region,
#     SUM(Land_area) AS Total_Land_Area
# FROM
#     Geographic_location
# GROUP BY
#     Sub_region
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 18 rows affected.
# [('Southern Asia', Decimal('4770136')),
#  ('Northern Africa', Decimal('6610941')),
#  ('Polynesia', Decimal('7218')),
#  ('Middle Africa', Decimal('3888270')),
#  ('Caribbean', Decimal('208104')),
#  ('South America', Decimal('15401392')),
#  ('Western Asia', Decimal('3488572')),
#  ('Australia and New Zealand', Decimal('7953710')),
#  ('Central America', Decimal('2452080')),
#  ('Western Africa', Decimal('5735549')),
#  ('Northern America', Decimal('9376094')),
#  ('Southern Africa', Decimal('2650670')),
#  ('South-Eastern Asia', Decimal('3865282')),
#  ('Eastern Africa', Decimal('5949153')),
#  ('Eastern Asia', Decimal('11346500')),
#  ('Melanesia', Decimal('529590')),
#  ('Micronesia', Decimal('2470')),
#  ('Central Asia', Decimal('3749015'))]

# %% [markdown]
# This gives us a table with a list of all the sub-regions and their total land areas calculated. In this case, we are not calculating a single value, but an entire table of values. Now we just join this table to the main one and reference the `Sub-region` as the key.

# %% [markdown]
# ### 2. Calculate country land area percentages for all the regions using a subquery in the JOIN clause

# %%
# %%sql
#
# SELECT
#     geoloc.Country_name,
#     geoloc.Land_area,
#     geoloc.Sub_region,
#     (geoloc.Land_area / Land_per_region.Total_Land_Area) * 100 AS Pct_Of_Region_Land
# FROM
#     Geographic_location AS geoloc
# JOIN
#     (
#     SELECT
#         Sub_region,
#         SUM(Land_area) AS Total_Land_Area
#     FROM
#         Geographic_location
#     GROUP BY
#         Sub_region)  AS Land_per_region
#     ON
#         geoloc.Sub_region = Land_per_region.sub_Region;

# %% [markdown]
# While this method may look a bit more complicated, it runs much faster than the previous method because it does not need to repeat calculations for each row. This is especially true for larger tables.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
