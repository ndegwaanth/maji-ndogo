# %%
# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://anthony:Sucess%4022@localhost:3306/united_nations

# %%
# %%sql
# create table Water_samples (
#     Sample_name varchar(255) not null,
#     Purity int not null,
#     Analysis_type varchar(255) not null
# );
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %%
# %%sql
# insert into Water_samples (Sample_name, Purity, Analysis_type) values
# ('Alpha', 68, 'Basic'),
# ('Bravo', 75, 'Advanced'),
# ('Charlie', 52, 'Basic'),
# ('Delta', 89, 'Advanced'),
# ('Echo', 92, 'Basic');
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# []

# %%
# %%sql
# create table Analysis_costs(
#     Analysis_type varchar(255) not null,
#     Cost int not null
# );
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %%
# %%sql
# insert into Analysis_costs (Analysis_type, Cost) values
# ('Advanced', 1000),
# ('Basic', 50);
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 2 rows affected.
# []

# %%
# %%sql
# create table Sample_locations(
#     Sample_name varchar(255) not null,
#     Location varchar(255) not null,
#     Source varchar(255) not null
# );
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %%
# %%sql
# /*
# insert this
# Alpha Ziwa Maji Lake
# Bravo Limpopo River
# Charlie Mji River
# Delta Nairobi Tap
# Echo Jangwa Tap
# */
#     insert into Sample_locations
#     (Sample_name, Location, Source) values
#     ('Alpha', 'Ziwa Maji Lake', 'Lake'),
#     ('Bravo', 'Limpopo River', 'River'),
#     ('Charlie', 'Mji River', 'River'),
#     ('Delta', 'Nairobi Tap', 'Tap'),
#     ('Echo', 'Jangwa Tap', 'Tap');
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# []

# %%
# %%sql
# SELECT
#     Sample_name,
#     Purity
# FROM
#     Water_samples
# WHERE
#     purity > (
#         select
#             avg(Purity)
#         from
#             Water_samples
#     );
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 2 rows affected.
# [('Delta', 89), ('Echo', 92)]

# %%
# %%sql
# SELECT
#  SUM(Cost)
# FROM
#  (previous_query) AS Total_cost;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'AS Total_cost' at line 4")
# [SQL: SELECT
#  SUM(Cost)
# FROM
#  (previous_query) AS Total_cost;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
