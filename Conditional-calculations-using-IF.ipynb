# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Conditional calculations using IF

# %% [markdown]
# In this notebook, we learn how to use `IF` and nested `IF` statements to replace missing data based on certain criteria.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you should:
# - Understand the `IF` statement and how to use it for conditional data manipulations.
# - Know how to apply nested `IF` statements to address multiple conditions sequentially.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table created in MySQL Workbench, we want to answer some questions on the range of our dataset. We can apply the same queries in MySQL Workbench and in this notebook if we connect to our MySQL server. Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://anthony:Sucess%4022@localhost:3306/united_nations

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. Replace NULL values for Central and Southern Asia
#
# Write an `IF` statement that checks whether the `Region` is `Central and Southern Asia` and whether `Pct_unemployment` is `NULL`. If both conditions are met, set the value of a new alias column called `New_pct_unemployment` to `19.59`. If the conditions are not met, use `-999` as a placeholder value in the `New_pct_unemployment` column.

# %%
# %%sql
# describe access_to_basic_services;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 10 rows affected.
# [('Region', 'varchar(255)', 'NO', '', None, ''),
#  ('Sub_region', 'varchar(255)', 'NO', '', None, ''),
#  ('Country_name', 'varchar(255)', 'NO', '', None, ''),
#  ('Time_period', 'varchar(255)', 'NO', '', None, ''),
#  ('Pct_managed_drinking_water_services', 'decimal(10,2)', 'NO', '', None, ''),
#  ('Pct_managed_sanitation_services', 'decimal(10,2)', 'NO', '', None, ''),
#  ('Est_population_in_millions', 'decimal(10,2)', 'YES', '', None, ''),
#  ('Est_gdp_in_billions', 'decimal(10,2)', 'YES', '', None, ''),
#  ('Land_area_in_sq_km', 'decimal(10,2)', 'YES', '', None, ''),
#  ('Pct_unemployment_rate', 'decimal(10,2)', 'YES', '', None, '')]

# %%
# %%sql
# select * from access_to_basic_services limit 5;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2015', Decimal('94.67'), Decimal('98.00'), Decimal('17.54'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2016', Decimal('94.67'), Decimal('98.00'), Decimal('17.79'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2017', Decimal('95.00'), Decimal('98.00'), Decimal('18.04'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2018', Decimal('95.00'), Decimal('98.00'), Decimal('18.28'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', '2019', Decimal('95.00'), Decimal('98.00'), Decimal('18.51'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %%
# %%sql
# SELECT
#     Region,
#     Pct_managed_drinking_water_services,
#     IF((Region = "Central and Southern Asia") AND (Pct_managed_drinking_water_services IS NULL), 19.59, -999) AS New_pct_unemployment
# FROM access_to_basic_services;
# Out:
#  * mysql+pymysql://anthony:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Central and Southern Asia', Decimal('94.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('94.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('95.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('95.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('95.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('95.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('89.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('90.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('91.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('91.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('91.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('92.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('80.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('81.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('82.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('83.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('85.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('85.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('97.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('98.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('98.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('99.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('97.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('97.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('98.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('98.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('98.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('98.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('67.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('69.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('72.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('75.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('78.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('80.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('97.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('97.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('97.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('97.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('97.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('97.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('96.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('97.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('97.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('97.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('97.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('97.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('89.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('89.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('90.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('90.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('90.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('91.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('95.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('96.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('96.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('96.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('96.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('96.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('99.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('99.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('99.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('99.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('99.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('99.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('88.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('88.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('89.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('89.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('90.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('90.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('90.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('90.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('90.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('90.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('90.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('90.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('92.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('93.00'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('93.67'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('94.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('94.33'), Decimal('-999')),
#  ('Central and Southern Asia', Decimal('94.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('91.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('91.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('92.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('92.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('93.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('93.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('94.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('94.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('94.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('93.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('93.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('93.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('99.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('99.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('99.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('99.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('99.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('99.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('75.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('77.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('78.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('79.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('80.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('81.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('99.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('99.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('73.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('73.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('74.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('74.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('75.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('75.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('88.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('89.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('89.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('90.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('91.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('92.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('79.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('82.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('83.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('85.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('86.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('86.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('95.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('95.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('95.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('95.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('95.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('95.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('76.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('78.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('80.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('82.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('84.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('85.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('92.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('92.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('93.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('93.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('93.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('94.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('99.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('99.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('78.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('80.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('82.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('84.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('86.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('87.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('94.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('95.00'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('95.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('96.33'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('96.67'), Decimal('-999')),
#  ('Eastern and South-Eastern Asia', Decimal('97.33'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('99.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('99.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('99.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('99.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('99.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('99.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('91.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('91.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('91.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('91.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('91.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('91.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('99.00'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('99.33'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('99.67'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('99.67'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('99.67'), Decimal('-999')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('64.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('64.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('64.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('64.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('64.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('65.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('90.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('90.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('90.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('90.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('90.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('90.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('92.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('92.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('92.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('93.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('92.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('93.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('93.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('79.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('79.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('79.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('79.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('79.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('79.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('91.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('91.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('92.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('92.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('92.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('92.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('87.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('88.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('89.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('89.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('90.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('90.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('93.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('93.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('91.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('92.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('92.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('93.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('93.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('91.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('91.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('91.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('91.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('91.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('91.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('99.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('86.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('87.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('87.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('88.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('89.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('90.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('96.67'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('97.33'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('92.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('99.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('99.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('99.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('99.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('99.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('99.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('97.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('98.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('99.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('81.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('83.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('84.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('85.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('87.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('88.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('61.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('62.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('62.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('62.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('62.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('62.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('94.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('95.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('96.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('97.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('99.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('99.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('91.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('92.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('94.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('95.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('95.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('95.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('96.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('96.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('96.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('96.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('96.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('92.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('94.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('95.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('97.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('97.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('98.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('98.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('98.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('98.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('98.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('98.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('91.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('92.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('92.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('92.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('86.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('86.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('86.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('87.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('87.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('87.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('96.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('96.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('97.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('97.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('97.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('98.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('93.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('95.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('96.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('96.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('96.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('96.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('96.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('59.00'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('59.67'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('60.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('61.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('62.33'), Decimal('-999')),
#  ('Northern Africa and Western Asia', Decimal('63.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('93.67'), Decimal('-999')),
#  ('Oceania', Decimal('93.67'), Decimal('-999')),
#  ('Oceania', Decimal('93.67'), Decimal('-999')),
#  ('Oceania', Decimal('93.67'), Decimal('-999')),
#  ('Oceania', Decimal('93.67'), Decimal('-999')),
#  ('Oceania', Decimal('93.67'), Decimal('-999')),
#  ('Oceania', Decimal('98.00'), Decimal('-999')),
#  ('Oceania', Decimal('98.00'), Decimal('-999')),
#  ('Oceania', Decimal('99.00'), Decimal('-999')),
#  ('Oceania', Decimal('99.00'), Decimal('-999')),
#  ('Oceania', Decimal('99.00'), Decimal('-999')),
#  ('Oceania', Decimal('99.00'), Decimal('-999')),
#  ('Oceania', Decimal('53.67'), Decimal('-999')),
#  ('Oceania', Decimal('54.33'), Decimal('-999')),
#  ('Oceania', Decimal('55.00'), Decimal('-999')),
#  ('Oceania', Decimal('55.67'), Decimal('-999')),
#  ('Oceania', Decimal('56.33'), Decimal('-999')),
#  ('Oceania', Decimal('56.67'), Decimal('-999')),
#  ('Oceania', Decimal('74.33'), Decimal('-999')),
#  ('Oceania', Decimal('74.00'), Decimal('-999')),
#  ('Oceania', Decimal('73.33'), Decimal('-999')),
#  ('Oceania', Decimal('72.33'), Decimal('-999')),
#  ('Oceania', Decimal('72.33'), Decimal('-999')),
#  ('Oceania', Decimal('72.33'), Decimal('-999')),
#  ('Oceania', Decimal('92.00'), Decimal('-999')),
#  ('Oceania', Decimal('92.67'), Decimal('-999')),
#  ('Oceania', Decimal('93.00'), Decimal('-999')),
#  ('Oceania', Decimal('93.00'), Decimal('-999')),
#  ('Oceania', Decimal('93.00'), Decimal('-999')),
#  ('Oceania', Decimal('93.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('73.67'), Decimal('-999')),
#  ('Oceania', Decimal('74.33'), Decimal('-999')),
#  ('Oceania', Decimal('75.00'), Decimal('-999')),
#  ('Oceania', Decimal('75.33'), Decimal('-999')),
#  ('Oceania', Decimal('76.00'), Decimal('-999')),
#  ('Oceania', Decimal('77.00'), Decimal('-999')),
#  ('Oceania', Decimal('89.33'), Decimal('-999')),
#  ('Oceania', Decimal('89.67'), Decimal('-999')),
#  ('Oceania', Decimal('89.67'), Decimal('-999')),
#  ('Oceania', Decimal('90.00'), Decimal('-999')),
#  ('Oceania', Decimal('90.00'), Decimal('-999')),
#  ('Oceania', Decimal('90.00'), Decimal('-999')),
#  ('Oceania', Decimal('88.00'), Decimal('-999')),
#  ('Oceania', Decimal('88.00'), Decimal('-999')),
#  ('Oceania', Decimal('88.00'), Decimal('-999')),
#  ('Oceania', Decimal('88.00'), Decimal('-999')),
#  ('Oceania', Decimal('88.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
# ...
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('98.67'), Decimal('-999')),
#  ('Oceania', Decimal('98.67'), Decimal('-999')),
#  ('Oceania', Decimal('98.67'), Decimal('-999')),
#  ('Oceania', Decimal('98.67'), Decimal('-999')),
#  ('Oceania', Decimal('98.67'), Decimal('-999')),
#  ('Oceania', Decimal('99.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('100.00'), Decimal('-999')),
#  ('Oceania', Decimal('99.00'), Decimal('-999')),
#  ('Oceania', Decimal('99.00'), Decimal('-999')),
#  ('Oceania', Decimal('99.00'), Decimal('-999')),
#  ('Oceania', Decimal('99.00'), Decimal('-999')),
#  ('Oceania', Decimal('99.00'), Decimal('-999')),
#  ('Oceania', Decimal('99.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('68.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('68.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('69.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('69.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('70.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('70.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('81.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('81.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('81.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('81.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('81.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('69.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('69.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('69.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('69.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('69.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('69.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('56.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('56.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('52.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('53.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('54.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('55.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('57.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('58.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('64.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('65.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('65.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('65.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('66.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('67.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('53.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('54.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('54.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('55.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('56.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('56.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('71.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('72.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('72.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('73.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('73.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('74.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('100.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('100.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('100.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('100.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('100.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('100.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('97.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('97.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('97.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('96.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('96.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('96.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('55.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('58.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('60.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('62.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('64.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('66.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('63.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('64.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('65.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('65.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('66.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('66.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('100.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('100.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('100.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('100.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('100.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('100.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('96.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('96.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('96.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('96.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('97.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('50.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('52.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('53.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('54.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('56.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('57.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('46.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('46.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('47.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('47.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('48.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('48.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('55.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('55.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('57.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('58.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('59.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('61.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('58.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('60.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('61.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('63.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('64.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('65.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('63.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('64.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('64.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('65.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('66.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('66.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('70.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('69.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('69.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('68.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('68.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('68.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('50.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('51.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('51.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('52.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('52.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('52.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('62.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('62.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('63.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('63.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('63.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('64.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('44.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('42.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('41.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('40.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('39.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('38.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('51.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('52.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('52.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('52.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('52.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('52.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('66.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('67.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('68.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('68.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('69.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('69.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('45.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('45.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('46.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('46.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('47.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('47.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('57.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('57.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('58.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('72.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('72.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('73.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('73.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('73.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('73.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('76.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('76.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('77.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('77.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('77.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('77.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('85.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('86.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('87.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('88.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('89.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('89.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('73.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('74.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('75.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('75.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('76.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('76.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('74.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('75.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('75.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('76.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('76.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('76.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('83.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('83.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('83.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('83.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('83.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('83.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('90.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('90.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('91.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('91.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('91.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('92.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('65.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('65.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('65.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('65.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('65.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('65.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('56.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('56.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('55.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('54.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('54.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('53.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('83.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('84.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('85.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('86.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('86.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('87.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('71.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('71.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('71.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('71.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('70.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('70.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('78.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('78.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('78.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('78.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('79.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('79.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('79.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('80.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('81.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('82.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('83.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('84.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('67.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('67.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('67.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('67.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('67.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('67.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('60.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('60.33'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('60.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('60.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('60.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('60.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('72.67'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('73.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('74.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('74.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('75.00'), Decimal('-999')),
#  ('Sub-Saharan Africa', Decimal('75.00'), Decimal('-999')),
#  ...]

# %% [markdown]
# ### 2. Replace NULL values for Eastern and South-Eastern Asia
#
# Now we have our first region sorted, but we have various regions to consider, so we need to add conditions for each region.
# To begin, add a second condition to the solution to set the `New_pct_unemployment` for `Eastern and South-Eastern Asia` to `22.64`, using a nested `IF` statement.  If neither condition is met, it should assign a value of `-999`.

# %%
# Add your code here

# %% [markdown]
# ### 3. Replace NULL values for remaining regions
#
# Now, let's add more conditions to assign the `New_pct_unemployment` values for the remaining regions.
# We have five more regions to assign `Pct_unemployment` values for. Add five more layers to the nested `IF` statement to set the unemployment percentage for these regions as follows:
#  - `Europe and Northern America` to `24.43`
#  - `Latin America and the Caribbean` to `24.23`
#  - `Northern Africa and Western Asia` to `17.84`
#  - `Oceania` to `4.98`
#  - `Sub-Saharan Africa` to `33.65`
#
# Assign `-999` if none of the conditions are met.

# %%
# Add your code here

# %% [markdown]
# ### 4. Replace the placeholder value
#
# Finally, replace the placeholder value of `-999` with the actual `Pct_unemployment` value for records where none of our conditions are met.

# %%
# Add your code here

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Replace NULL values for Central and Southern Asia

# %%
# %%sql
#
# SELECT Region,
#        Pct_unemployment,
#        IF( (Region = "Central and Southern Asia") AND (Pct_unemployment IS NULL), 19.59, -999
#        ) AS New_pct_unemployment
# FROM united_nations.Access_to_Basic_Services
# LIMIT 10; -- Remove this line to see the full result

# %% [markdown]
# The placeholder value of `-999` helps us keep track of what our `IF` statement has changed so we can verify that our logic is working correctly.

# %% [markdown]
# ### 2. Replace NULL values for Eastern and South-Eastern Asia

# %%
# %%sql
#
# SELECT Region,
#        Pct_unemployment,
#        IF( (Region = "Central and Southern Asia") AND (Pct_unemployment IS NULL), 19.59,
#             IF( (Region = "Eastern and South-Eastern Asia") AND (Pct_unemployment IS NULL), 22.64,
#                  -999
#             )
#        ) AS New_pct_unemployment
# FROM united_nations.Access_to_Basic_Services;

# %% [markdown]
# ### 3. Replace NULL values for remaining regions

# %%
# %%sql
#
# SELECT Region,
#        Pct_unemployment,
#        IF( (Region = "Central and Southern Asia") AND (Pct_unemployment IS NULL), 19.59,
#             IF( (Region = "Eastern and South-Eastern Asia") AND (Pct_unemployment IS NULL), 22.64,
#                  IF( (Region = "Europe and Northern America") AND (Pct_unemployment IS NULL), 24.43,
#                       IF( (Region = "Latin America and the Caribbean") AND (Pct_unemployment IS NULL), 24.23,
#                            IF( (Region = "Northern Africa and Western Asia") AND (Pct_unemployment IS NULL), 17.84,
#                                 IF( (Region = "Oceania") AND (Pct_unemployment IS NULL), 4.98,
#                                      IF( (Region = "Sub-Saharan Africa") AND (Pct_unemployment IS NULL), 33.65,
#                                           -999
#                                          )
#                                     )
#                                )
#                           )
#                      )
#                 )
#            )
#        ) AS New_pct_unemployment
# FROM united_nations.Access_to_Basic_Services;

# %% [markdown]
# ### 4. Replace the placeholder value

# %%
# %%sql
#
# SELECT Region,
#        Pct_unemployment,
#        IF( (Region = "Central and Southern Asia") AND (Pct_unemployment IS NULL), 19.59,
#             IF( (Region = "Eastern and South-Eastern Asia") AND (Pct_unemployment IS NULL), 22.64,
#                  IF( (Region = "Europe and Northern America") AND (Pct_unemployment IS NULL), 24.43,
#                       IF( (Region = "Latin America and the Caribbean") AND (Pct_unemployment IS NULL), 24.23,
#                            IF( (Region = "Northern Africa and Western Asia") AND (Pct_unemployment IS NULL), 17.84,
#                                 IF( (Region = "Oceania") AND (Pct_unemployment IS NULL), 4.98,
#                                      IF( (Region = "Sub-Saharan Africa") AND (Pct_unemployment IS NULL), 33.65,
#                                           Pct_unemployment
#                                          )
#                                     )
#                                )
#                           )
#                      )
#                 )
#            )
#        ) AS New_pct_unemployment
# FROM united_nations.Access_to_Basic_Services;

# %% [markdown]
# ### Summary
#
# We have identified the NULL values within the `Pct_unemployment` column and assigned estimated unemployment rates based on their respective regions.

# %% [markdown]
# #
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
