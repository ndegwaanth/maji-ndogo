# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Intro to the Second Normal Form – 2NF

# %% [markdown]
# In this train, we will learn how to normalise a database table into the Second Normal Form (2NF) by first ensuring that the table is in the First Normal Form (1NF) and then creating separate tables for related entities. We will also be introduced to the concept of a junction table.

# %% [markdown]
# > ⚠️ This exercise extends the concepts introduced in the previous one, **Intro to the First Normal Form – 1NF**. Therefore, it's important to ensure that you continue using the modified `dam_levels.db` database after successfully completing the previous exercise.
#
# > ⚠️ Since the queries here will modify the database, you will have to get a fresh copy to redo the code cells.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you should:
# - Understand the key principles of achieving Second Normal Form (2NF) in database normalisation.
# - Practise splitting a denormalised table into separate tables, addressing partial functional dependencies.
# - Master the concept of a junction table and its role in linking data between two related tables in a database schema.

# %% [markdown]
# ## 1. Overview
# To get the table in 2NF, we need to ensure the following:
#
# - The table is in 1NF.
# - All partial functional dependencies should be removed – all non-key columns should depend on the key column, and anything else should be placed in a separate table.

# %% [markdown]
# <div>
# Let's look at normalising the 1NF dams database containing information about Cape Town dam water levels leading up to the 2018 Cape Town water crisis.
# </div>

# %% [markdown]
# ## Connecting to the database

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Load SQLite database
# %sql sqlite:///data/dam_levels-a-3987.db

# %% [markdown]
# Before we proceed, let's first take a closer look at the `dam_levels_1nf` table:

# %%
# %%sql
#
# SELECT *
# FROM dam_levels_1nf
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# Done.
# [(1, 2012, 'WEMMERSHOEK', 'P. M. Naidoo', 201013, 48.2, -33.826246, 19.091828),
#  (2, 2012, 'STEENBRAS LOWER;STEENBRAS UPPER', 'V. Mokere', 201124, 20.3, -34.180527, 18.866688),
#  (3, 2012, 'VOËLVLEI', 'A. T. Sijovu', 202256, 15.0, -33.34178, 19.04105),
#  (4, 2012, 'HELY-HUTCHINSON', 'P. M. Naidoo', 201013, 14.2, -33.976929, 18.409568),
#  (5, 2012, 'WOODHEAD', 'A. T. Sijovu', 202256, 35.3, -33.977341, 18.404046),
#  (6, 2013, 'WEMMERSHOEK', 'P. M. Naidoo', 201013, 53.3, -33.826246, 19.091828),
#  (7, 2013, 'STEENBRAS LOWER;STEENBRAS UPPER', 'V. Mokere', 201124, 22.4, -34.180527, 18.866688),
#  (8, 2013, 'VOËLVLEI', 'A. T. Sijovu', 202256, 16.6, -33.34178, 19.04105),
#  (9, 2013, 'HELY-HUTCHINSON', 'P. M. Naidoo', 201013, 15.2, -33.976929, 18.409568),
#  (10, 2013, 'WOODHEAD', 'A. T. Sijovu', 202256, 35.9, -33.977341, 18.404046),
#  (11, 2015, 'WEMMERSHOEK', 'P. M. Naidoo', 201013, 47.5, -33.826246, 19.091828),
#  (12, 2015, 'STEENBRAS LOWER;STEENBRAS UPPER', 'V. Mokere', 201124, 22.7, -34.180527, 18.866688),
#  (13, 2015, 'VOËLVLEI', 'A. T. Sijovu', 202256, 11.9, -33.34178, 19.04105),
#  (14, 2015, 'HELY-HUTCHINSON', 'P. M. Naidoo', 201013, 15.3, -33.976929, 18.409568),
#  (15, 2015, 'WOODHEAD', 'A. T. Sijovu', 202256, 36.1, -33.977341, 18.404046)]

# %% [markdown]
# Looking at the table, we notice two distinct entities: assessments and dam information.
#
#
# As such, we need to create two tables:
#
# - `assessments` – with columns: `AssessmentId`, `year`, `Assessment_Officer`, `Officer_Reg`, `water_level`
# - `dams` – with columns: `dam_name`, `dam_latitude`, `dam_longitude`

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### Exercise 1
#
# Create the `assessments` table.

# %%
# %%sql
# drop table if exists assessment;
# create table assessment(
#     Assessmented_ID INTEGER PRIMARY KEY,
#     year INTEGER,
#     Assessment_Officer varchar(25),
#     Officer_Reg varchar(20),
#     water_level REAL
# )
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# Done.
# Done.
# []

# %%
# %%sql
# select * from assessment limit 5;
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# Done.
# [(1, 2012, 'P. M. Naidoo', 201013, 48.2),
#  (2, 2012, 'V. Mokere', 201124, 20.3),
#  (3, 2012, 'A. T. Sijovu', 202256, 15.0),
#  (4, 2012, 'P. M. Naidoo', 201013, 14.2),
#  (5, 2012, 'A. T. Sijovu', 202256, 35.3)]

# %%
# %%sql
# create table dams AS
# select
#     dam_name,
#     dam_latitude,
#     dam_longitude
# from dam_levels_1nf;
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# Done.
# []

# %%
# %%sql
# select * from dams limit 5;
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# Done.
# [('WEMMERSHOEK', -33.826246, 19.091828),
#  ('STEENBRAS LOWER;STEENBRAS UPPER', -34.180527, 18.866688),
#  ('VOËLVLEI', -33.34178, 19.04105),
#  ('HELY-HUTCHINSON', -33.976929, 18.409568),
#  ('WOODHEAD', -33.977341, 18.404046)]

# %%
# %%sql
# select
#     name
# from sqlite_master
# where type='table';
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# Done.
# [('dam_levels',),
#  ('dam_levels_split',),
#  ('dam_levels_1nf',),
#  ('sqlite_sequence',),
#  ('assessment',),
#  ('dams',)]

# %% [markdown]
# ### Exercise 2
#
# Copy the relevant data into the `assessments` table from `dam_levels_1nf`.

# %%
# %%sql
# insert into assessment
# Select
#     Assessmented_ID,
#     year,
#     Assessment_Officer,
#     Officer_Reg,
#     water_level
# from dam_levels_1nf;
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# 15 rows affected.
# []

# %%
# %%sql
# select * from assessment limit 5;
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# Done.
# [(1, 2012, 'P. M. Naidoo', '201013', 48.2),
#  (2, 2012, 'V. Mokere', '201124', 20.3),
#  (3, 2012, 'A. T. Sijovu', '202256', 15.0),
#  (4, 2012, 'P. M. Naidoo', '201013', 14.2),
#  (5, 2012, 'A. T. Sijovu', '202256', 35.3)]

# %% [markdown]
# ### Exercise 3
#
# Create the `dams` table.

# %%
# %%sql
# drop table if exists dams;
# create table dams (
#     dam_name varchar(100),
#     dam_latitude decimal(10, 8),
#     dam_longitude decimal(11, 8)
# );
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# Done.
# Done.
# []

# %% [markdown]
# ### Exercise 4
#
# Copy the relevant data into the `dams` table from `dam_levels_1nf`.

# %%
# %%sql
# insert into dams
# select
#     dam_name,
#     dam_latitude,
#     dam_longitude
# from dam_levels_1nf;
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# 15 rows affected.
# []

# %%
# %%sql
# select * from dams limit 5;
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# Done.
# [('WEMMERSHOEK', -33.826246, 19.091828),
#  ('STEENBRAS LOWER;STEENBRAS UPPER', -34.180527, 18.866688),
#  ('VOËLVLEI', -33.34178, 19.04105),
#  ('HELY-HUTCHINSON', -33.976929, 18.409568),
#  ('WOODHEAD', -33.977341, 18.404046)]

# %% [markdown]
# ### Exercise 5
#
# At this point, we've created two tables: the `assessments` and the `dams` tables. However, the assessments and dam information are no longer linked, i.e. we don't know which assessment belongs to which dam. As such, we'll need to create a junction table (i.e. a linking table, in this case, a table that connects an assessment to a dam).
#
# To make a valid junction table, we'll need primary keys from both tables.
#
# Using the `AssessmentId` from the `assessments` table and the `dam_name` from the `dams` table, create the junction table. Call it `dam_assessments`.

# %%
# %%sql
# drop table if exists dam_assessment;
# create table dam_assessment(
#     Assessmented_ID INTEGER PRIMARY KEY AUTOINCREMENT,
#     dam_name varchar(100)
# );
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# Done.
# Done.
# []

# %% [markdown]
# ### Exercise 6
#
# Insert the relevant data into the `dam_assessments` table.

# %%
# %%sql
# INSERT INTO dam_assessment (Assessmented_ID, dam_name)
# SELECT
#     Assessmented_ID,
#     dam_name
# FROM dam_levels_1nf;
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# 15 rows affected.
# []

# %%
# %%sql
# select * from dam_assessment;
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# Done.
# [(1, 'WEMMERSHOEK'),
#  (2, 'STEENBRAS LOWER;STEENBRAS UPPER'),
#  (3, 'VOËLVLEI'),
#  (4, 'HELY-HUTCHINSON'),
#  (5, 'WOODHEAD'),
#  (6, 'WEMMERSHOEK'),
#  (7, 'STEENBRAS LOWER;STEENBRAS UPPER'),
#  (8, 'VOËLVLEI'),
#  (9, 'HELY-HUTCHINSON'),
#  (10, 'WOODHEAD'),
#  (11, 'WEMMERSHOEK'),
#  (12, 'STEENBRAS LOWER;STEENBRAS UPPER'),
#  (13, 'VOËLVLEI'),
#  (14, 'HELY-HUTCHINSON'),
#  (15, 'WOODHEAD')]

# %% [markdown]
# ### Exercise 7
#
# Delete the now redundant `dam_levels_1nf` table.

# %%
# %%sql
# -- drop table if exists dam_levels_1nf;
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# Done.
# []

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Exercise 1

# %%
# %%sql
#
# CREATE TABLE assessments (
#     AssessmentId INTEGER PRIMARY KEY AUTOINCREMENT,
#     year INTEGER,
#     Assessment_Officer VARCHAR(100),
#     Officer_Reg INTEGER,
#     water_level NUMERIC(10,1)
# );

# %% [markdown]
# ### Exercise 2

# %%
# %%sql
#
# INSERT INTO
#     assessments(
#             AssessmentId,
#             year,
#             Assessment_Officer,
#             Officer_Reg,
#             water_level
#         )
# SELECT
#     AssessmentId,
#     year,
#     Assessment_Officer,
#     Officer_Reg,
#     water_level
# FROM
#     dam_levels_1nf
# ORDER BY year;

# %% [markdown]
# ### Exercise 3

# %%
# %%sql
#
# CREATE TABLE dams (
#     dam_name VARCHAR(100),
#     dam_latitude NUMERIC(3,6),
#     dam_longitude NUMERIC(3,6)
# );

# %% [markdown]
# ### Exercise 4

# %%
# %%sql
#
# INSERT INTO
#     dams(
#             dam_name,
#             dam_latitude,
#             dam_longitude
#         )
# SELECT
#     dam_name,
#     dam_latitude,
#     dam_longitude
# FROM
#     dam_levels_1nf
# GROUP BY dam_name;

# %% [markdown]
# ### Exercise 5

# %%
# %%sql
#
# CREATE TABLE
#     dam_assessments (
#         AssessmentId INTEGER PRIMARY KEY AUTOINCREMENT,
#         dam_name VARCHAR(100)
#     );

# %% [markdown]
# ### Exercise 6

# %%
# %%sql
#
# INSERT INTO
#     dam_assessments(
#             AssessmentId,
#             dam_name
#         )
# VALUES
#     (1 	, "WEMMERSHOEK"),
#     (2 	, "VOËLVLEI"),
#     (3 	, "HELY-HUTCHINSON"),
#     (4 	, "WOODHEAD"),
#     (5 	, "STEENBRAS LOWER"),
#     (6 	, "STEENBRAS UPPER"),
#     (7 	, "WEMMERSHOEK"),
#     (8 	, "VOËLVLEI"),
#     (9 	, "HELY-HUTCHINSON"),
#     (10 , "WOODHEAD"),
#     (11 , "STEENBRAS LOWER"),
#     (12 , "STEENBRAS UPPER"),
#     (13 , "WEMMERSHOEK"),
#     (14 , "VOËLVLEI"),
#     (15 , "HELY-HUTCHINSON"),
#     (16 , "WOODHEAD"),
#     (17 , "STEENBRAS LOWER"),
#     (18 , "STEENBRAS UPPER");

# %% [markdown]
# ### Exercise 7

# %%
# %%sql
#
# DROP TABLE dam_levels_1nf;

# %%
# %%sql
# select name
# from sqlite_master
# where type='table';
# Out:
#  * sqlite:///data/dam_levels-a-3987.db
# Done.
# [('dam_levels',),
#  ('dam_levels_split',),
#  ('dam_levels_1nf',),
#  ('sqlite_sequence',),
#  ('assessment',),
#  ('dams',),
#  ('dam_assessment',)]

# %% [markdown]
# ## Summary
#
# At this point, we have split the dam_levels_1nf table into the following tables:
#
# |name|
# ---
# assessments
# dam_assessments
# dams
#
# Since these tables are in 1NF and do not have any partial functional dependencies, we have successfully normalised our tables into the Second Normal Form!

# %% [markdown]
# **Important**: After completing this exercise, ensure that you save the `dam_levels.db` file, as it will be used as a foundation for the next exercise.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
